# %% [markdown]
# # Machine Learning for CICY 3-Folds
#
# We compute the Hodge numbers of CICY 3-folds using deep learning techniques inspired by the Inception architecture by Google.

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import tarfile
import urllib
import json
import joblib
from IPython.display import Image
from nntools import *

# %%
random_state = 123
np.random.seed(random_state)
tf.random.set_seed(random_state)

# %% [markdown]
# ## Create a Saving Directory
#
# Each model will be assigned to a different directory based on the time of running.

# %%
img_dir, mod_dir = dir_struct('convnet_5x5_h11', dirs=['img', 'models'])
# Out:
# Current working directories:
#
#   ./img/convnet_5x5_h11_20201222_085105
#   ./models/convnet_5x5_h11_20201222_085105

# %% [markdown]
# ## Load the Dataset
#
# We then download the JSON file containing the configuration matrix and the Hodge numbers of the CICY.

# %%
os.makedirs('./data', exist_ok=True)

urllib.request.urlretrieve('http://www.lpthe.jussieu.fr/~erbin/files/data/cicy3o_data.tar.gz', './data/cicy3o_data.tar.gz')
with tarfile.open('./data/cicy3o_data.tar.gz', 'r') as tar:
    tar.extract('cicy3o.h5', path='./data')

# %%
df, (n_rows, n_cols) = load_hdf('./data/cicy3o.h5')
# Out:
# Size of the dataset: 7890 rows, 31 columns.

# %% [markdown]
# We then select only the non product spaces:

# %%
df = df.loc[df['isprod'] == False]

# %% [markdown]
# We the pad the matrix to get the same size for all configuration matrices:

# %%
max_size = df['matrix'].apply(np.shape).max()

df.loc[:, 'matrix'] = df['matrix'].apply(lambda x: np.pad(x, ((0, max_size[0] - np.shape(x)[0]), (0, max_size[1] - np.shape(x)[1]))))
df = df[['h11', 'h21', 'matrix']]
n_rows, n_cols = df.shape

# %%
num_classes = (int(df['h11'].max() + 1), int(df['h21'].max() + 1))

# %% [markdown]
# We then split it into train, validation and test sets:

# %%
df_splits = {'train_split': 0.80, 'val_split': 0.5}
with open(os.path.join(mod_dir, 'train_ratio.json'), 'w') as f:
    json.dump(df_splits, f)

# split the sets
(df_train, df_val, df_test), (n_train, n_val, n_test) = train_test(df, df_splits, random_state=random_state)

# %%
del df

# %% [markdown]
# ## Outliers in the Training Set
#
# We then study the outliers in the training set:

# %%
# remove outliers
df_train = df_train.loc[(df_train['h11'] >= 1) & (df_train['h11'] <= 16)
                        &
                        (df_train['h21'] >= 15) & (df_train['h21'] <= 86)
                       ]
n_train_pruned = df_train.shape[0]

# %%
print(f'Samples removed: {n_train - n_train_pruned:d} ({100 * (n_train - n_train_pruned) / n_train:.2f}% of the training set, {100 * (n_train - n_train_pruned) / n_rows:.2f}% of the total set)')
# Out:
# Samples removed: 12 (0.19% of the training set, 0.15% of the total set)

# %% [markdown]
# ## Rescale the Matrices
#
# We then rescale the matrices in the sets to improve the deep learning results:

# %%
# rescaling = {'min': df_train['matrix'].apply(lambda x: np.min(x)).min(),
#              'max': df_train['matrix'].apply(lambda x: np.max(x)).max()
#             }
rescaling = None

# %% [markdown]
# ## Feature and Label Creation
#
# We then create the features and the labels.

# %%
reshape = df_train['matrix'].apply(np.shape).max() + (1,)

# %%
X_train = create_features(df_train['matrix'], rescaling=rescaling, reshape=reshape)
X_val   = create_features(df_val['matrix'], rescaling=rescaling, reshape=reshape)
X_test  = create_features(df_test['matrix'], rescaling=rescaling, reshape=reshape)

# %%
y_train = create_labels(df_train[['h11']], one_hot=True, num_classes=num_classes[0])
y_val   = create_labels(df_val[['h11']], one_hot=True, num_classes=num_classes[0])
y_test  = create_labels(df_test[['h11']], one_hot=True, num_classes=num_classes[0])

# %%
del df_train, df_val, df_test

# %% [markdown]
# ## Inception Model
#
# We then start to build the Inception model to be trained on the configuration matrices.

# %% [markdown]
# ### Build the Model

# %%
model_data = {'input_shape':   reshape,
              'name':          'matrix',
              'learning_rate': 1.0e-3,
              'output_names':  'h11',
              'output_size':   num_classes[0],
              'model_type':    'classification',
              'conv_1b1':      False,
              'conv_layers':   [180, 100, 40, 20],
              'conv_kernel':   (5,5),
              'conv_padding':  'same',
              'conv_alpha':    0.0,
              'conv_red':      0,
              'feat_map':      0,
              'recurrent':     False,
              'fc_layers':     [],
              'fc_alpha':      0.0,
              'dropout':       0.2,
              'full_dropout':  0.0,
              'batchnorm':     0.99,
              'last_relu':     False,
              'loss_weights':  None,
              'l1_reg':        1.0e-4,
              'l2_reg':        1.0e-3,
              'output_layers': True,
              'random_state':  random_state
             }

with open(os.path.join(mod_dir, 'model_data.json'), 'w') as f:
    json.dump(model_data, f)

# %%
convnet = nn_lenet(**model_data)
convnet.summary()
# Out:
# Model: "matrix"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# matrix (InputLayer)          [(None, 12, 15, 1)]       0
# _________________________________________________________________
# matrix_convA_0 (Conv2D)      (None, 12, 15, 180)       4680
# _________________________________________________________________
# matrix_actA_0 (LeakyReLU)    (None, 12, 15, 180)       0
# _________________________________________________________________
# matrix_convBN_0 (BatchNormal (None, 12, 15, 180)       720
# _________________________________________________________________
# matrix_convA_1 (Conv2D)      (None, 12, 15, 100)       450100
# _________________________________________________________________
# matrix_actA_1 (LeakyReLU)    (None, 12, 15, 100)       0
# _________________________________________________________________
# matrix_convBN_1 (BatchNormal (None, 12, 15, 100)       400
# _________________________________________________________________
# matrix_convA_2 (Conv2D)      (None, 12, 15, 40)        100040
# _________________________________________________________________
# matrix_actA_2 (LeakyReLU)    (None, 12, 15, 40)        0
# _________________________________________________________________
# matrix_convBN_2 (BatchNormal (None, 12, 15, 40)        160
# _________________________________________________________________
# matrix_convA_3 (Conv2D)      (None, 12, 15, 20)        20020
# _________________________________________________________________
# matrix_actA_3 (LeakyReLU)    (None, 12, 15, 20)        0
# _________________________________________________________________
# matrix_convBN_3 (BatchNormal (None, 12, 15, 20)        80
# _________________________________________________________________
# matrix_flat (Flatten)        (None, 3600)              0
# _________________________________________________________________
# matrix_drop (Dropout)        (None, 3600)              0
# _________________________________________________________________
# h11 (Dense)                  (None, 20)                72020
# =================================================================
# Total params: 648,220
# Trainable params: 647,540
# Non-trainable params: 680
# _________________________________________________________________

# %%
convnet_graph = keras.utils.model_to_dot(convnet, show_shapes=True, dpi=144)
convnet_graph.write_pdf(os.path.join(img_dir, 'convnet.pdf'))
Image(convnet_graph.create_png(), width=480)

# %% [markdown]
# ### Train the Model

# %%
fit_data = {'epochs':             1000,
            'batch_size':         32,
            'reduce_lr_factor':   0.3,
            'reduce_lr_patience': 350,
            'stat_interval':      100
           }

with open(os.path.join(mod_dir, 'fit_data.json'), 'w') as f:
    json.dump(fit_data, f)

# %%
callbacks = model_checkpoints(root=mod_dir,
                              validation=True,
                              reduce_lr=fit_data['reduce_lr_factor'],
                              lr_patience=fit_data['reduce_lr_patience'],
                              summary=fit_data['stat_interval']
                             )

convnet_hst = convnet.fit(x=X_train,
                          y=y_train,
                          batch_size=fit_data['batch_size'],
                          epochs=fit_data['epochs'],
                          verbose=0,
                          callbacks=callbacks,
                          validation_data=(X_val, y_val)
                         )
# Out:
# Training has started. Callouts will be printed every 100 epochs.
#
# Training epoch 1. Started on 22/12/2020 at 08:51:08.
#
#     Average epoch training time: 00 hours, 00 minutes, 26 seconds
#
#     loss = 2.454739
#     categorical_accuracy = 0.580070
#     val_loss = 4.964350
#     val_categorical_accuracy = 0.016518
#     lr = 0.001000
#
# Training epoch 100. Started on 22/12/2020 at 08:58:49.
#
#     Average epoch training time: 00 hours, 00 minutes, 15 seconds
#
#     loss = 0.198796
#     categorical_accuracy = 0.991563
#     val_loss = 0.799724
#     val_categorical_accuracy = 0.907243
#     lr = 0.001000
#
# Training epoch 200. Started on 22/12/2020 at 09:06:30.
#
#     Average epoch training time: 00 hours, 00 minutes, 11 seconds
#
#     loss = 0.161924
#     categorical_accuracy = 0.989812
#     val_loss = 0.650024
#     val_categorical_accuracy = 0.927573
#     lr = 0.001000
#
# Training epoch 300. Started on 22/12/2020 at 09:14:12.
#
#     Average epoch training time: 00 hours, 00 minutes, 10 seconds
#
#     loss = 0.138706
#     categorical_accuracy = 0.991245
#     val_loss = 0.784416
#     val_categorical_accuracy = 0.914867
#     lr = 0.001000
#
# Training epoch 400. Started on 22/12/2020 at 09:21:26.
#
#     Average epoch training time: 00 hours, 00 minutes, 08 seconds
#
#     loss = 0.097775
#     categorical_accuracy = 0.996975
#     val_loss = 0.739095
#     val_categorical_accuracy = 0.927573
#     lr = 0.001000
#
# Training epoch 500. Started on 22/12/2020 at 09:27:02.
#
#     Average epoch training time: 00 hours, 00 minutes, 07 seconds
#
#     loss = 0.097982
#     categorical_accuracy = 0.995861
#     val_loss = 0.731599
#     val_categorical_accuracy = 0.922490
#     lr = 0.001000
#
# Training epoch 600. Started on 22/12/2020 at 09:31:28.
#
#     Average epoch training time: 00 hours, 00 minutes, 07 seconds
#
#     loss = 0.047212
#     categorical_accuracy = 0.998567
#     val_loss = 1.002630
#     val_categorical_accuracy = 0.914867
#     lr = 0.000300
#
# Training epoch 700. Started on 22/12/2020 at 09:35:16.
#
#     Average epoch training time: 00 hours, 00 minutes, 06 seconds
#
#     loss = 0.040123
#     categorical_accuracy = 0.999363
#     val_loss = 1.051559
#     val_categorical_accuracy = 0.923761
#     lr = 0.000300
#
# Training epoch 800. Started on 22/12/2020 at 09:39:03.
#
#     Average epoch training time: 00 hours, 00 minutes, 05 seconds
#
#     loss = 0.042856
#     categorical_accuracy = 0.997771
#     val_loss = 0.938331
#     val_categorical_accuracy = 0.919949
#     lr = 0.000300
#
# Training epoch 900. Started on 22/12/2020 at 09:42:43.
#
#     Average epoch training time: 00 hours, 00 minutes, 05 seconds
#
#     loss = 0.034641
#     categorical_accuracy = 0.999522
#     val_loss = 0.897482
#     val_categorical_accuracy = 0.922490
#     lr = 0.000090
#
# Training epoch 1000. Started on 22/12/2020 at 09:44:44.
#
#     Average epoch training time: 00 hours, 00 minutes, 05 seconds
#
#     loss = 0.020540
#     categorical_accuracy = 1.000000
#     val_loss = 0.918810
#     val_categorical_accuracy = 0.932656
#     lr = 0.000090
#
# Training ended on 22/12/2020 at 09:44:45 after 00 hours, 53 minutes, 37 seconds.

# %% [markdown]
# ## Visualisation of the Training Data
#
# We plot the metrics and the loss of the training for reference.

# %%
convnet_hst = pd.DataFrame(convnet_hst.history)
convnet_hst.to_json(os.path.join(mod_dir, 'history.json'), orient='index')

# %%
plot_loss(os.path.join(mod_dir, 'history.json'),
          out_name='convnet_loss',
          root=img_dir,
          validation=True,
          title='Loss Function (categorical crossentropy)',
          yscale='log',
          base_ratio=(1,1),
          show=True,
          save_pdf=True
         )

# %%
plot_metric(os.path.join(mod_dir, 'history.json'),
            metric='categorical_accuracy',
            root=img_dir,
            validation=True,
            title='',
            ylabel='categorical accuracy',
            yscale=None,
            base_ratio=(1,1),
            show=True
           )

# %%
plot_lr(os.path.join(mod_dir, 'history.json'),
        out_name='convnet_lr',
        root=img_dir,
        show=True,
        save_pdf=True
       )

# %% [markdown]
# ## Test Predictions
#
# We finally compute the predictions on the test set.

# %%
model = keras.models.load_model(os.path.join(mod_dir, 'val_loss.h5'))

# %%
y_pred = model.predict(X_test)
y_pred = {key: value.argmax(axis=1) for key, value in y_pred.items()}
y_true = {key: value.argmax(axis=1) for key, value in y_test.items()}

# %%
test_accuracy = {key: np.mean(np.equal(y_pred[key], y_true[key])) for key in y_true.keys()}
for key in test_accuracy.keys():
    print('Test set accuracy:\n')
    print(f'  {key}: {test_accuracy[key]:.3f}')
# Out:
# Test set accuracy:
#
#   h11: 0.916

# %%
with open(os.path.join(mod_dir, 'test_accuracy.json'), 'w') as f:
    json.dump(test_accuracy, f)
