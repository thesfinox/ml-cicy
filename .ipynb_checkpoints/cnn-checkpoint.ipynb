# %% [markdown]
# # Convolutional Neural Networks
#
# We study the performance of CNN architectures on the configuration matrices of CICY 3-folds.

# %%
# set memory growth (necessary for training)
import tensorflow as tf

gpus = tf.config.experimental.list_physical_devices('GPU')

if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
            logical_gpus = tf.config.experimental.list_logical_devices('GPU')
            print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %% [markdown]
# ## Download the Dataset
#
# We first download and unzip the dataset.

# %%
import urllib, tarfile, os

file_url = 'http://www.lpthe.jussieu.fr/~erbin/files/data/cicy3o_data.tar.gz'
file_out = './cicy3o.tar.gz'
file_dat = 'cicy3o.h5'

if not os.path.isfile(file_out):
    urllib.request.urlretrieve(file_url, file_out)
    
if not os.path.isfile(file_dat):
    with tarfile.open(file_out, 'r') as tar:
        tar.extract(file_dat)

# %% [markdown]
# ## Load the Dataset
#
# We then load the dataset:

# %%
import pandas as pd

dat = pd.read_hdf(os.path.join('.', file_dat))

# %% [markdown]
# Remove the outliers (keep $h^{1,1} \in [1, 16]$ and $h^{2,1} \in [15, 86]$):

# %%
dat_out   = dat
dat_noout = dat.loc[(dat['h11'] > 0) &
                    (dat['h11'] < 17) &
                    (dat['h21'] > 14) &
                    (dat['h21'] < 87)
                   ]

dat_out   = dat_out[['h11', 'h21', 'matrix']]
dat_noout = dat_noout[['h11', 'h21', 'matrix']]

# %% [markdown]
# Then extract the `matrix` column into its dense format:

# %%
import numpy as np

def extract_series(series: pd.Series) -> pd.Series:
    '''
    Extract a Pandas series into its dense format.
    
    Required arguments:
        series: the pandas series.
        
    Returns:
        the pandas series in dense format.
    '''
    # avoid direct overwriting
    series = series.copy()
    
    # cget the maximum size of each axis
    max_shape = series.apply(np.shape).max()
    
    # return the transformed series
    if np.prod(max_shape) > 1:
        # compute the necessary shift and apply it
        offset = lambda s: [(0, max_shape[i] - np.shape(s)[i])
                            for i in range(len(max_shape))
                           ]
        return series.apply(lambda s: np.pad(s, offset(s), mode='constant'))
    else:
        return series
    
# apply it to the matrix
dat_out   = dat_out.apply(extract_series)
dat_noout = dat_noout.apply(extract_series)

# %% [markdown]
# ## Training and Validation Strategy
#
# We then subsample the set into training, validation and test sets for evaluation.

# %%
from sklearn.model_selection import train_test_split

# set random state
RAND = 42
np.random.seed(RAND)
tf.random.set_seed(RAND)

# split training set
dat_out_train_80,   dat_out_test_80   = train_test_split(dat_out, train_size=0.8, shuffle=True, random_state=RAND)
dat_out_train_30,   dat_out_test_30   = train_test_split(dat_out, train_size=0.3, shuffle=True, random_state=RAND)
dat_noout_train_80, dat_noout_test_80 = train_test_split(dat_noout, train_size=0.8, shuffle=True, random_state=RAND)
dat_noout_train_30, dat_noout_test_30 = train_test_split(dat_noout, train_size=0.3, shuffle=True, random_state=RAND)

# split validation set
dat_out_val_80,   dat_out_test_80   = train_test_split(dat_out_test_80, train_size=0.5, shuffle=True, random_state=RAND)
dat_out_val_30,   dat_out_test_30   = train_test_split(dat_out_test_30, train_size=1/7, shuffle=True, random_state=RAND)
dat_noout_val_80, dat_noout_test_80 = train_test_split(dat_noout_test_80, train_size=0.5, shuffle=True, random_state=RAND)
dat_noout_val_30, dat_noout_test_30 = train_test_split(dat_noout_test_30, train_size=1/7, shuffle=True, random_state=RAND)

# check sizes
print('80% training data:')
print('    Training set w/ outliers:   {:.2f}%'.format(100 * dat_out_train_80.shape[0] / dat_out.shape[0]))
print('    Validation set w/ outliers: {:.2f}%'.format(100 * dat_out_val_80.shape[0] / dat_out.shape[0]))
print('    Test set w/ outliers:       {:.2f}%'.format(100 * dat_out_test_80.shape[0] / dat_out.shape[0]))
print('')
print('    Training set w/o outliers:   {:.2f}%'.format(100 * dat_noout_train_80.shape[0] / dat_noout.shape[0]))
print('    Validation set w/o outliers: {:.2f}%'.format(100 * dat_noout_val_80.shape[0] / dat_noout.shape[0]))
print('    Test set w/o outliers:       {:.2f}%'.format(100 * dat_noout_test_80.shape[0] / dat_noout.shape[0]))
print('')
print('30% training data:')
print('    Training set w/ outliers:   {:.2f}%'.format(100 * dat_out_train_30.shape[0] / dat_out.shape[0]))
print('    Validation set w/ outliers: {:.2f}%'.format(100 * dat_out_val_30.shape[0] / dat_out.shape[0]))
print('    Test set w/ outliers:       {:.2f}%'.format(100 * dat_out_test_30.shape[0] / dat_out.shape[0]))
print('')
print('    Training set w/o outliers:   {:.2f}%'.format(100 * dat_noout_train_30.shape[0] / dat_noout.shape[0]))
print('    Validation set w/o outliers: {:.2f}%'.format(100 * dat_noout_val_30.shape[0] / dat_noout.shape[0]))
print('    Test set w/o outliers:       {:.2f}%'.format(100 * dat_noout_test_30.shape[0] / dat_noout.shape[0]))
# Out:
# 80% training data:
#     Training set w/ outliers:   80.00%
#     Validation set w/ outliers: 10.00%
#     Test set w/ outliers:       10.00%
#
#     Training set w/o outliers:   79.99%
#     Validation set w/o outliers: 10.00%
#     Test set w/o outliers:       10.01%
#
# 30% training data:
#     Training set w/ outliers:   30.00%
#     Validation set w/ outliers: 10.00%
#     Test set w/ outliers:       60.00%
#
#     Training set w/o outliers:   30.00%
#     Validation set w/o outliers: 10.00%
#     Test set w/o outliers:       60.01%

# %% [markdown]
# # Input Visualisation (Training Set)
#
# We then want to visualise the input matrices for comparison with the output.

# %%
os.makedirs('img', exist_ok=True)

# %% [markdown]
# ## Random Samples
#
# We first visualise random samples in the training set (they must be scaled in the interval $[0,1]$):

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()

# normalisation factor (use the matrix w/o outliers to avoid getting an outlier)
max_train_entry = dat_noout_train_80['matrix'].apply(np.max).max()

ncols = 4
nrows = 4
_, ax = plt.subplots(nrows=nrows, ncols=ncols, figsize=(6 * ncols, 5 * nrows))

for i in range(nrows):
    for j in range(ncols):
        
        matrix = dat_noout_train_80['matrix'].\
                    iloc[np.random.randint(low=0,
                                           high=dat_noout_train_80.shape[0] - 1
                                          )
                        ]
        sns.heatmap(data=matrix / max_train_entry,
                    vmin=0.0,
                    vmax=1.0,
                    ax=ax[i,j],
                    cmap='Blues',
                    xticklabels=False,
                    yticklabels=False
                   )
        
plt.tight_layout()
plt.savefig('./img/train_samples_rnd.pdf', dpi=150, format='pdf')

# %% [markdown]
# ## Average Entries
#
# We then compute the average of all entries as a representative of the training set (first of all we scale the input and then take the mean value of each entry).

# %%
avg_mat = dat_noout_train_80['matrix'] / max_train_entry
avg_mat = avg_mat.mean()

_, ax = plt.subplots(1, 1, figsize=(6, 5))

sns.heatmap(data=avg_mat,
            vmin=0.0,
            vmax=1.0,
            ax=ax,
            cmap='Blues',
            xticklabels=False,
            yticklabels=False
           )
        
plt.tight_layout()
plt.savefig('./img/train_samples_avg.pdf', dpi=150, format='pdf')

# %% [markdown]
# # CNN Architectures
#
# We then study both a sequential CNN and the Inception-like CNN to analyse their feature maps.

# %%
# matrix
mat_out_train_80   = np.array(dat_out_train_80['matrix'].tolist()).reshape(-1, 12, 15, 1)
mat_noout_train_80 = np.array(dat_noout_train_80['matrix'].tolist()).reshape(-1, 12, 15, 1)
mat_out_train_30   = np.array(dat_out_train_30['matrix'].tolist()).reshape(-1, 12, 15, 1)
mat_noout_train_30 = np.array(dat_noout_train_30['matrix'].tolist()).reshape(-1, 12, 15, 1)

mat_out_val_80     = np.array(dat_out_val_80['matrix'].tolist()).reshape(-1, 12, 15, 1)
mat_noout_val_80   = np.array(dat_noout_val_80['matrix'].tolist()).reshape(-1, 12, 15, 1)
mat_out_val_30     = np.array(dat_out_val_30['matrix'].tolist()).reshape(-1, 12, 15, 1)
mat_noout_val_30   = np.array(dat_noout_val_30['matrix'].tolist()).reshape(-1, 12, 15, 1)

mat_out_test_80    = np.array(dat_out_test_80['matrix'].tolist()).reshape(-1, 12, 15, 1)
mat_noout_test_80  = np.array(dat_noout_test_80['matrix'].tolist()).reshape(-1, 12, 15, 1)
mat_out_test_30    = np.array(dat_out_test_30['matrix'].tolist()).reshape(-1, 12, 15, 1)
mat_noout_test_30  = np.array(dat_noout_test_30['matrix'].tolist()).reshape(-1, 12, 15, 1)

input_shape = (12, 15, 1)

# labels
lab_out_train_80 = {'h11_output': dat_out_train_80['h11'].values.reshape(-1,1),
                    'h21_output': dat_out_train_80['h21'].values.reshape(-1,1),
                   }
lab_noout_train_80 = {'h11_output': dat_noout_train_80['h11'].values.reshape(-1,1),
                      'h21_output': dat_noout_train_80['h21'].values.reshape(-1,1),
                     }
lab_out_train_30 = {'h11_output': dat_out_train_30['h11'].values.reshape(-1,1),
                    'h21_output': dat_out_train_30['h21'].values.reshape(-1,1),
                   }
lab_noout_train_30 = {'h11_output': dat_noout_train_30['h11'].values.reshape(-1,1),
                      'h21_output': dat_noout_train_30['h21'].values.reshape(-1,1),
                     }

lab_out_val_80   = {'h11_output': dat_out_val_80['h11'].values.reshape(-1,1),
                    'h21_output': dat_out_val_80['h21'].values.reshape(-1,1),
                   }
lab_noout_val_80   = {'h11_output': dat_noout_val_80['h11'].values.reshape(-1,1),
                      'h21_output': dat_noout_val_80['h21'].values.reshape(-1,1),
                     }
lab_out_val_30   = {'h11_output': dat_out_val_30['h11'].values.reshape(-1,1),
                    'h21_output': dat_out_val_30['h21'].values.reshape(-1,1),
                   }
lab_noout_val_30   = {'h11_output': dat_noout_val_30['h11'].values.reshape(-1,1),
                      'h21_output': dat_noout_val_30['h21'].values.reshape(-1,1),
                     }


lab_out_test_80   = {'h11_output': dat_out_test_80['h11'].values.reshape(-1,1),
                     'h21_output': dat_out_test_80['h21'].values.reshape(-1,1),
                    }
lab_noout_test_80   = {'h11_output': dat_noout_test_80['h11'].values.reshape(-1,1),
                       'h21_output': dat_noout_test_80['h21'].values.reshape(-1,1),
                      }
lab_out_test_30   = {'h11_output': dat_out_test_30['h11'].values.reshape(-1,1),
                     'h21_output': dat_out_test_30['h21'].values.reshape(-1,1),
                    }
lab_noout_test_30   = {'h11_output': dat_noout_test_30['h11'].values.reshape(-1,1),
                       'h21_output': dat_noout_test_30['h21'].values.reshape(-1,1),
                      }

# %%
# outdir
os.makedirs('./mod', exist_ok=True)

# %% [markdown]
# ## Inception CNN

# %%
from tensorflow import keras

def inc_model(input_shape,
              model_name='inception',
              learning_rate=0.001,
              filters=[32],
              kernel_size=[(3,3), (5,5)],
              dropout=0.2,
              momentum=0.99,
              l1_reg=0.0,
              l2_reg=0.0,
              rho=0.5
             ):
    
    # reset session
    keras.backend.clear_session()
    
    # define the regularisation factor
    kernel_regularizer = keras.regularizers.l1_l2(l1=l1_reg, l2=l2_reg)
    
    # input of the model
    I = keras.layers.Input(shape=input_shape, name=model_name + '_input')
    x = I
    
    # convolutional layers
    for n in range(len(filters)):
        a = keras.layers.Conv2D(filters=filters[n],
                                kernel_size=kernel_size[0],
                                padding='same',
                                kernel_regularizer=kernel_regularizer,
                                activation='relu',
                                name=model_name + '_convA_' + str(n+1)
                               )(x)
        b = keras.layers.Conv2D(filters=filters[n],
                                kernel_size=kernel_size[1],
                                padding='same',
                                kernel_regularizer=kernel_regularizer,
                                activation='relu',
                                name=model_name + '_convB_' + str(n+1)
                               )(x)
        x = keras.layers.concatenate([a, b], name=model_name + '_conc_' + str(n+1))
        if momentum > 0.0:
            x = keras.layers.BatchNormalization(momentum=momentum,
                                                name=model_name + '_bnorm_' + str(n+1)
                                               )(x)
    
    # dropout layer
    if dropout > 0.0:
        x = keras.layers.Dropout(rate=dropout, name=model_name + '_drop')(x)
        
    # flatten
    x = keras.layers.Flatten(name=model_name + '_flat')(x)
    
    # output
    h11 = keras.layers.Dense(units=1,
                             activation='relu',
                             name='h11_output'
                            )(x)
    h21 = keras.layers.Dense(units=1,
                             activation='relu',
                             name='h21_output'
                            )(x)
    
    # prepare dictionary
    output_layers = {}
    output_layers['h11_output'] = h11
    output_layers['h21_output'] = h21
    
    weights = {'h11_output': rho,
               'h21_output': 1 - rho
              }
    
    # define the model
    model = keras.models.Model(inputs=I, outputs=output_layers, name=model_name)
    model.compile(optimizer=keras.optimizers.Adam(learning_rate=learning_rate),
                  loss='mse',
                  loss_weights=weights,
                  metrics=['mse', 'mae']
                 )
    
    return model

# %% [markdown]
# We then define the model.

# %%
inception_line = inc_model(input_shape=input_shape,
                           model_name='inc_line',
                           learning_rate=0.001,
                           filters=[32, 64, 32],
                           kernel_size=[(12,1), (1,15)],
                           dropout=0.2,
                           l1_reg=1.0e-4,
                           l2_reg=1.0e-4,
                           rho=0.5
                          )
inception_square = inc_model(input_shape=input_shape,
                             model_name='inc_square',
                             learning_rate=0.001,
                             filters=[32, 64, 32],
                             kernel_size=[(3,3), (5,5)],
                             dropout=0.2,
                             l1_reg=1.0e-4,
                             l2_reg=1.0e-4,
                             rho=0.5
                            )

# %% [markdown]
# The model can be visualised using `keras` utility functions:

# %%
#from IPython.display import Image

inception_line_dot = keras.utils.model_to_dot(inception_line,
                                              show_shapes=True,
                                              dpi=150
                                             )
inception_line_dot.write_pdf('./img/inc_arch.pdf')
#Image(inception_line_dot.create_png(), width=480)

# %% [markdown]
# We then train the model.

# %%
os.makedirs('./dat', exist_ok=True)

# %% [markdown]
# ### 80% Training Data w/ Outliers (line kernel)

# %%
callbacks = [keras.callbacks.ModelCheckpoint('./mod/inception_line_out_80.h5',
                                             monitor='val_loss',
                                             verbose=0,
                                             save_best_only=True
                                            ),
             keras.callbacks.ReduceLROnPlateau(monitor='val_loss',
                                               factor=0.3,
                                               patience=80,
                                               verbose=0,
                                               min_lr=1.0e-6
                                              ),
             keras.callbacks.EarlyStopping(monitor='val_loss',
                                           patience=200,
                                           restore_best_weights=True,
                                           verbose=0
                                          )
            ]

print('Training 80% data w/ outliers (line kernel)')
inception_line.summary()

# define the model
inception_line = inc_model(input_shape=input_shape,
                           model_name='inc_line',
                           learning_rate=0.001,
                           filters=[32, 64, 32],
                           kernel_size=[(12,1), (1,15)],
                           dropout=0.2,
                           l1_reg=1.0e-4,
                           l2_reg=1.0e-4,
                           rho=0.5
                          )
inc_line_out_80 = inception_line.fit(x=mat_out_train_80,
                                     y=lab_out_train_80,
                                     batch_size=32,
                                     epochs=2000,
                                     verbose=0,
                                     callbacks=callbacks,
                                     validation_data=(mat_out_val_80, lab_out_val_80)
                                    )
# Out:
# Model: "inc_line"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# inc_line_input (InputLayer)     [(None, 12, 15, 1)]  0
# __________________________________________________________________________________________________
# inc_line_convA_1 (Conv2D)       (None, 12, 15, 32)   416         inc_line_input[0][0]
# __________________________________________________________________________________________________
# inc_line_convB_1 (Conv2D)       (None, 12, 15, 32)   512         inc_line_input[0][0]
# __________________________________________________________________________________________________
# inc_line_conc_1 (Concatenate)   (None, 12, 15, 64)   0           inc_line_convA_1[0][0]
#                                                                  inc_line_convB_1[0][0]
# __________________________________________________________________________________________________
# inc_line_bnorm_1 (BatchNormaliz (None, 12, 15, 64)   256         inc_line_conc_1[0][0]
# __________________________________________________________________________________________________
# inc_line_convA_2 (Conv2D)       (None, 12, 15, 64)   49216       inc_line_bnorm_1[0][0]
# __________________________________________________________________________________________________
# inc_line_convB_2 (Conv2D)       (None, 12, 15, 64)   61504       inc_line_bnorm_1[0][0]
# __________________________________________________________________________________________________
# inc_line_conc_2 (Concatenate)   (None, 12, 15, 128)  0           inc_line_convA_2[0][0]
#                                                                  inc_line_convB_2[0][0]
# __________________________________________________________________________________________________
# inc_line_bnorm_2 (BatchNormaliz (None, 12, 15, 128)  512         inc_line_conc_2[0][0]
# __________________________________________________________________________________________________
# inc_line_convA_3 (Conv2D)       (None, 12, 15, 32)   49184       inc_line_bnorm_2[0][0]
# __________________________________________________________________________________________________
# inc_line_convB_3 (Conv2D)       (None, 12, 15, 32)   61472       inc_line_bnorm_2[0][0]
# __________________________________________________________________________________________________
# inc_line_conc_3 (Concatenate)   (None, 12, 15, 64)   0           inc_line_convA_3[0][0]
#                                                                  inc_line_convB_3[0][0]
# __________________________________________________________________________________________________
# inc_line_bnorm_3 (BatchNormaliz (None, 12, 15, 64)   256         inc_line_conc_3[0][0]
# __________________________________________________________________________________________________
# inc_line_drop (Dropout)         (None, 12, 15, 64)   0           inc_line_bnorm_3[0][0]
# __________________________________________________________________________________________________
# inc_line_flat (Flatten)         (None, 11520)        0           inc_line_drop[0][0]
# __________________________________________________________________________________________________
# h11_output (Dense)              (None, 1)            11521       inc_line_flat[0][0]
# __________________________________________________________________________________________________
# h21_output (Dense)              (None, 1)            11521       inc_line_flat[0][0]
# ==================================================================================================
# Total params: 246,370
# Trainable params: 245,858
# Non-trainable params: 512
# __________________________________________________________________________________________________
# Epoch 1/2000
# 198/198 [==============================] - ETA: 0s - loss: 24.1097 - h11_output_loss: 3.9261 - h21_output_loss: 42.9748 - h11_output_mse: 3.9261 - h11_output_mae: 1.4446 - h21_output_mse: 42.9748 - h21_output_mae: 4.3829
# Epoch 00001: val_loss improved from inf to 67.48760, saving model to ./mod/inception_line_out_80.h5
# 198/198 [==============================] - 1s 7ms/step - loss: 24.1097 - h11_output_loss: 3.9261 - h21_output_loss: 42.9748 - h11_output_mse: 3.9261 - h11_output_mae: 1.4446 - h21_output_mse: 42.9748 - h21_output_mae: 4.3829 - val_loss: 67.4876 - val_h11_output_loss: 61.2750 - val_h21_output_loss: 72.3710 - val_h11_output_mse: 61.2750 - val_h11_output_mae: 7.4626 - val_h21_output_mse: 72.3710 - val_h21_output_mae: 5.7288 - lr: 0.0010
# Epoch 2/2000
# 194/198 [============================>.] - ETA: 0s - loss: 13.3826 - h11_output_loss: 2.6400 - h21_output_loss: 22.7875 - h11_output_mse: 2.6400 - h11_output_mae: 1.1981 - h21_output_mse: 22.7875 - h21_output_mae: 3.3217
# Epoch 00002: val_loss improved from 67.48760 to 38.58665, saving model to ./mod/inception_line_out_80.h5
# 198/198 [==============================] - 1s 5ms/step - loss: 13.3498 - h11_output_loss: 2.6322 - h21_output_loss: 22.7295 - h11_output_mse: 2.6322 - h11_output_mae: 1.1972 - h21_output_mse: 22.7295 - h21_output_mae: 3.3213 - val_loss: 38.5866 - val_h11_output_loss: 30.9895 - val_h21_output_loss: 44.8351 - val_h11_output_mse: 30.9895 - val_h11_output_mae: 5.2519 - val_h21_output_mse: 44.8351 - val_h21_output_mae: 4.8095 - lr: 0.0010
# Epoch 3/2000
# 195/198 [============================>.] - ETA: 0s - loss: 9.3612 - h11_output_loss: 1.9585 - h21_output_loss: 15.4053 - h11_output_mse: 1.9585 - h11_output_mae: 1.0063 - h21_output_mse: 15.4053 - h21_output_mae: 2.7790
# Epoch 00003: val_loss improved from 38.58665 to 21.98930, saving model to ./mod/inception_line_out_80.h5
# 198/198 [==============================] - 1s 5ms/step - loss: 9.3458 - h11_output_loss: 1.9540 - h21_output_loss: 15.3790 - h11_output_mse: 1.9540 - h11_output_mae: 1.0065 - h21_output_mse: 15.3790 - h21_output_mae: 2.7783 - val_loss: 21.9893 - val_h11_output_loss: 5.1240 - val_h21_output_loss: 37.4858 - val_h11_output_mse: 5.1240 - val_h11_output_mae: 1.8224 - val_h21_output_mse: 37.4858 - val_h21_output_mae: 5.1608 - lr: 0.0010
# Epoch 4/2000
# 190/198 [===========================>..] - ETA: 0s - loss: 6.9887 - h11_output_loss: 1.8601 - h21_output_loss: 10.7405 - h11_output_mse: 1.8601 - h11_output_mae: 0.9923 - h21_output_mse: 10.7405 - h21_output_mae: 2.3787
# Epoch 00004: val_loss improved from 21.98930 to 7.81400, saving model to ./mod/inception_line_out_80.h5
# 198/198 [==============================] - 1s 5ms/step - loss: 7.0086 - h11_output_loss: 1.8804 - h21_output_loss: 10.7598 - h11_output_mse: 1.8804 - h11_output_mae: 0.9905 - h21_output_mse: 10.7598 - h21_output_mae: 2.3793 - val_loss: 7.8140 - val_h11_output_loss: 1.8182 - val_h21_output_loss: 12.4256 - val_h11_output_mse: 1.8182 - val_h11_output_mae: 0.8180 - val_h21_output_mse: 12.4256 - val_h21_output_mae: 2.3721 - lr: 0.0010
# Epoch 5/2000
# 188/198 [===========================>..] - ETA: 0s - loss: 5.7486 - h11_output_loss: 1.6990 - h21_output_loss: 8.4071 - h11_output_mse: 1.6990 - h11_output_mae: 0.9522 - h21_output_mse: 8.4071 - h21_output_mae: 2.1159
# Epoch 00005: val_loss did not improve from 7.81400
# 198/198 [==============================] - 1s 5ms/step - loss: 5.7708 - h11_output_loss: 1.7175 - h21_output_loss: 8.4327 - h11_output_mse: 1.7175 - h11_output_mae: 0.9572 - h21_output_mse: 8.4327 - h21_output_mae: 2.1094 - val_loss: 9.0433 - val_h11_output_loss: 1.5200 - val_h21_output_loss: 15.1693 - val_h11_output_mse: 1.5200 - val_h11_output_mae: 0.8025 - val_h21_output_mse: 15.1693 - val_h21_output_mae: 3.0696 - lr: 0.0010
# Epoch 6/2000
# 193/198 [============================>.] - ETA: 0s - loss: 5.4277 - h11_output_loss: 1.5159 - h21_output_loss: 7.9360 - h11_output_mse: 1.5159 - h11_output_mae: 0.8876 - h21_output_mse: 7.9360 - h21_output_mae: 2.1104
# Epoch 00006: val_loss improved from 7.81400 to 7.73604, saving model to ./mod/inception_line_out_80.h5
# 198/198 [==============================] - 1s 5ms/step - loss: 5.4337 - h11_output_loss: 1.5043 - h21_output_loss: 7.9593 - h11_output_mse: 1.5043 - h11_output_mae: 0.8863 - h21_output_mse: 7.9593 - h21_output_mae: 2.1113 - val_loss: 7.7360 - val_h11_output_loss: 1.7025 - val_h21_output_loss: 12.3584 - val_h11_output_mse: 1.7025 - val_h11_output_mae: 0.7858 - val_h21_output_mse: 12.3584 - val_h21_output_mae: 2.1640 - lr: 0.0010
# Epoch 7/2000
# 193/198 [============================>.] - ETA: 0s - loss: 4.4831 - h11_output_loss: 1.2749 - h21_output_loss: 6.2748 - h11_output_mse: 1.2749 - h11_output_mae: 0.8192 - h21_output_mse: 6.2748 - h21_output_mae: 1.8763
# Epoch 00007: val_loss improved from 7.73604 to 6.22869, saving model to ./mod/inception_line_out_80.h5
# 198/198 [==============================] - 1s 5ms/step - loss: 4.4755 - h11_output_loss: 1.2695 - h21_output_loss: 6.2650 - h11_output_mse: 1.2695 - h11_output_mae: 0.8184 - h21_output_mse: 6.2650 - h21_output_mae: 1.8722 - val_loss: 6.2287 - val_h11_output_loss: 1.7487 - val_h21_output_loss: 9.2868 - val_h11_output_mse: 1.7487 - val_h11_output_mae: 0.7979 - val_h21_output_mse: 9.2868 - val_h21_output_mae: 1.9373 - lr: 0.0010
# Epoch 8/2000
# 190/198 [===========================>..] - ETA: 0s - loss: 4.0560 - h11_output_loss: 1.2113 - h21_output_loss: 5.4729 - h11_output_mse: 1.2113 - h11_output_mae: 0.7880 - h21_output_mse: 5.4729 - h21_output_mae: 1.7129
# Epoch 00008: val_loss did not improve from 6.22869
# 198/198 [==============================] - 1s 5ms/step - loss: 4.0392 - h11_output_loss: 1.2044 - h21_output_loss: 5.4462 - h11_output_mse: 1.2044 - h11_output_mae: 0.7862 - h21_output_mse: 5.4462 - h21_output_mae: 1.7123 - val_loss: 6.9179 - val_h11_output_loss: 1.7517 - val_h21_output_loss: 10.6527 - val_h11_output_mse: 1.7517 - val_h11_output_mae: 0.8461 - val_h21_output_mse: 10.6527 - val_h21_output_mae: 2.5947 - lr: 0.0010
# Epoch 9/2000
# 190/198 [===========================>..] - ETA: 0s - loss: 3.5475 - h11_output_loss: 0.9092 - h21_output_loss: 4.7525 - h11_output_mse: 0.9092 - h11_output_mae: 0.7028 - h21_output_mse: 4.7525 - h21_output_mae: 1.6326
# Epoch 00009: val_loss improved from 6.22869 to 5.90356, saving model to ./mod/inception_line_out_80.h5
# 198/198 [==============================] - 1s 5ms/step - loss: 3.6333 - h11_output_loss: 0.9358 - h21_output_loss: 4.8974 - h11_output_mse: 0.9358 - h11_output_mae: 0.7066 - h21_output_mse: 4.8974 - h21_output_mae: 1.6459 - val_loss: 5.9036 - val_h11_output_loss: 1.4045 - val_h21_output_loss: 8.9653 - val_h11_output_mse: 1.4045 - val_h11_output_mae: 0.8263 - val_h21_output_mse: 8.9653 - val_h21_output_mae: 2.0261 - lr: 0.0010
# Epoch 10/2000
# 198/198 [==============================] - ETA: 0s - loss: 4.2151 - h11_output_loss: 1.1322 - h21_output_loss: 5.8442 - h11_output_mse: 1.1322 - h11_output_mae: 0.7734 - h21_output_mse: 5.8442 - h21_output_mae: 1.7653
# Epoch 00010: val_loss did not improve from 5.90356
# 198/198 [==============================] - 1s 5ms/step - loss: 4.2151 - h11_output_loss: 1.1322 - h21_output_loss: 5.8442 - h11_output_mse: 1.1322 - h11_output_mae: 0.7734 - h21_output_mse: 5.8442 - h21_output_mae: 1.7653 - val_loss: 9.4601 - val_h11_output_loss: 1.3989 - val_h21_output_loss: 16.0624 - val_h11_output_mse: 1.3989 - val_h11_output_mae: 0.7129 - val_h21_output_mse: 16.0624 - val_h21_output_mae: 3.3813 - lr: 0.0010
# Epoch 11/2000
# 190/198 [===========================>..] - ETA: 0s - loss: 3.3609 - h11_output_loss: 0.9292 - h21_output_loss: 4.3301 - h11_output_mse: 0.9292 - h11_output_mae: 0.7079 - h21_output_mse: 4.3301 - h21_output_mae: 1.5391
# Epoch 00011: val_loss improved from 5.90356 to 5.30929, saving model to ./mod/inception_line_out_80.h5
# 198/198 [==============================] - 1s 5ms/step - loss: 3.3843 - h11_output_loss: 0.9341 - h21_output_loss: 4.3720 - h11_output_mse: 0.9341 - h11_output_mae: 0.7113 - h21_output_mse: 4.3720 - h21_output_mae: 1.5519 - val_loss: 5.3093 - val_h11_output_loss: 1.8754 - val_h21_output_loss: 7.2767 - val_h11_output_mse: 1.8754 - val_h11_output_mae: 0.8257 - val_h21_output_mse: 7.2767 - val_h21_output_mae: 1.8050 - lr: 0.0010
# Epoch 12/2000
# 191/198 [===========================>..] - ETA: 0s - loss: 3.2635 - h11_output_loss: 0.8643 - h21_output_loss: 4.1943 - h11_output_mse: 0.8643 - h11_output_mae: 0.6869 - h21_output_mse: 4.1943 - h21_output_mae: 1.5221
# Epoch 00012: val_loss did not improve from 5.30929
# 198/198 [==============================] - 1s 5ms/step - loss: 3.2533 - h11_output_loss: 0.8673 - h21_output_loss: 4.1706 - h11_output_mse: 0.8673 - h11_output_mae: 0.6881 - h21_output_mse: 4.1706 - h21_output_mae: 1.5200 - val_loss: 6.3682 - val_h11_output_loss: 1.2738 - val_h21_output_loss: 9.9877 - val_h11_output_mse: 1.2738 - val_h11_output_mae: 0.7258 - val_h21_output_mse: 9.9877 - val_h21_output_mae: 2.2046 - lr: 0.0010
# Epoch 13/2000
# 196/198 [============================>.] - ETA: 0s - loss: 3.2845 - h11_output_loss: 0.8888 - h21_output_loss: 4.2023 - h11_output_mse: 0.8888 - h11_output_mae: 0.7096 - h21_output_mse: 4.2023 - h21_output_mae: 1.5308
# Epoch 00013: val_loss improved from 5.30929 to 4.77566, saving model to ./mod/inception_line_out_80.h5
# 198/198 [==============================] - 1s 5ms/step - loss: 3.2808 - h11_output_loss: 0.8897 - h21_output_loss: 4.1941 - h11_output_mse: 0.8897 - h11_output_mae: 0.7105 - h21_output_mse: 4.1941 - h21_output_mae: 1.5295 - val_loss: 4.7757 - val_h11_output_loss: 1.3689 - val_h21_output_loss: 6.6987 - val_h11_output_mse: 1.3689 - val_h11_output_mae: 0.8239 - val_h21_output_mse: 6.6987 - val_h21_output_mae: 1.7479 - lr: 0.0010
# Epoch 14/2000
# 191/198 [===========================>..] - ETA: 0s - loss: 2.6737 - h11_output_loss: 0.7443 - h21_output_loss: 3.1191 - h11_output_mse: 0.7443 - h11_output_mae: 0.6574 - h21_output_mse: 3.1191 - h21_output_mae: 1.3311
# Epoch 00014: val_loss did not improve from 4.77566
# 198/198 [==============================] - 1s 5ms/step - loss: 2.6722 - h11_output_loss: 0.7434 - h21_output_loss: 3.1169 - h11_output_mse: 0.7434 - h11_output_mae: 0.6571 - h21_output_mse: 3.1169 - h21_output_mae: 1.3289 - val_loss: 6.1358 - val_h11_output_loss: 1.2971 - val_h21_output_loss: 9.4909 - val_h11_output_mse: 1.2971 - val_h11_output_mae: 0.7555 - val_h21_output_mse: 9.4909 - val_h21_output_mae: 2.3201 - lr: 0.0010
# Epoch 15/2000
# 192/198 [============================>.] - ETA: 0s - loss: 2.6407 - h11_output_loss: 0.6725 - h21_output_loss: 3.1244 - h11_output_mse: 0.6725 - h11_output_mae: 0.6177 - h21_output_mse: 3.1244 - h21_output_mae: 1.3534
# Epoch 00015: val_loss did not improve from 4.77566
# 198/198 [==============================] - 1s 5ms/step - loss: 2.6473 - h11_output_loss: 0.6667 - h21_output_loss: 3.1433 - h11_output_mse: 0.6667 - h11_output_mae: 0.6152 - h21_output_mse: 3.1433 - h21_output_mae: 1.3533 - val_loss: 6.0968 - val_h11_output_loss: 1.0941 - val_h21_output_loss: 9.6144 - val_h11_output_mse: 1.0941 - val_h11_output_mae: 0.6859 - val_h21_output_mse: 9.6144 - val_h21_output_mae: 2.2938 - lr: 0.0010
# Epoch 16/2000
# 193/198 [============================>.] - ETA: 0s - loss: 2.6271 - h11_output_loss: 0.6923 - h21_output_loss: 3.0753 - h11_output_mse: 0.6923 - h11_output_mae: 0.6161 - h21_output_mse: 3.0753 - h21_output_mae: 1.3406
# Epoch 00016: val_loss improved from 4.77566 to 3.44687, saving model to ./mod/inception_line_out_80.h5
# 198/198 [==============================] - 1s 5ms/step - loss: 2.6238 - h11_output_loss: 0.6948 - h21_output_loss: 3.0661 - h11_output_mse: 0.6948 - h11_output_mae: 0.6165 - h21_output_mse: 3.0661 - h21_output_mae: 1.3369 - val_loss: 3.4469 - val_h11_output_loss: 1.3697 - val_h21_output_loss: 4.0371 - val_h11_output_mse: 1.3697 - val_h11_output_mae: 0.9019 - val_h21_output_mse: 4.0371 - val_h21_output_mae: 1.3411 - lr: 0.0010
# Epoch 17/2000
# 194/198 [============================>.] - ETA: 0s - loss: 2.9958 - h11_output_loss: 0.5800 - h21_output_loss: 3.9150 - h11_output_mse: 0.5800 - h11_output_mae: 0.5706 - h21_output_mse: 3.9150 - h21_output_mae: 1.5145
# Epoch 00017: val_loss improved from 3.44687 to 3.31821, saving model to ./mod/inception_line_out_80.h5
# 198/198 [==============================] - 1s 5ms/step - loss: 2.9871 - h11_output_loss: 0.5818 - h21_output_loss: 3.8958 - h11_output_mse: 0.5818 - h11_output_mae: 0.5698 - h21_output_mse: 3.8958 - h21_output_mae: 1.5107 - val_loss: 3.3182 - val_h11_output_loss: 0.9006 - val_h21_output_loss: 4.2371 - val_h11_output_mse: 0.9006 - val_h11_output_mae: 0.5826 - val_h21_output_mse: 4.2371 - val_h21_output_mae: 1.3376 - lr: 0.0010
# Epoch 18/2000
# 191/198 [===========================>..] - ETA: 0s - loss: 2.4040 - h11_output_loss: 0.5777 - h21_output_loss: 2.7325 - h11_output_mse: 0.5777 - h11_output_mae: 0.5852 - h21_output_mse: 2.7325 - h21_output_mae: 1.2634
# Epoch 00018: val_loss did not improve from 3.31821
# 198/198 [==============================] - 1s 5ms/step - loss: 2.3958 - h11_output_loss: 0.5769 - h21_output_loss: 2.7169 - h11_output_mse: 0.5769 - h11_output_mae: 0.5840 - h21_output_mse: 2.7169 - h21_output_mae: 1.2567 - val_loss: 3.6336 - val_h11_output_loss: 1.0841 - val_h21_output_loss: 4.6868 - val_h11_output_mse: 1.0841 - val_h11_output_mae: 0.7428 - val_h21_output_mse: 4.6868 - val_h21_output_mae: 1.4749 - lr: 0.0010
# Epoch 19/2000
# 189/198 [===========================>..] - ETA: 0s - loss: 2.2964 - h11_output_loss: 0.5797 - h21_output_loss: 2.5170 - h11_output_mse: 0.5797 - h11_output_mae: 0.5759 - h21_output_mse: 2.5170 - h21_output_mae: 1.1949
# Epoch 00019: val_loss did not improve from 3.31821
# 198/198 [==============================] - 1s 5ms/step - loss: 2.3157 - h11_output_loss: 0.5796 - h21_output_loss: 2.5558 - h11_output_mse: 0.5796 - h11_output_mae: 0.5773 - h21_output_mse: 2.5558 - h21_output_mae: 1.2066 - val_loss: 3.6763 - val_h11_output_loss: 1.3896 - val_h21_output_loss: 4.4667 - val_h11_output_mse: 1.3896 - val_h11_output_mae: 0.8242 - val_h21_output_mse: 4.4667 - val_h21_output_mae: 1.3907 - lr: 0.0010
# Epoch 20/2000
# 189/198 [===========================>..] - ETA: 0s - loss: 2.3287 - h11_output_loss: 0.5845 - h21_output_loss: 2.5758 - h11_output_mse: 0.5845 - h11_output_mae: 0.5819 - h21_output_mse: 2.5758 - h21_output_mae: 1.2010
# Epoch 00020: val_loss did not improve from 3.31821
# 198/198 [==============================] - 1s 5ms/step - loss: 2.3543 - h11_output_loss: 0.5864 - h21_output_loss: 2.6249 - h11_output_mse: 0.5864 - h11_output_mae: 0.5837 - h21_output_mse: 2.6249 - h21_output_mae: 1.2125 - val_loss: 4.4765 - val_h11_output_loss: 0.9981 - val_h21_output_loss: 6.4545 - val_h11_output_mse: 0.9981 - val_h11_output_mae: 0.5778 - val_h21_output_mse: 6.4545 - val_h21_output_mae: 1.5403 - lr: 0.0010
# Epoch 21/2000
# 190/198 [===========================>..] - ETA: 0s - loss: 2.6950 - h11_output_loss: 0.6459 - h21_output_loss: 3.2358 - h11_output_mse: 0.6459 - h11_output_mae: 0.6087 - h21_output_mse: 3.2358 - h21_output_mae: 1.3499
# Epoch 00021: val_loss did not improve from 3.31821
# 198/198 [==============================] - 1s 5ms/step - loss: 2.6754 - h11_output_loss: 0.6394 - h21_output_loss: 3.2031 - h11_output_mse: 0.6394 - h11_output_mae: 0.6057 - h21_output_mse: 3.2031 - h21_output_mae: 1.3443 - val_loss: 3.4216 - val_h11_output_loss: 0.9875 - val_h21_output_loss: 4.3391 - val_h11_output_mse: 0.9875 - val_h11_output_mae: 0.6187 - val_h21_output_mse: 4.3391 - val_h21_output_mae: 1.4995 - lr: 0.0010
# Epoch 22/2000
# 191/198 [===========================>..] - ETA: 0s - loss: 2.3231 - h11_output_loss: 0.5936 - h21_output_loss: 2.5348 - h11_output_mse: 0.5936 - h11_output_mae: 0.5821 - h21_output_mse: 2.5348 - h21_output_mae: 1.2015
# Epoch 00022: val_loss did not improve from 3.31821
# 198/198 [==============================] - 1s 5ms/step - loss: 2.3149 - h11_output_loss: 0.5954 - h21_output_loss: 2.5167 - h11_output_mse: 0.5954 - h11_output_mae: 0.5820 - h21_output_mse: 2.5167 - h21_output_mae: 1.1952 - val_loss: 3.4358 - val_h11_output_loss: 1.2897 - val_h21_output_loss: 4.0657 - val_h11_output_mse: 1.2897 - val_h11_output_mae: 0.7998 - val_h21_output_mse: 4.0657 - val_h21_output_mae: 1.3976 - lr: 0.0010
# Epoch 23/2000
# 193/198 [============================>.] - ETA: 0s - loss: 2.6013 - h11_output_loss: 0.6248 - h21_output_loss: 3.0537 - h11_output_mse: 0.6248 - h11_output_mae: 0.5830 - h21_output_mse: 3.0537 - h21_output_mae: 1.3097
# Epoch 00023: val_loss did not improve from 3.31821
# 198/198 [==============================] - 1s 5ms/step - loss: 2.5969 - h11_output_loss: 0.6268 - h21_output_loss: 3.0428 - h11_output_mse: 0.6268 - h11_output_mae: 0.5829 - h21_output_mse: 3.0428 - h21_output_mae: 1.3097 - val_loss: 4.0087 - val_h11_output_loss: 0.9560 - val_h21_output_loss: 5.5289 - val_h11_output_mse: 0.9560 - val_h11_output_mae: 0.5665 - val_h21_output_mse: 5.5289 - val_h21_output_mae: 1.6243 - lr: 0.0010
# Epoch 24/2000
# 192/198 [============================>.] - ETA: 0s - loss: 2.5637 - h11_output_loss: 0.7902 - h21_output_loss: 2.8028 - h11_output_mse: 0.7902 - h11_output_mae: 0.6514 - h21_output_mse: 2.8028 - h21_output_mae: 1.2646
# Epoch 00024: val_loss did not improve from 3.31821
# 198/198 [==============================] - 1s 5ms/step - loss: 2.5670 - h11_output_loss: 0.7893 - h21_output_loss: 2.8100 - h11_output_mse: 0.7893 - h11_output_mae: 0.6526 - h21_output_mse: 2.8100 - h21_output_mae: 1.2680 - val_loss: 3.4015 - val_h11_output_loss: 1.1566 - val_h21_output_loss: 4.1064 - val_h11_output_mse: 1.1566 - val_h11_output_mae: 0.7999 - val_h21_output_mse: 4.1064 - val_h21_output_mae: 1.3376 - lr: 0.0010
# Epoch 25/2000
# 193/198 [============================>.] - ETA: 0s - loss: 2.0171 - h11_output_loss: 0.5546 - h21_output_loss: 1.9445 - h11_output_mse: 0.5546 - h11_output_mae: 0.5640 - h21_output_mse: 1.9445 - h21_output_mae: 1.0441
# Epoch 00025: val_loss did not improve from 3.31821
# 198/198 [==============================] - 1s 5ms/step - loss: 2.0121 - h11_output_loss: 0.5536 - h21_output_loss: 1.9356 - h11_output_mse: 0.5536 - h11_output_mae: 0.5629 - h21_output_mse: 1.9356 - h21_output_mae: 1.0423 - val_loss: 3.7832 - val_h11_output_loss: 1.2869 - val_h21_output_loss: 4.7482 - val_h11_output_mse: 1.2869 - val_h11_output_mae: 0.8636 - val_h21_output_mse: 4.7482 - val_h21_output_mae: 1.4792 - lr: 0.0010
# Epoch 26/2000
# 191/198 [===========================>..] - ETA: 0s - loss: 2.1122 - h11_output_loss: 0.5087 - h21_output_loss: 2.1851 - h11_output_mse: 0.5087 - h11_output_mae: 0.5522 - h21_output_mse: 2.1851 - h21_output_mae: 1.1164
# Epoch 00026: val_loss improved from 3.31821 to 3.09135, saving model to ./mod/inception_line_out_80.h5
# 198/198 [==============================] - 1s 5ms/step - loss: 2.1058 - h11_output_loss: 0.5056 - h21_output_loss: 2.1755 - h11_output_mse: 0.5056 - h11_output_mae: 0.5508 - h21_output_mse: 2.1755 - h21_output_mae: 1.1150 - val_loss: 3.0913 - val_h11_output_loss: 0.5384 - val_h21_output_loss: 4.1179 - val_h11_output_mse: 0.5384 - val_h11_output_mae: 0.4458 - val_h21_output_mse: 4.1179 - val_h21_output_mae: 1.4983 - lr: 0.0010
# Epoch 27/2000
# 191/198 [===========================>..] - ETA: 0s - loss: 2.0468 - h11_output_loss: 0.4545 - h21_output_loss: 2.1152 - h11_output_mse: 0.4545 - h11_output_mae: 0.5131 - h21_output_mse: 2.1152 - h21_output_mae: 1.0950
# Epoch 00027: val_loss improved from 3.09135 to 2.72133, saving model to ./mod/inception_line_out_80.h5
# 198/198 [==============================] - 1s 5ms/step - loss: 2.0536 - h11_output_loss: 0.4530 - h21_output_loss: 2.1303 - h11_output_mse: 0.4530 - h11_output_mae: 0.5130 - h21_output_mse: 2.1303 - h21_output_mae: 1.0992 - val_loss: 2.7213 - val_h11_output_loss: 0.6733 - val_h21_output_loss: 3.2458 - val_h11_output_mse: 0.6733 - val_h11_output_mae: 0.5602 - val_h21_output_mse: 3.2458 - val_h21_output_mae: 1.2472 - lr: 0.0010
# Epoch 28/2000
# 192/198 [============================>.] - ETA: 0s - loss: 2.2112 - h11_output_loss: 0.4736 - h21_output_loss: 2.4232 - h11_output_mse: 0.4736 - h11_output_mae: 0.5295 - h21_output_mse: 2.4232 - h21_output_mae: 1.1932
# Epoch 00028: val_loss did not improve from 2.72133
# 198/198 [==============================] - 1s 5ms/step - loss: 2.2064 - h11_output_loss: 0.4867 - h21_output_loss: 2.4004 - h11_output_mse: 0.4867 - h11_output_mae: 0.5373 - h21_output_mse: 2.4004 - h21_output_mae: 1.1876 - val_loss: 3.0171 - val_h11_output_loss: 1.6686 - val_h21_output_loss: 2.8374 - val_h11_output_mse: 1.6686 - val_h11_output_mae: 1.0443 - val_h21_output_mse: 2.8374 - val_h21_output_mae: 1.1419 - lr: 0.0010
# Epoch 29/2000
# 193/198 [============================>.] - ETA: 0s - loss: 1.9812 - h11_output_loss: 0.4579 - h21_output_loss: 1.9788 - h11_output_mse: 0.4579 - h11_output_mae: 0.5160 - h21_output_mse: 1.9788 - h21_output_mae: 1.0413
# Epoch 00029: val_loss improved from 2.72133 to 2.63251, saving model to ./mod/inception_line_out_80.h5
# 198/198 [==============================] - 1s 5ms/step - loss: 1.9821 - h11_output_loss: 0.4554 - h21_output_loss: 1.9830 - h11_output_mse: 0.4554 - h11_output_mae: 0.5144 - h21_output_mse: 1.9830 - h21_output_mae: 1.0445 - val_loss: 2.6325 - val_h11_output_loss: 0.9392 - val_h21_output_loss: 2.8029 - val_h11_output_mse: 0.9392 - val_h11_output_mae: 0.6938 - val_h21_output_mse: 2.8029 - val_h21_output_mae: 1.1430 - lr: 0.0010
# Epoch 30/2000
# 192/198 [============================>.] - ETA: 0s - loss: 2.1007 - h11_output_loss: 0.5260 - h21_output_loss: 2.1490 - h11_output_mse: 0.5260 - h11_output_mae: 0.5466 - h21_output_mse: 2.1490 - h21_output_mae: 1.1173
# Epoch 00030: val_loss did not improve from 2.63251
# 198/198 [==============================] - 1s 5ms/step - loss: 2.0962 - h11_output_loss: 0.5313 - h21_output_loss: 2.1346 - h11_output_mse: 0.5313 - h11_output_mae: 0.5495 - h21_output_mse: 2.1346 - h21_output_mae: 1.1138 - val_loss: 2.9940 - val_h11_output_loss: 1.5442 - val_h21_output_loss: 2.9175 - val_h11_output_mse: 1.5442 - val_h11_output_mae: 0.8474 - val_h21_output_mse: 2.9175 - val_h21_output_mae: 1.1561 - lr: 0.0010
# Epoch 31/2000
# 191/198 [===========================>..] - ETA: 0s - loss: 2.0601 - h11_output_loss: 0.5214 - h21_output_loss: 2.0733 - h11_output_mse: 0.5214 - h11_output_mae: 0.5400 - h21_output_mse: 2.0733 - h21_output_mae: 1.0899
# Epoch 00031: val_loss did not improve from 2.63251
# 198/198 [==============================] - 1s 5ms/step - loss: 2.0692 - h11_output_loss: 0.5178 - h21_output_loss: 2.0952 - h11_output_mse: 0.5178 - h11_output_mae: 0.5390 - h21_output_mse: 2.0952 - h21_output_mae: 1.0962 - val_loss: 3.1368 - val_h11_output_loss: 0.7922 - val_h21_output_loss: 3.9537 - val_h11_output_mse: 0.7922 - val_h11_output_mae: 0.5070 - val_h21_output_mse: 3.9537 - val_h21_output_mae: 1.3251 - lr: 0.0010
# Epoch 32/2000
# 193/198 [============================>.] - ETA: 0s - loss: 2.3172 - h11_output_loss: 0.4272 - h21_output_loss: 2.6647 - h11_output_mse: 0.4272 - h11_output_mae: 0.4929 - h21_output_mse: 2.6647 - h21_output_mae: 1.2017
# Epoch 00032: val_loss did not improve from 2.63251
# 198/198 [==============================] - 1s 5ms/step - loss: 2.3103 - h11_output_loss: 0.4298 - h21_output_loss: 2.6481 - h11_output_mse: 0.4298 - h11_output_mae: 0.4936 - h21_output_mse: 2.6481 - h21_output_mae: 1.1993 - val_loss: 3.7327 - val_h11_output_loss: 0.6404 - val_h21_output_loss: 5.2720 - val_h11_output_mse: 0.6404 - val_h11_output_mae: 0.4580 - val_h21_output_mse: 5.2720 - val_h21_output_mae: 1.6997 - lr: 0.0010
# Epoch 33/2000
# 192/198 [============================>.] - ETA: 0s - loss: 2.2953 - h11_output_loss: 0.5858 - h21_output_loss: 2.4464 - h11_output_mse: 0.5858 - h11_output_mae: 0.5372 - h21_output_mse: 2.4464 - h21_output_mae: 1.1622
# Epoch 00033: val_loss did not improve from 2.63251
# 198/198 [==============================] - 1s 5ms/step - loss: 2.2824 - h11_output_loss: 0.5789 - h21_output_loss: 2.4273 - h11_output_mse: 0.5789 - h11_output_mae: 0.5349 - h21_output_mse: 2.4273 - h21_output_mae: 1.1585 - val_loss: 6.7534 - val_h11_output_loss: 0.8569 - val_h21_output_loss: 11.0845 - val_h11_output_mse: 0.8569 - val_h11_output_mae: 0.5705 - val_h21_output_mse: 11.0845 - val_h21_output_mae: 2.7885 - lr: 0.0010
# Epoch 34/2000
# 191/198 [===========================>..] - ETA: 0s - loss: 2.1075 - h11_output_loss: 0.4050 - h21_output_loss: 2.2430 - h11_output_mse: 0.4050 - h11_output_mae: 0.4795 - h21_output_mse: 2.2430 - h21_output_mae: 1.1548
# Epoch 00034: val_loss did not improve from 2.63251
# 198/198 [==============================] - 1s 5ms/step - loss: 2.0956 - h11_output_loss: 0.4058 - h21_output_loss: 2.2184 - h11_output_mse: 0.4058 - h11_output_mae: 0.4810 - h21_output_mse: 2.2184 - h21_output_mae: 1.1474 - val_loss: 3.4177 - val_h11_output_loss: 0.6899 - val_h21_output_loss: 4.5823 - val_h11_output_mse: 0.6899 - val_h11_output_mae: 0.5277 - val_h21_output_mse: 4.5823 - val_h21_output_mae: 1.6174 - lr: 0.0010
# Epoch 35/2000
# 189/198 [===========================>..] - ETA: 0s - loss: 1.8540 - h11_output_loss: 0.4209 - h21_output_loss: 1.7316 - h11_output_mse: 0.4209 - h11_output_mae: 0.4913 - h21_output_mse: 1.7316 - h21_output_mae: 1.0103
# Epoch 00035: val_loss did not improve from 2.63251
# 198/198 [==============================] - 1s 5ms/step - loss: 1.8545 - h11_output_loss: 0.4230 - h21_output_loss: 1.7309 - h11_output_mse: 0.4230 - h11_output_mae: 0.4932 - h21_output_mse: 1.7309 - h21_output_mae: 1.0120 - val_loss: 2.8199 - val_h11_output_loss: 0.5458 - val_h21_output_loss: 3.5492 - val_h11_output_mse: 0.5458 - val_h11_output_mae: 0.4730 - val_h21_output_mse: 3.5492 - val_h21_output_mae: 1.2681 - lr: 0.0010
# Epoch 36/2000
# 190/198 [===========================>..] - ETA: 0s - loss: 1.8038 - h11_output_loss: 0.3646 - h21_output_loss: 1.7026 - h11_output_mse: 0.3646 - h11_output_mae: 0.4588 - h21_output_mse: 1.7026 - h21_output_mae: 0.9952
# Epoch 00036: val_loss did not improve from 2.63251
# 198/198 [==============================] - 1s 5ms/step - loss: 1.8051 - h11_output_loss: 0.3591 - h21_output_loss: 1.7111 - h11_output_mse: 0.3591 - h11_output_mae: 0.4550 - h21_output_mse: 1.7111 - h21_output_mae: 0.9984 - val_loss: 4.6743 - val_h11_output_loss: 0.4775 - val_h21_output_loss: 7.3392 - val_h11_output_mse: 0.4775 - val_h11_output_mae: 0.4132 - val_h21_output_mse: 7.3392 - val_h21_output_mae: 2.2363 - lr: 0.0010
# Epoch 37/2000
# 191/198 [===========================>..] - ETA: 0s - loss: 2.1585 - h11_output_loss: 0.3916 - h21_output_loss: 2.3855 - h11_output_mse: 0.3916 - h11_output_mae: 0.4675 - h21_output_mse: 2.3855 - h21_output_mae: 1.1308
# Epoch 00037: val_loss did not improve from 2.63251
# 198/198 [==============================] - 1s 5ms/step - loss: 2.1550 - h11_output_loss: 0.3923 - h21_output_loss: 2.3776 - h11_output_mse: 0.3923 - h11_output_mae: 0.4676 - h21_output_mse: 2.3776 - h21_output_mae: 1.1317 - val_loss: 3.1453 - val_h11_output_loss: 0.6212 - val_h21_output_loss: 4.1236 - val_h11_output_mse: 0.6212 - val_h11_output_mae: 0.4681 - val_h21_output_mse: 4.1236 - val_h21_output_mae: 1.4537 - lr: 0.0010
# Epoch 38/2000
# 192/198 [============================>.] - ETA: 0s - loss: 1.6851 - h11_output_loss: 0.3466 - h21_output_loss: 1.4862 - h11_output_mse: 0.3466 - h11_output_mae: 0.4505 - h21_output_mse: 1.4862 - h21_output_mae: 0.9266
# Epoch 00038: val_loss improved from 2.63251 to 2.31636, saving model to ./mod/inception_line_out_80.h5
# 198/198 [==============================] - 1s 5ms/step - loss: 1.6939 - h11_output_loss: 0.3481 - h21_output_loss: 1.5027 - h11_output_mse: 0.3481 - h11_output_mae: 0.4507 - h21_output_mse: 1.5027 - h21_output_mae: 0.9302 - val_loss: 2.3164 - val_h11_output_loss: 0.4950 - val_h21_output_loss: 2.6117 - val_h11_output_mse: 0.4950 - val_h11_output_mae: 0.4291 - val_h21_output_mse: 2.6117 - val_h21_output_mae: 1.0874 - lr: 0.0010
# Epoch 39/2000
# 192/198 [============================>.] - ETA: 0s - loss: 1.8056 - h11_output_loss: 0.3066 - h21_output_loss: 1.7832 - h11_output_mse: 0.3066 - h11_output_mae: 0.4225 - h21_output_mse: 1.7832 - h21_output_mae: 1.0252
# Epoch 00039: val_loss did not improve from 2.31636
# 198/198 [==============================] - 1s 5ms/step - loss: 1.8164 - h11_output_loss: 0.3092 - h21_output_loss: 1.8021 - h11_output_mse: 0.3092 - h11_output_mae: 0.4240 - h21_output_mse: 1.8021 - h21_output_mae: 1.0292 - val_loss: 4.5464 - val_h11_output_loss: 0.5014 - val_h21_output_loss: 7.0710 - val_h11_output_mse: 0.5014 - val_h11_output_mae: 0.4472 - val_h21_output_mse: 7.0710 - val_h21_output_mae: 2.0795 - lr: 0.0010
# Epoch 40/2000
# 192/198 [============================>.] - ETA: 0s - loss: 2.1500 - h11_output_loss: 0.4913 - h21_output_loss: 2.2710 - h11_output_mse: 0.4913 - h11_output_mae: 0.5406 - h21_output_mse: 2.2710 - h21_output_mae: 1.1337
# Epoch 00040: val_loss did not improve from 2.31636
# 198/198 [==============================] - 1s 5ms/step - loss: 2.1375 - h11_output_loss: 0.4859 - h21_output_loss: 2.2514 - h11_output_mse: 0.4859 - h11_output_mae: 0.5376 - h21_output_mse: 2.2514 - h21_output_mae: 1.1292 - val_loss: 2.7881 - val_h11_output_loss: 0.5198 - val_h21_output_loss: 3.5176 - val_h11_output_mse: 0.5198 - val_h11_output_mae: 0.4364 - val_h21_output_mse: 3.5176 - val_h21_output_mae: 1.3277 - lr: 0.0010
# Epoch 41/2000
# 191/198 [===========================>..] - ETA: 0s - loss: 2.2316 - h11_output_loss: 0.5784 - h21_output_loss: 2.3292 - h11_output_mse: 0.5784 - h11_output_mae: 0.5426 - h21_output_mse: 2.3292 - h21_output_mae: 1.0944
# Epoch 00041: val_loss did not improve from 2.31636
# 198/198 [==============================] - 1s 5ms/step - loss: 2.2544 - h11_output_loss: 0.5825 - h21_output_loss: 2.3697 - h11_output_mse: 0.5825 - h11_output_mae: 0.5432 - h21_output_mse: 2.3697 - h21_output_mae: 1.0995 - val_loss: 4.1408 - val_h11_output_loss: 1.2593 - val_h21_output_loss: 5.4323 - val_h11_output_mse: 1.2593 - val_h11_output_mae: 0.6175 - val_h21_output_mse: 5.4323 - val_h21_output_mae: 1.5013 - lr: 0.0010
# Epoch 42/2000
# 192/198 [============================>.] - ETA: 0s - loss: 2.0276 - h11_output_loss: 0.4656 - h21_output_loss: 1.9919 - h11_output_mse: 0.4656 - h11_output_mae: 0.5000 - h21_output_mse: 1.9919 - h21_output_mae: 1.0398
# Epoch 00042: val_loss did not improve from 2.31636
# 198/198 [==============================] - 1s 5ms/step - loss: 2.0279 - h11_output_loss: 0.4676 - h21_output_loss: 1.9905 - h11_output_mse: 0.4676 - h11_output_mae: 0.4994 - h21_output_mse: 1.9905 - h21_output_mae: 1.0390 - val_loss: 2.7939 - val_h11_output_loss: 0.5350 - val_h21_output_loss: 3.4581 - val_h11_output_mse: 0.5350 - val_h11_output_mae: 0.4478 - val_h21_output_mse: 3.4581 - val_h21_output_mae: 1.2156 - lr: 0.0010
# Epoch 43/2000
# 189/198 [===========================>..] - ETA: 0s - loss: 1.8408 - h11_output_loss: 0.3440 - h21_output_loss: 1.7480 - h11_output_mse: 0.3440 - h11_output_mae: 0.4398 - h21_output_mse: 1.7480 - h21_output_mae: 0.9775
# Epoch 00043: val_loss did not improve from 2.31636
# 198/198 [==============================] - 1s 5ms/step - loss: 1.8515 - h11_output_loss: 0.3462 - h21_output_loss: 1.7677 - h11_output_mse: 0.3462 - h11_output_mae: 0.4418 - h21_output_mse: 1.7677 - h21_output_mae: 0.9863 - val_loss: 2.9683 - val_h11_output_loss: 0.8065 - val_h21_output_loss: 3.5525 - val_h11_output_mse: 0.8065 - val_h11_output_mae: 0.5438 - val_h21_output_mse: 3.5525 - val_h21_output_mae: 1.2073 - lr: 0.0010
# Epoch 44/2000
# 191/198 [===========================>..] - ETA: 0s - loss: 1.6472 - h11_output_loss: 0.3572 - h21_output_loss: 1.3672 - h11_output_mse: 0.3572 - h11_output_mae: 0.4531 - h21_output_mse: 1.3672 - h21_output_mae: 0.8881
# Epoch 00044: val_loss did not improve from 2.31636
# 198/198 [==============================] - 1s 5ms/step - loss: 1.6408 - h11_output_loss: 0.3560 - h21_output_loss: 1.3559 - h11_output_mse: 0.3560 - h11_output_mae: 0.4524 - h21_output_mse: 1.3559 - h21_output_mae: 0.8847 - val_loss: 2.7943 - val_h11_output_loss: 0.5922 - val_h21_output_loss: 3.4415 - val_h11_output_mse: 0.5922 - val_h11_output_mae: 0.4397 - val_h21_output_mse: 3.4415 - val_h21_output_mae: 1.1804 - lr: 0.0010
# Epoch 45/2000
# 190/198 [===========================>..] - ETA: 0s - loss: 1.6039 - h11_output_loss: 0.2994 - h21_output_loss: 1.3670 - h11_output_mse: 0.2994 - h11_output_mae: 0.4135 - h21_output_mse: 1.3670 - h21_output_mae: 0.8957
# Epoch 00045: val_loss improved from 2.31636 to 2.16326, saving model to ./mod/inception_line_out_80.h5
# 198/198 [==============================] - 1s 5ms/step - loss: 1.6081 - h11_output_loss: 0.3016 - h21_output_loss: 1.3737 - h11_output_mse: 0.3016 - h11_output_mae: 0.4142 - h21_output_mse: 1.3737 - h21_output_mae: 0.8984 - val_loss: 2.1633 - val_h11_output_loss: 0.4751 - val_h21_output_loss: 2.3200 - val_h11_output_mse: 0.4751 - val_h11_output_mae: 0.4607 - val_h21_output_mse: 2.3200 - val_h21_output_mae: 1.0663 - lr: 0.0010
# Epoch 46/2000
# 190/198 [===========================>..] - ETA: 0s - loss: 1.6699 - h11_output_loss: 0.3242 - h21_output_loss: 1.4897 - h11_output_mse: 0.3242 - h11_output_mae: 0.4251 - h21_output_mse: 1.4897 - h21_output_mae: 0.9101
# Epoch 00046: val_loss did not improve from 2.16326
# 198/198 [==============================] - 1s 5ms/step - loss: 1.6715 - h11_output_loss: 0.3242 - h21_output_loss: 1.4931 - h11_output_mse: 0.3242 - h11_output_mae: 0.4248 - h21_output_mse: 1.4931 - h21_output_mae: 0.9112 - val_loss: 3.4677 - val_h11_output_loss: 0.4321 - val_h21_output_loss: 4.9837 - val_h11_output_mse: 0.4321 - val_h11_output_mae: 0.3954 - val_h21_output_mse: 4.9837 - val_h21_output_mae: 1.7531 - lr: 0.0010
# Epoch 47/2000
# 192/198 [============================>.] - ETA: 0s - loss: 1.6455 - h11_output_loss: 0.2527 - h21_output_loss: 1.5271 - h11_output_mse: 0.2527 - h11_output_mae: 0.3813 - h21_output_mse: 1.5271 - h21_output_mae: 0.9423
# Epoch 00047: val_loss did not improve from 2.16326
# 198/198 [==============================] - 1s 5ms/step - loss: 1.6438 - h11_output_loss: 0.2524 - h21_output_loss: 1.5242 - h11_output_mse: 0.2524 - h11_output_mae: 0.3812 - h21_output_mse: 1.5242 - h21_output_mae: 0.9412 - val_loss: 2.2932 - val_h11_output_loss: 0.4999 - val_h21_output_loss: 2.5824 - val_h11_output_mse: 0.4999 - val_h11_output_mae: 0.4897 - val_h21_output_mse: 2.5824 - val_h21_output_mae: 1.1085 - lr: 0.0010
# Epoch 48/2000
# 190/198 [===========================>..] - ETA: 0s - loss: 1.6013 - h11_output_loss: 0.2769 - h21_output_loss: 1.4307 - h11_output_mse: 0.2769 - h11_output_mae: 0.3884 - h21_output_mse: 1.4307 - h21_output_mae: 0.9103
# Epoch 00048: val_loss did not improve from 2.16326
# 198/198 [==============================] - 1s 5ms/step - loss: 1.6030 - h11_output_loss: 0.2827 - h21_output_loss: 1.4285 - h11_output_mse: 0.2827 - h11_output_mae: 0.3904 - h21_output_mse: 1.4285 - h21_output_mae: 0.9107 - val_loss: 2.8692 - val_h11_output_loss: 0.6954 - val_h21_output_loss: 3.5519 - val_h11_output_mse: 0.6954 - val_h11_output_mae: 0.5861 - val_h21_output_mse: 3.5519 - val_h21_output_mae: 1.2623 - lr: 0.0010
# Epoch 49/2000
# 192/198 [============================>.] - ETA: 0s - loss: 1.6139 - h11_output_loss: 0.2629 - h21_output_loss: 1.4725 - h11_output_mse: 0.2629 - h11_output_mae: 0.3827 - h21_output_mse: 1.4725 - h21_output_mae: 0.9081
# Epoch 00049: val_loss did not improve from 2.16326
# 198/198 [==============================] - 1s 5ms/step - loss: 1.6121 - h11_output_loss: 0.2623 - h21_output_loss: 1.4697 - h11_output_mse: 0.2623 - h11_output_mae: 0.3827 - h21_output_mse: 1.4697 - h21_output_mae: 0.9092 - val_loss: 2.7423 - val_h11_output_loss: 0.4895 - val_h21_output_loss: 3.5097 - val_h11_output_mse: 0.4895 - val_h11_output_mae: 0.3981 - val_h21_output_mse: 3.5097 - val_h21_output_mae: 1.2807 - lr: 0.0010
# Epoch 50/2000
# 192/198 [============================>.] - ETA: 0s - loss: 1.6110 - h11_output_loss: 0.2654 - h21_output_loss: 1.4790 - h11_output_mse: 0.2654 - h11_output_mae: 0.3834 - h21_output_mse: 1.4790 - h21_output_mae: 0.9253
# Epoch 00050: val_loss did not improve from 2.16326
# 198/198 [==============================] - 1s 5ms/step - loss: 1.6183 - h11_output_loss: 0.2662 - h21_output_loss: 1.4930 - h11_output_mse: 0.2662 - h11_output_mae: 0.3832 - h21_output_mse: 1.4930 - h21_output_mae: 0.9290 - val_loss: 2.3710 - val_h11_output_loss: 0.5707 - val_h21_output_loss: 2.6964 - val_h11_output_mse: 0.5707 - val_h11_output_mae: 0.4780 - val_h21_output_mse: 2.6964 - val_h21_output_mae: 1.0757 - lr: 0.0010
# Epoch 51/2000
# 192/198 [============================>.] - ETA: 0s - loss: 1.9862 - h11_output_loss: 0.4481 - h21_output_loss: 2.0201 - h11_output_mse: 0.4481 - h11_output_mae: 0.4918 - h21_output_mse: 2.0201 - h21_output_mae: 1.0010
# Epoch 00051: val_loss did not improve from 2.16326
# 198/198 [==============================] - 1s 5ms/step - loss: 1.9835 - h11_output_loss: 0.4594 - h21_output_loss: 2.0021 - h11_output_mse: 0.4594 - h11_output_mae: 0.4929 - h21_output_mse: 2.0021 - h21_output_mae: 0.9971 - val_loss: 2.9230 - val_h11_output_loss: 0.7508 - val_h21_output_loss: 3.5455 - val_h11_output_mse: 0.7508 - val_h11_output_mae: 0.5108 - val_h21_output_mse: 3.5455 - val_h21_output_mae: 1.1863 - lr: 0.0010
# Epoch 52/2000
# 193/198 [============================>.] - ETA: 0s - loss: 1.9917 - h11_output_loss: 0.4867 - h21_output_loss: 1.9408 - h11_output_mse: 0.4867 - h11_output_mae: 0.4838 - h21_output_mse: 1.9408 - h21_output_mae: 1.0085
# Epoch 00052: val_loss did not improve from 2.16326
# 198/198 [==============================] - 1s 5ms/step - loss: 1.9825 - h11_output_loss: 0.4813 - h21_output_loss: 1.9273 - h11_output_mse: 0.4813 - h11_output_mae: 0.4813 - h21_output_mse: 1.9273 - h21_output_mae: 1.0055 - val_loss: 2.4749 - val_h11_output_loss: 0.6471 - val_h21_output_loss: 2.7329 - val_h11_output_mse: 0.6471 - val_h11_output_mae: 0.5378 - val_h21_output_mse: 2.7329 - val_h21_output_mae: 1.0940 - lr: 0.0010
# Epoch 53/2000
# 193/198 [============================>.] - ETA: 0s - loss: 1.8441 - h11_output_loss: 0.3043 - h21_output_loss: 1.8301 - h11_output_mse: 0.3043 - h11_output_mae: 0.4209 - h21_output_mse: 1.8301 - h21_output_mae: 1.0248
# Epoch 00053: val_loss did not improve from 2.16326
# 198/198 [==============================] - 1s 5ms/step - loss: 1.8507 - h11_output_loss: 0.3037 - h21_output_loss: 1.8440 - h11_output_mse: 0.3037 - h11_output_mae: 0.4210 - h21_output_mse: 1.8440 - h21_output_mae: 1.0301 - val_loss: 2.5538 - val_h11_output_loss: 0.6065 - val_h21_output_loss: 2.9509 - val_h11_output_mse: 0.6065 - val_h11_output_mae: 0.5522 - val_h21_output_mse: 2.9509 - val_h21_output_mae: 1.1792 - lr: 0.0010
# Epoch 54/2000
# 189/198 [===========================>..] - ETA: 0s - loss: 1.7282 - h11_output_loss: 0.2864 - h21_output_loss: 1.6286 - h11_output_mse: 0.2864 - h11_output_mae: 0.3967 - h21_output_mse: 1.6286 - h21_output_mae: 0.9715
# Epoch 00054: val_loss did not improve from 2.16326
# 198/198 [==============================] - 1s 5ms/step - loss: 1.7379 - h11_output_loss: 0.2848 - h21_output_loss: 1.6496 - h11_output_mse: 0.2848 - h11_output_mae: 0.3958 - h21_output_mse: 1.6496 - h21_output_mae: 0.9785 - val_loss: 3.4635 - val_h11_output_loss: 0.3985 - val_h21_output_loss: 4.9865 - val_h11_output_mse: 0.3985 - val_h11_output_mae: 0.4365 - val_h21_output_mse: 4.9865 - val_h21_output_mae: 1.8312 - lr: 0.0010
# Epoch 55/2000
# 191/198 [===========================>..] - ETA: 0s - loss: 1.6202 - h11_output_loss: 0.2888 - h21_output_loss: 1.4225 - h11_output_mse: 0.2888 - h11_output_mae: 0.3994 - h21_output_mse: 1.4225 - h21_output_mae: 0.9054
# Epoch 00055: val_loss did not improve from 2.16326
# 198/198 [==============================] - 1s 5ms/step - loss: 1.6146 - h11_output_loss: 0.2862 - h21_output_loss: 1.4143 - h11_output_mse: 0.2862 - h11_output_mae: 0.3983 - h21_output_mse: 1.4143 - h21_output_mae: 0.9033 - val_loss: 2.2350 - val_h11_output_loss: 0.4108 - val_h21_output_loss: 2.5464 - val_h11_output_mse: 0.4108 - val_h11_output_mae: 0.4098 - val_h21_output_mse: 2.5464 - val_h21_output_mae: 1.0357 - lr: 0.0010
# Epoch 56/2000
# 193/198 [============================>.] - ETA: 0s - loss: 1.4952 - h11_output_loss: 0.2803 - h21_output_loss: 1.2108 - h11_output_mse: 0.2803 - h11_output_mae: 0.4080 - h21_output_mse: 1.2108 - h21_output_mae: 0.8353
# Epoch 00056: val_loss did not improve from 2.16326
# 198/198 [==============================] - 1s 5ms/step - loss: 1.4924 - h11_output_loss: 0.2796 - h21_output_loss: 1.2062 - h11_output_mse: 0.2796 - h11_output_mae: 0.4079 - h21_output_mse: 1.2062 - h21_output_mae: 0.8337 - val_loss: 2.4170 - val_h11_output_loss: 0.3669 - val_h21_output_loss: 2.9847 - val_h11_output_mse: 0.3669 - val_h11_output_mae: 0.3987 - val_h21_output_mse: 2.9847 - val_h21_output_mae: 1.2637 - lr: 0.0010
# Epoch 57/2000
# 190/198 [===========================>..] - ETA: 0s - loss: 1.4651 - h11_output_loss: 0.2105 - h21_output_loss: 1.2482 - h11_output_mse: 0.2105 - h11_output_mae: 0.3481 - h21_output_mse: 1.2482 - h21_output_mae: 0.8542
# Epoch 00057: val_loss improved from 2.16326 to 2.15395, saving model to ./mod/inception_line_out_80.h5
# 198/198 [==============================] - 1s 5ms/step - loss: 1.4646 - h11_output_loss: 0.2103 - h21_output_loss: 1.2480 - h11_output_mse: 0.2103 - h11_output_mae: 0.3482 - h21_output_mse: 1.2480 - h21_output_mae: 0.8561 - val_loss: 2.1539 - val_h11_output_loss: 0.5249 - val_h21_output_loss: 2.3250 - val_h11_output_mse: 0.5249 - val_h11_output_mae: 0.5197 - val_h21_output_mse: 2.3250 - val_h21_output_mae: 1.0512 - lr: 0.0010
# Epoch 58/2000
# 193/198 [============================>.] - ETA: 0s - loss: 1.6486 - h11_output_loss: 0.4069 - h21_output_loss: 1.4296 - h11_output_mse: 0.4069 - h11_output_mae: 0.4563 - h21_output_mse: 1.4296 - h21_output_mae: 0.9111
# Epoch 00058: val_loss did not improve from 2.15395
# 198/198 [==============================] - 1s 5ms/step - loss: 1.6394 - h11_output_loss: 0.4034 - h21_output_loss: 1.4147 - h11_output_mse: 0.4034 - h11_output_mae: 0.4551 - h21_output_mse: 1.4147 - h21_output_mae: 0.9063 - val_loss: 2.1797 - val_h11_output_loss: 0.5202 - val_h21_output_loss: 2.3827 - val_h11_output_mse: 0.5202 - val_h11_output_mae: 0.4419 - val_h21_output_mse: 2.3827 - val_h21_output_mae: 1.0685 - lr: 0.0010
# Epoch 59/2000
# 188/198 [===========================>..] - ETA: 0s - loss: 1.5382 - h11_output_loss: 0.2828 - h21_output_loss: 1.3465 - h11_output_mse: 0.2828 - h11_output_mae: 0.3969 - h21_output_mse: 1.3465 - h21_output_mae: 0.8659
# Epoch 00059: val_loss did not improve from 2.15395
# 198/198 [==============================] - 1s 5ms/step - loss: 1.5353 - h11_output_loss: 0.2846 - h21_output_loss: 1.3392 - h11_output_mse: 0.2846 - h11_output_mae: 0.3994 - h21_output_mse: 1.3392 - h21_output_mae: 0.8636 - val_loss: 2.3078 - val_h11_output_loss: 0.3595 - val_h21_output_loss: 2.8145 - val_h11_output_mse: 0.3595 - val_h11_output_mae: 0.3973 - val_h21_output_mse: 2.8145 - val_h21_output_mae: 1.1854 - lr: 0.0010
# Epoch 60/2000
# 193/198 [============================>.] - ETA: 0s - loss: 1.5989 - h11_output_loss: 0.2699 - h21_output_loss: 1.4880 - h11_output_mse: 0.2699 - h11_output_mae: 0.3817 - h21_output_mse: 1.4880 - h21_output_mae: 0.9122
# Epoch 00060: val_loss improved from 2.15395 to 2.02149, saving model to ./mod/inception_line_out_80.h5
# 198/198 [==============================] - 1s 5ms/step - loss: 1.6016 - h11_output_loss: 0.2688 - h21_output_loss: 1.4943 - h11_output_mse: 0.2688 - h11_output_mae: 0.3816 - h21_output_mse: 1.4943 - h21_output_mae: 0.9109 - val_loss: 2.0215 - val_h11_output_loss: 0.5346 - val_h21_output_loss: 2.0650 - val_h11_output_mse: 0.5346 - val_h11_output_mae: 0.4800 - val_h21_output_mse: 2.0650 - val_h21_output_mae: 0.9758 - lr: 0.0010
# Epoch 61/2000
# ...
# Epoch 00769: val_loss did not improve from 0.78435
# 198/198 [==============================] - 1s 5ms/step - loss: 0.3104 - h11_output_loss: 0.0485 - h21_output_loss: 0.2765 - h11_output_mse: 0.0485 - h11_output_mae: 0.1589 - h21_output_mse: 0.2765 - h21_output_mae: 0.4021 - val_loss: 0.8733 - val_h11_output_loss: 0.1095 - val_h21_output_loss: 1.3415 - val_h11_output_mse: 0.1095 - val_h11_output_mae: 0.1690 - val_h21_output_mse: 1.3415 - val_h21_output_mae: 0.8319 - lr: 3.0000e-04
# Epoch 770/2000
# 192/198 [============================>.] - ETA: 0s - loss: 0.2978 - h11_output_loss: 0.0471 - h21_output_loss: 0.2533 - h11_output_mse: 0.0471 - h11_output_mae: 0.1571 - h21_output_mse: 0.2533 - h21_output_mae: 0.3871
# Epoch 00770: val_loss did not improve from 0.78435
# 198/198 [==============================] - 1s 5ms/step - loss: 0.2974 - h11_output_loss: 0.0471 - h21_output_loss: 0.2526 - h11_output_mse: 0.0471 - h11_output_mae: 0.1571 - h21_output_mse: 0.2526 - h21_output_mae: 0.3867 - val_loss: 0.8812 - val_h11_output_loss: 0.1296 - val_h21_output_loss: 1.3379 - val_h11_output_mse: 0.1296 - val_h11_output_mae: 0.1663 - val_h21_output_mse: 1.3379 - val_h21_output_mae: 0.8060 - lr: 3.0000e-04
# Epoch 771/2000
# 191/198 [===========================>..] - ETA: 0s - loss: 0.3114 - h11_output_loss: 0.0514 - h21_output_loss: 0.2764 - h11_output_mse: 0.0514 - h11_output_mae: 0.1582 - h21_output_mse: 0.2764 - h21_output_mae: 0.3964
# Epoch 00771: val_loss did not improve from 0.78435
# 198/198 [==============================] - 1s 5ms/step - loss: 0.3109 - h11_output_loss: 0.0512 - h21_output_loss: 0.2756 - h11_output_mse: 0.0512 - h11_output_mae: 0.1583 - h21_output_mse: 0.2756 - h21_output_mae: 0.3964 - val_loss: 1.0015 - val_h11_output_loss: 0.2232 - val_h21_output_loss: 1.4842 - val_h11_output_mse: 0.2232 - val_h11_output_mae: 0.1724 - val_h21_output_mse: 1.4842 - val_h21_output_mae: 0.8433 - lr: 3.0000e-04
# Epoch 772/2000
# 192/198 [============================>.] - ETA: 0s - loss: 0.3169 - h11_output_loss: 0.0550 - h21_output_loss: 0.2834 - h11_output_mse: 0.0550 - h11_output_mae: 0.1635 - h21_output_mse: 0.2834 - h21_output_mae: 0.4024
# Epoch 00772: val_loss did not improve from 0.78435
# 198/198 [==============================] - 1s 5ms/step - loss: 0.3172 - h11_output_loss: 0.0549 - h21_output_loss: 0.2841 - h11_output_mse: 0.0549 - h11_output_mae: 0.1635 - h21_output_mse: 0.2841 - h21_output_mae: 0.4027 - val_loss: 0.9061 - val_h11_output_loss: 0.1306 - val_h21_output_loss: 1.3865 - val_h11_output_mse: 0.1306 - val_h11_output_mae: 0.1917 - val_h21_output_mse: 1.3865 - val_h21_output_mae: 0.8235 - lr: 3.0000e-04
# Epoch 773/2000
# 192/198 [============================>.] - ETA: 0s - loss: 0.3106 - h11_output_loss: 0.0473 - h21_output_loss: 0.2788 - h11_output_mse: 0.0473 - h11_output_mae: 0.1571 - h21_output_mse: 0.2788 - h21_output_mae: 0.4032
# Epoch 00773: val_loss did not improve from 0.78435
# 198/198 [==============================] - 1s 5ms/step - loss: 0.3098 - h11_output_loss: 0.0469 - h21_output_loss: 0.2776 - h11_output_mse: 0.0469 - h11_output_mae: 0.1563 - h21_output_mse: 0.2776 - h21_output_mae: 0.4023 - val_loss: 0.8866 - val_h11_output_loss: 0.1146 - val_h21_output_loss: 1.3630 - val_h11_output_mse: 0.1146 - val_h11_output_mae: 0.1647 - val_h21_output_mse: 1.3630 - val_h21_output_mae: 0.8308 - lr: 3.0000e-04
# Epoch 774/2000
# 192/198 [============================>.] - ETA: 0s - loss: 0.3077 - h11_output_loss: 0.0490 - h21_output_loss: 0.2715 - h11_output_mse: 0.0490 - h11_output_mae: 0.1591 - h21_output_mse: 0.2715 - h21_output_mae: 0.3988
# Epoch 00774: val_loss did not improve from 0.78435
# 198/198 [==============================] - 1s 5ms/step - loss: 0.3076 - h11_output_loss: 0.0490 - h21_output_loss: 0.2713 - h11_output_mse: 0.0490 - h11_output_mae: 0.1592 - h21_output_mse: 0.2713 - h21_output_mae: 0.3983 - val_loss: 0.9119 - val_h11_output_loss: 0.1343 - val_h21_output_loss: 1.3950 - val_h11_output_mse: 0.1343 - val_h11_output_mae: 0.1686 - val_h21_output_mse: 1.3950 - val_h21_output_mae: 0.8358 - lr: 3.0000e-04
# Epoch 775/2000
# 190/198 [===========================>..] - ETA: 0s - loss: 0.3229 - h11_output_loss: 0.0528 - h21_output_loss: 0.2982 - h11_output_mse: 0.0528 - h11_output_mae: 0.1638 - h21_output_mse: 0.2982 - h21_output_mae: 0.4186
# Epoch 00775: val_loss did not improve from 0.78435
# 198/198 [==============================] - 1s 5ms/step - loss: 0.3236 - h11_output_loss: 0.0527 - h21_output_loss: 0.2998 - h11_output_mse: 0.0527 - h11_output_mae: 0.1639 - h21_output_mse: 0.2998 - h21_output_mae: 0.4199 - val_loss: 0.9135 - val_h11_output_loss: 0.1461 - val_h21_output_loss: 1.3853 - val_h11_output_mse: 0.1461 - val_h11_output_mae: 0.2102 - val_h21_output_mse: 1.3853 - val_h21_output_mae: 0.8347 - lr: 3.0000e-04
# Epoch 776/2000
# 194/198 [============================>.] - ETA: 0s - loss: 0.3080 - h11_output_loss: 0.0476 - h21_output_loss: 0.2734 - h11_output_mse: 0.0476 - h11_output_mae: 0.1575 - h21_output_mse: 0.2734 - h21_output_mae: 0.3934
# Epoch 00776: val_loss did not improve from 0.78435
# 198/198 [==============================] - 1s 5ms/step - loss: 0.3076 - h11_output_loss: 0.0475 - h21_output_loss: 0.2728 - h11_output_mse: 0.0475 - h11_output_mae: 0.1575 - h21_output_mse: 0.2728 - h21_output_mae: 0.3931 - val_loss: 0.9509 - val_h11_output_loss: 0.1042 - val_h21_output_loss: 1.5038 - val_h11_output_mse: 0.1042 - val_h11_output_mae: 0.1645 - val_h21_output_mse: 1.5038 - val_h21_output_mae: 0.8724 - lr: 3.0000e-04
# Epoch 777/2000
# 192/198 [============================>.] - ETA: 0s - loss: 0.3016 - h11_output_loss: 0.0490 - h21_output_loss: 0.2607 - h11_output_mse: 0.0490 - h11_output_mae: 0.1585 - h21_output_mse: 0.2607 - h21_output_mae: 0.3941
# Epoch 00777: val_loss did not improve from 0.78435
# 198/198 [==============================] - 1s 5ms/step - loss: 0.3020 - h11_output_loss: 0.0488 - h21_output_loss: 0.2617 - h11_output_mse: 0.0488 - h11_output_mae: 0.1585 - h21_output_mse: 0.2617 - h21_output_mae: 0.3945 - val_loss: 0.8834 - val_h11_output_loss: 0.1122 - val_h21_output_loss: 1.3613 - val_h11_output_mse: 0.1122 - val_h11_output_mae: 0.1741 - val_h21_output_mse: 1.3613 - val_h21_output_mae: 0.8205 - lr: 3.0000e-04
# Epoch 778/2000
# 193/198 [============================>.] - ETA: 0s - loss: 0.2947 - h11_output_loss: 0.0480 - h21_output_loss: 0.2488 - h11_output_mse: 0.0480 - h11_output_mae: 0.1582 - h21_output_mse: 0.2488 - h21_output_mae: 0.3835
# Epoch 00778: val_loss did not improve from 0.78435
# 198/198 [==============================] - 1s 5ms/step - loss: 0.2947 - h11_output_loss: 0.0479 - h21_output_loss: 0.2488 - h11_output_mse: 0.0479 - h11_output_mae: 0.1582 - h21_output_mse: 0.2488 - h21_output_mae: 0.3840 - val_loss: 0.8606 - val_h11_output_loss: 0.1028 - val_h21_output_loss: 1.3261 - val_h11_output_mse: 0.1028 - val_h11_output_mae: 0.1759 - val_h21_output_mse: 1.3261 - val_h21_output_mae: 0.8105 - lr: 3.0000e-04
# Epoch 779/2000
# 192/198 [============================>.] - ETA: 0s - loss: 0.3010 - h11_output_loss: 0.0495 - h21_output_loss: 0.2602 - h11_output_mse: 0.0495 - h11_output_mae: 0.1581 - h21_output_mse: 0.2602 - h21_output_mae: 0.3897
# Epoch 00779: val_loss did not improve from 0.78435
# 198/198 [==============================] - 1s 5ms/step - loss: 0.3004 - h11_output_loss: 0.0494 - h21_output_loss: 0.2590 - h11_output_mse: 0.0494 - h11_output_mae: 0.1582 - h21_output_mse: 0.2590 - h21_output_mae: 0.3892 - val_loss: 0.8668 - val_h11_output_loss: 0.1078 - val_h21_output_loss: 1.3337 - val_h11_output_mse: 0.1078 - val_h11_output_mae: 0.1720 - val_h21_output_mse: 1.3337 - val_h21_output_mae: 0.8103 - lr: 3.0000e-04
# Epoch 780/2000
# 190/198 [===========================>..] - ETA: 0s - loss: 0.3067 - h11_output_loss: 0.0443 - h21_output_loss: 0.2771 - h11_output_mse: 0.0443 - h11_output_mae: 0.1523 - h21_output_mse: 0.2771 - h21_output_mae: 0.4008
# Epoch 00780: val_loss did not improve from 0.78435
# 198/198 [==============================] - 1s 5ms/step - loss: 0.3086 - h11_output_loss: 0.0441 - h21_output_loss: 0.2811 - h11_output_mse: 0.0441 - h11_output_mae: 0.1521 - h21_output_mse: 0.2811 - h21_output_mae: 0.4030 - val_loss: 0.8945 - val_h11_output_loss: 0.1068 - val_h21_output_loss: 1.3899 - val_h11_output_mse: 0.1068 - val_h11_output_mae: 0.1745 - val_h21_output_mse: 1.3899 - val_h21_output_mae: 0.8395 - lr: 3.0000e-04
# Epoch 781/2000
# 193/198 [============================>.] - ETA: 0s - loss: 0.3199 - h11_output_loss: 0.0474 - h21_output_loss: 0.2999 - h11_output_mse: 0.0474 - h11_output_mae: 0.1571 - h21_output_mse: 0.2999 - h21_output_mae: 0.4104
# Epoch 00781: val_loss did not improve from 0.78435
# 198/198 [==============================] - 1s 5ms/step - loss: 0.3198 - h11_output_loss: 0.0475 - h21_output_loss: 0.2997 - h11_output_mse: 0.0475 - h11_output_mae: 0.1574 - h21_output_mse: 0.2997 - h21_output_mae: 0.4106 - val_loss: 0.9372 - val_h11_output_loss: 0.0975 - val_h21_output_loss: 1.4847 - val_h11_output_mse: 0.0975 - val_h11_output_mae: 0.1866 - val_h21_output_mse: 1.4847 - val_h21_output_mae: 0.8683 - lr: 3.0000e-04
# Epoch 782/2000
# 189/198 [===========================>..] - ETA: 0s - loss: 0.3306 - h11_output_loss: 0.0519 - h21_output_loss: 0.3160 - h11_output_mse: 0.0519 - h11_output_mae: 0.1637 - h21_output_mse: 0.3160 - h21_output_mae: 0.4232
# Epoch 00782: val_loss did not improve from 0.78435
# 198/198 [==============================] - 1s 5ms/step - loss: 0.3287 - h11_output_loss: 0.0519 - h21_output_loss: 0.3124 - h11_output_mse: 0.0519 - h11_output_mae: 0.1637 - h21_output_mse: 0.3124 - h21_output_mae: 0.4209 - val_loss: 0.8828 - val_h11_output_loss: 0.1051 - val_h21_output_loss: 1.3677 - val_h11_output_mse: 0.1051 - val_h11_output_mae: 0.1871 - val_h21_output_mse: 1.3677 - val_h21_output_mae: 0.8194 - lr: 3.0000e-04
# Epoch 783/2000
# 193/198 [============================>.] - ETA: 0s - loss: 0.3106 - h11_output_loss: 0.0464 - h21_output_loss: 0.2823 - h11_output_mse: 0.0464 - h11_output_mae: 0.1569 - h21_output_mse: 0.2823 - h21_output_mae: 0.4046
# Epoch 00783: val_loss did not improve from 0.78435
# 198/198 [==============================] - 1s 5ms/step - loss: 0.3106 - h11_output_loss: 0.0463 - h21_output_loss: 0.2823 - h11_output_mse: 0.0463 - h11_output_mae: 0.1569 - h21_output_mse: 0.2823 - h21_output_mae: 0.4048 - val_loss: 0.8529 - val_h11_output_loss: 0.1050 - val_h21_output_loss: 1.3086 - val_h11_output_mse: 0.1050 - val_h11_output_mae: 0.1831 - val_h21_output_mse: 1.3086 - val_h21_output_mae: 0.8247 - lr: 3.0000e-04
# Epoch 784/2000
# 190/198 [===========================>..] - ETA: 0s - loss: 0.2986 - h11_output_loss: 0.0435 - h21_output_loss: 0.2618 - h11_output_mse: 0.0435 - h11_output_mae: 0.1551 - h21_output_mse: 0.2618 - h21_output_mae: 0.3939
# Epoch 00784: val_loss did not improve from 0.78435
# 198/198 [==============================] - 1s 5ms/step - loss: 0.2984 - h11_output_loss: 0.0443 - h21_output_loss: 0.2607 - h11_output_mse: 0.0443 - h11_output_mae: 0.1559 - h21_output_mse: 0.2607 - h21_output_mae: 0.3929 - val_loss: 0.8715 - val_h11_output_loss: 0.1119 - val_h21_output_loss: 1.3398 - val_h11_output_mse: 0.1119 - val_h11_output_mae: 0.1788 - val_h21_output_mse: 1.3398 - val_h21_output_mae: 0.8452 - lr: 3.0000e-04
# Epoch 785/2000
# 191/198 [===========================>..] - ETA: 0s - loss: 0.3008 - h11_output_loss: 0.0473 - h21_output_loss: 0.2630 - h11_output_mse: 0.0473 - h11_output_mae: 0.1577 - h21_output_mse: 0.2630 - h21_output_mae: 0.3934
# Epoch 00785: val_loss did not improve from 0.78435
# 198/198 [==============================] - 1s 5ms/step - loss: 0.3030 - h11_output_loss: 0.0472 - h21_output_loss: 0.2675 - h11_output_mse: 0.0472 - h11_output_mae: 0.1577 - h21_output_mse: 0.2675 - h21_output_mae: 0.3958 - val_loss: 0.8305 - val_h11_output_loss: 0.0780 - val_h21_output_loss: 1.2918 - val_h11_output_mse: 0.0780 - val_h11_output_mae: 0.1567 - val_h21_output_mse: 1.2918 - val_h21_output_mae: 0.8110 - lr: 3.0000e-04
# Epoch 786/2000
# 193/198 [============================>.] - ETA: 0s - loss: 0.2989 - h11_output_loss: 0.0468 - h21_output_loss: 0.2599 - h11_output_mse: 0.0468 - h11_output_mae: 0.1556 - h21_output_mse: 0.2599 - h21_output_mae: 0.3934
# Epoch 00786: val_loss did not improve from 0.78435
# 198/198 [==============================] - 1s 5ms/step - loss: 0.2982 - h11_output_loss: 0.0470 - h21_output_loss: 0.2584 - h11_output_mse: 0.0470 - h11_output_mae: 0.1560 - h21_output_mse: 0.2584 - h21_output_mae: 0.3923 - val_loss: 0.8018 - val_h11_output_loss: 0.0887 - val_h21_output_loss: 1.2244 - val_h11_output_mse: 0.0887 - val_h11_output_mae: 0.1739 - val_h21_output_mse: 1.2244 - val_h21_output_mae: 0.7979 - lr: 3.0000e-04
# Epoch 787/2000
# 192/198 [============================>.] - ETA: 0s - loss: 0.2996 - h11_output_loss: 0.0490 - h21_output_loss: 0.2600 - h11_output_mse: 0.0490 - h11_output_mae: 0.1612 - h21_output_mse: 0.2600 - h21_output_mae: 0.3897
# Epoch 00787: val_loss did not improve from 0.78435
# 198/198 [==============================] - 1s 5ms/step - loss: 0.3017 - h11_output_loss: 0.0498 - h21_output_loss: 0.2632 - h11_output_mse: 0.0498 - h11_output_mae: 0.1612 - h21_output_mse: 0.2632 - h21_output_mae: 0.3906 - val_loss: 1.3606 - val_h11_output_loss: 0.4659 - val_h21_output_loss: 1.9638 - val_h11_output_mse: 0.4659 - val_h11_output_mae: 0.1972 - val_h21_output_mse: 1.9638 - val_h21_output_mae: 0.8502 - lr: 3.0000e-04
# Epoch 788/2000
# 193/198 [============================>.] - ETA: 0s - loss: 0.3469 - h11_output_loss: 0.0700 - h21_output_loss: 0.3294 - h11_output_mse: 0.0700 - h11_output_mae: 0.1700 - h21_output_mse: 0.3294 - h21_output_mae: 0.4256
# Epoch 00788: val_loss did not improve from 0.78435
# 198/198 [==============================] - 1s 5ms/step - loss: 0.3461 - h11_output_loss: 0.0697 - h21_output_loss: 0.3278 - h11_output_mse: 0.0697 - h11_output_mae: 0.1703 - h21_output_mse: 0.3278 - h21_output_mae: 0.4250 - val_loss: 1.5842 - val_h11_output_loss: 0.5753 - val_h21_output_loss: 2.2954 - val_h11_output_mse: 0.5753 - val_h11_output_mae: 0.2338 - val_h21_output_mse: 2.2954 - val_h21_output_mae: 0.9710 - lr: 3.0000e-04
# Epoch 789/2000
# 191/198 [===========================>..] - ETA: 0s - loss: 0.3535 - h11_output_loss: 0.0617 - h21_output_loss: 0.3457 - h11_output_mse: 0.0617 - h11_output_mae: 0.1705 - h21_output_mse: 0.3457 - h21_output_mae: 0.4345
# Epoch 00789: val_loss did not improve from 0.78435
# 198/198 [==============================] - 1s 5ms/step - loss: 0.3514 - h11_output_loss: 0.0609 - h21_output_loss: 0.3423 - h11_output_mse: 0.0609 - h11_output_mae: 0.1698 - h21_output_mse: 0.3423 - h21_output_mae: 0.4326 - val_loss: 1.2997 - val_h11_output_loss: 0.3343 - val_h21_output_loss: 1.9675 - val_h11_output_mse: 0.3343 - val_h11_output_mae: 0.1925 - val_h21_output_mse: 1.9675 - val_h21_output_mae: 0.8494 - lr: 3.0000e-04
# Epoch 790/2000
# 191/198 [===========================>..] - ETA: 0s - loss: 0.3234 - h11_output_loss: 0.0461 - h21_output_loss: 0.3034 - h11_output_mse: 0.0461 - h11_output_mae: 0.1546 - h21_output_mse: 0.3034 - h21_output_mae: 0.4214
# Epoch 00790: val_loss did not improve from 0.78435
# 198/198 [==============================] - 1s 5ms/step - loss: 0.3231 - h11_output_loss: 0.0466 - h21_output_loss: 0.3023 - h11_output_mse: 0.0466 - h11_output_mae: 0.1557 - h21_output_mse: 0.3023 - h21_output_mae: 0.4209 - val_loss: 1.3182 - val_h11_output_loss: 0.3404 - val_h21_output_loss: 1.9998 - val_h11_output_mse: 0.3404 - val_h11_output_mae: 0.1901 - val_h21_output_mse: 1.9998 - val_h21_output_mae: 0.8493 - lr: 3.0000e-04
# Epoch 791/2000
#  37/198 [====>.........................] - ETA: 0s - loss: 0.2940 - h11_output_loss: 0.0472 - h21_output_loss: 0.2445 - h11_output_mse: 0.0472 - h11_output_mae: 0.1605 - h21_output_mse: 0.2445 - h21_output_mae: 0.3743

# %% [markdown]
# We the take a look at the accuracy of the output:

# %%
import joblib

# predictions
h11_pred = np.rint(inception_line.predict(mat_out_test_80)['h11_output']).astype(int).reshape(-1,)
h21_pred = np.rint(inception_line.predict(mat_out_test_80)['h21_output']).astype(int).reshape(-1,)

# true values
h11_true = lab_out_test_80['h11_output'].astype(int).reshape(-1,)
h21_true = lab_out_test_80['h21_output'].astype(int).reshape(-1,)

# accuracy
h11_acc = np.mean((h11_pred == h11_true).astype(int))
h21_acc = np.mean((h21_pred == h21_true).astype(int))

# save predictions
predictions = {'h11_pred': h11_pred,
               'h11_true': h11_true,
               'h21_pred': h21_true,
               'h21_true': h21_pred
              }
predictions = pd.DataFrame(predictions)
predictions.to_csv('./dat/inc_line_out_80.csv')

# save history
joblib.dump(inc_line_out_80.history, './dat/inc_line_out_80.pkl')

# print accuracy
print('Accuracy for h_11: {:.2f}%'.format(h11_acc * 100))
print('Accuracy for h_21: {:.2f}%'.format(h21_acc * 100))

# %% [markdown]
# ### 80% Training Data w/o Outliers (line kernel)

# %%
callbacks = [keras.callbacks.ModelCheckpoint('./mod/inception_line_noout_80.h5',
                                             monitor='val_loss',
                                             verbose=0,
                                             save_best_only=True
                                            ),
             keras.callbacks.ReduceLROnPlateau(monitor='val_loss',
                                               factor=0.3,
                                               patience=80,
                                               verbose=0,
                                               min_lr=1.0e-6
                                              ),
             keras.callbacks.EarlyStopping(monitor='val_loss',
                                           patience=200,
                                           restore_best_weights=True,
                                           verbose=0
                                          )
            ]

inception_line.summary()

print('Training 80% data w/o outliers (line kernel)')

# define the model
inception_line = inc_model(input_shape=input_shape,
                           model_name='inc_line',
                           learning_rate=0.001,
                           filters=[32, 64, 32],
                           kernel_size=[(12,1), (1,15)],
                           dropout=0.2,
                           l1_reg=1.0e-4,
                           l2_reg=1.0e-4,
                           rho=0.5
                          )
inc_line_noout_80 = inception_line.fit(x=mat_noout_train_80,
                                       y=lab_noout_train_80,
                                       batch_size=32,
                                       epochs=2000,
                                       verbose=0,
                                       callbacks=callbacks,
                                       validation_data=(mat_noout_val_80, lab_noout_val_80)
                                      )

# %% [markdown]
# We the take a look at the accuracy of the output:

# %%
import joblib

# predictions
h11_pred = np.rint(inception_line.predict(mat_noout_test_80)['h11_output']).astype(int).reshape(-1,)
h21_pred = np.rint(inception_line.predict(mat_noout_test_80)['h21_output']).astype(int).reshape(-1,)

# true values
h11_true = lab_noout_test_80['h11_output'].astype(int).reshape(-1,)
h21_true = lab_noout_test_80['h21_output'].astype(int).reshape(-1,)

# accuracy
h11_acc = np.mean((h11_pred == h11_true).astype(int))
h21_acc = np.mean((h21_pred == h21_true).astype(int))

# save predictions
predictions = {'h11_pred': h11_pred,
               'h11_true': h11_true,
               'h21_pred': h21_true,
               'h21_true': h21_pred
              }
predictions = pd.DataFrame(predictions)
predictions.to_csv('./dat/inc_line_noout_80.csv')

# save history
joblib.dump(inc_line_noout_80.history, './dat/inc_line_noout_80.pkl')

# print accuracy
print('Accuracy for h_11: {:.2f}%'.format(h11_acc * 100))
print('Accuracy for h_21: {:.2f}%'.format(h21_acc * 100))

# %% [markdown]
# ### 30% Training Data w/ Outliers (line kernel)

# %%
callbacks = [keras.callbacks.ModelCheckpoint('./mod/inception_line_out_30.h5',
                                             monitor='val_loss',
                                             verbose=0,
                                             save_best_only=True
                                            ),
             keras.callbacks.ReduceLROnPlateau(monitor='val_loss',
                                               factor=0.3,
                                               patience=80,
                                               verbose=0,
                                               min_lr=1.0e-6
                                              ),
             keras.callbacks.EarlyStopping(monitor='val_loss',
                                           patience=200,
                                           verbose=0
                                          )
            ]

inception_line.summary()

print('Training 30% data w/ outliers (line kernel)')

# define the model
inception_line = inc_model(input_shape=input_shape,
                           model_name='inc_line',
                           learning_rate=0.001,
                           filters=[32, 64, 32],
                           kernel_size=[(12,1), (1,15)],
                           dropout=0.2,
                           l1_reg=1.0e-4,
                           l2_reg=1.0e-4,
                           rho=0.5
                          )
inc_line_out_30 = inception_line.fit(x=mat_out_train_30,
                                     y=lab_out_train_30,
                                     batch_size=32,
                                     epochs=2000,
                                     verbose=0,
                                     callbacks=callbacks,
                                     validation_data=(mat_out_val_30, lab_out_val_30)
                                    )

# %% [markdown]
# We the take a look at the accuracy of the output:

# %%
import joblib

# predictions
h11_pred = np.rint(inception_line.predict(mat_out_test_30)['h11_output']).astype(int).reshape(-1,)
h21_pred = np.rint(inception_line.predict(mat_out_test_30)['h21_output']).astype(int).reshape(-1,)

# true values
h11_true = lab_out_test_30['h11_output'].astype(int).reshape(-1,)
h21_true = lab_out_test_30['h21_output'].astype(int).reshape(-1,)

# accuracy
h11_acc = np.mean((h11_pred == h11_true).astype(int))
h21_acc = np.mean((h21_pred == h21_true).astype(int))

# save predictions
predictions = {'h11_pred': h11_pred,
               'h11_true': h11_true,
               'h21_pred': h21_true,
               'h21_true': h21_pred
              }
predictions = pd.DataFrame(predictions)
predictions.to_csv('./dat/inc_line_out_30.csv')

# save history
joblib.dump(inc_line_out_30.history, './dat/inc_line_out_30.pkl')

# print accuracy
print('Accuracy for h_11: {:.2f}%'.format(h11_acc * 100))
print('Accuracy for h_21: {:.2f}%'.format(h21_acc * 100))

# %% [markdown]
# ### 30% Training Data w/o Outliers (line kernel)

# %%
callbacks = [keras.callbacks.ModelCheckpoint('./mod/inception_line_noout_30.h5',
                                             monitor='val_loss',
                                             verbose=0,
                                             save_best_only=True
                                            ),
             keras.callbacks.ReduceLROnPlateau(monitor='val_loss',
                                               factor=0.3,
                                               patience=80,
                                               verbose=0,
                                               min_lr=1.0e-6
                                              ),
             keras.callbacks.EarlyStopping(monitor='val_loss',
                                           patience=200,
                                           restore_best_weights=True,
                                           verbose=0
                                          )
            ]

inception_line.summary()

print('Training 30% data w/o outliers (line kernel)')

# define the model
inception_line = inc_model(input_shape=input_shape,
                           model_name='inc_line',
                           learning_rate=0.001,
                           filters=[32, 64, 32],
                           kernel_size=[(12,1), (1,15)],
                           dropout=0.2,
                           l1_reg=1.0e-4,
                           l2_reg=1.0e-4,
                           rho=0.5
                          )
inc_line_noout_30 = inception_line.fit(x=mat_noout_train_30,
                                       y=lab_noout_train_30,
                                       batch_size=32,
                                       epochs=2000,
                                       verbose=0,
                                       callbacks=callbacks,
                                       validation_data=(mat_noout_val_30, lab_noout_val_30)
                                      )

# %% [markdown]
# We the take a look at the accuracy of the output:

# %%
import joblib

# predictions
h11_pred = np.rint(inception_line.predict(mat_noout_test_30)['h11_output']).astype(int).reshape(-1,)
h21_pred = np.rint(inception_line.predict(mat_noout_test_30)['h21_output']).astype(int).reshape(-1,)

# true values
h11_true = lab_noout_test_30['h11_output'].astype(int).reshape(-1,)
h21_true = lab_noout_test_30['h21_output'].astype(int).reshape(-1,)

# accuracy
h11_acc = np.mean((h11_pred == h11_true).astype(int))
h21_acc = np.mean((h21_pred == h21_true).astype(int))

# save predictions
predictions = {'h11_pred': h11_pred,
               'h11_true': h11_true,
               'h21_pred': h21_true,
               'h21_true': h21_pred
              }
predictions = pd.DataFrame(predictions)
predictions.to_csv('./dat/inc_line_noout_30.csv')

# save history
joblib.dump(inc_line_noout_30.history, './dat/inc_line_noout_30.pkl')

# print accuracy
print('Accuracy for h_11: {:.2f}%'.format(h11_acc * 100))
print('Accuracy for h_21: {:.2f}%'.format(h21_acc * 100))

# %% [markdown]
# ### 80% Training Data w/ Outliers (square kernel)

# %%
callbacks = [keras.callbacks.ModelCheckpoint('./mod/inception_square_out_80.h5',
                                             monitor='val_loss',
                                             verbose=0,
                                             save_best_only=True
                                            ),
             keras.callbacks.ReduceLROnPlateau(monitor='val_loss',
                                               factor=0.3,
                                               patience=80,
                                               verbose=0,
                                               min_lr=1.0e-6
                                              ),
             keras.callbacks.EarlyStopping(monitor='val_loss',
                                           patience=200,
                                           restore_best_weights=True,
                                           verbose=0
                                          )
            ]

inception_square.summary()

print('Training 80% data w/ outliers (square kernel)')

# define the model
inception_square = inc_model(input_shape=input_shape,
                           model_name='inc_square',
                           learning_rate=0.001,
                           filters=[32, 64, 32],
                           kernel_size=[(3,3), (5,5)],
                           dropout=0.2,
                           l1_reg=1.0e-4,
                           l2_reg=1.0e-4,
                           rho=0.5
                          )
inc_square_out_80 = inception_square.fit(x=mat_out_train_80,
                                         y=lab_out_train_80,
                                         batch_size=32,
                                         epochs=2000,
                                         verbose=0,
                                         callbacks=callbacks,
                                         validation_data=(mat_out_val_80, lab_out_val_80)
                                        )

# %% [markdown]
# We the take a look at the accuracy of the output:

# %%
import joblib

# predictions
h11_pred = np.rint(inception_square.predict(mat_out_test_80)['h11_output']).astype(int).reshape(-1,)
h21_pred = np.rint(inception_square.predict(mat_out_test_80)['h21_output']).astype(int).reshape(-1,)

# true values
h11_true = lab_out_test_80['h11_output'].astype(int).reshape(-1,)
h21_true = lab_out_test_80['h21_output'].astype(int).reshape(-1,)

# accuracy
h11_acc = np.mean((h11_pred == h11_true).astype(int))
h21_acc = np.mean((h21_pred == h21_true).astype(int))

# save predictions
predictions = {'h11_pred': h11_pred,
               'h11_true': h11_true,
               'h21_pred': h21_true,
               'h21_true': h21_pred
              }
predictions = pd.DataFrame(predictions)
predictions.to_csv('./dat/inc_square_out_80.csv')

# save history
joblib.dump(inc_square_out_80.history, './dat/inc_square_out_80.pkl')

# print accuracy
print('Accuracy for h_11: {:.2f}%'.format(h11_acc * 100))
print('Accuracy for h_21: {:.2f}%'.format(h21_acc * 100))

# %% [markdown]
# ### 80% Training Data w/o Outliers (square kernel)

# %%
callbacks = [keras.callbacks.ModelCheckpoint('./mod/inception_square_noout_80.h5',
                                             monitor='val_loss',
                                             verbose=0,
                                             save_best_only=True
                                            ),
             keras.callbacks.ReduceLROnPlateau(monitor='val_loss',
                                               factor=0.3,
                                               patience=80,
                                               verbose=0,
                                               min_lr=1.0e-6
                                              ),
             keras.callbacks.EarlyStopping(monitor='val_loss',
                                           patience=200,
                                           restore_best_weights=True,
                                           verbose=0
                                          )
            ]

inception_square.summary()

print('Training 80% data w/o outliers (square kernel)')

# define the model
inception_square = inc_model(input_shape=input_shape,
                             model_name='inc_square',
                             learning_rate=0.001,
                             filters=[32, 64, 32],
                             kernel_size=[(3,3), (5,5)],
                             dropout=0.2,
                             l1_reg=1.0e-4,
                             l2_reg=1.0e-4,
                             rho=0.5
                            )
inc_square_noout_80 = inception_square.fit(x=mat_noout_train_80,
                                           y=lab_noout_train_80,
                                           batch_size=32,
                                           epochs=2000,
                                           verbose=0,
                                           callbacks=callbacks,
                                           validation_data=(mat_noout_val_80, lab_noout_val_80)
                                          )

# %% [markdown]
# We the take a look at the accuracy of the output:

# %%
import joblib

# predictions
h11_pred = np.rint(inception_square.predict(mat_noout_test_80)['h11_output']).astype(int).reshape(-1,)
h21_pred = np.rint(inception_square.predict(mat_noout_test_80)['h21_output']).astype(int).reshape(-1,)

# true values
h11_true = lab_noout_test_80['h11_output'].astype(int).reshape(-1,)
h21_true = lab_noout_test_80['h21_output'].astype(int).reshape(-1,)

# accuracy
h11_acc = np.mean((h11_pred == h11_true).astype(int))
h21_acc = np.mean((h21_pred == h21_true).astype(int))

# save predictions
predictions = {'h11_pred': h11_pred,
               'h11_true': h11_true,
               'h21_pred': h21_true,
               'h21_true': h21_pred
              }
predictions = pd.DataFrame(predictions)
predictions.to_csv('./dat/inc_square_noout_80.csv')

# save history
joblib.dump(inc_square_noout_80.history, './dat/inc_square_noout_80.pkl')

# print accuracy
print('Accuracy for h_11: {:.2f}%'.format(h11_acc * 100))
print('Accuracy for h_21: {:.2f}%'.format(h21_acc * 100))

# %% [markdown]
# ### 30% Training Data w/ Outliers (square kernel)

# %%
callbacks = [keras.callbacks.ModelCheckpoint('./mod/inception_square_out_30.h5',
                                             monitor='val_loss',
                                             verbose=0,
                                             save_best_only=True
                                            ),
             keras.callbacks.ReduceLROnPlateau(monitor='val_loss',
                                               factor=0.3,
                                               patience=80,
                                               verbose=0,
                                               min_lr=1.0e-6
                                              ),
             keras.callbacks.EarlyStopping(monitor='val_loss',
                                           patience=200,
                                           restore_best_weights=True,
                                           verbose=0
                                          )
            ]

inception_square.summary()

print('Training 30% data w/ outliers (square kernel)')

# define the model
inception_square = inc_model(input_shape=input_shape,
                             model_name='inc_square',
                             learning_rate=0.001,
                             filters=[32, 64, 32],
                             kernel_size=[(3,3), (5,5)],
                             dropout=0.2,
                             l1_reg=1.0e-4,
                             l2_reg=1.0e-4,
                             rho=0.5
                            )
inc_square_out_30 = inception_square.fit(x=mat_out_train_30,
                                         y=lab_out_train_30,
                                         batch_size=32,
                                         epochs=2000,
                                         verbose=0,
                                         callbacks=callbacks,
                                         validation_data=(mat_out_val_30, lab_out_val_30)
                                        )

# %% [markdown]
# We the take a look at the accuracy of the output:

# %%
import joblib

# predictions
h11_pred = np.rint(inception_square.predict(mat_out_test_30)['h11_output']).astype(int).reshape(-1,)
h21_pred = np.rint(inception_square.predict(mat_out_test_30)['h21_output']).astype(int).reshape(-1,)

# true values
h11_true = lab_out_test_30['h11_output'].astype(int).reshape(-1,)
h21_true = lab_out_test_30['h21_output'].astype(int).reshape(-1,)

# accuracy
h11_acc = np.mean((h11_pred == h11_true).astype(int))
h21_acc = np.mean((h21_pred == h21_true).astype(int))

# save predictions
predictions = {'h11_pred': h11_pred,
               'h11_true': h11_true,
               'h21_pred': h21_true,
               'h21_true': h21_pred
              }
predictions = pd.DataFrame(predictions)
predictions.to_csv('./dat/inc_square_out_30.csv')

# save history
joblib.dump(inc_square_out_30.history, './dat/inc_square_out_30.pkl')

# print accuracy
print('Accuracy for h_11: {:.2f}%'.format(h11_acc * 100))
print('Accuracy for h_21: {:.2f}%'.format(h21_acc * 100))

# %% [markdown]
# ### 30% Training Data w/o Outliers (square kernel)

# %%
callbacks = [keras.callbacks.ModelCheckpoint('./mod/inception_square_noout_30.h5',
                                             monitor='val_loss',
                                             verbose=0,
                                             save_best_only=True
                                            ),
             keras.callbacks.ReduceLROnPlateau(monitor='val_loss',
                                               factor=0.3,
                                               patience=80,
                                               verbose=0,
                                               min_lr=1.0e-6
                                              ),
             keras.callbacks.EarlyStopping(monitor='val_loss',
                                           patience=200,
                                           restore_best_weights=True,
                                           verbose=0
                                          )
            ]

inception_square.summary()

print('Training 30% data w/o outliers (square kernel)')

# define the model
inception_square = inc_model(input_shape=input_shape,
                             model_name='inc_square',
                             learning_rate=0.001,
                             filters=[32, 64, 32],
                             kernel_size=[(3,3), (5,5)],
                             dropout=0.2,
                             l1_reg=1.0e-4,
                             l2_reg=1.0e-4,
                             rho=0.5
                            )
inc_square_noout_30 = inception_square.fit(x=mat_noout_train_30,
                                           y=lab_noout_train_30,
                                           batch_size=32,
                                           epochs=2000,
                                           verbose=0,
                                           callbacks=callbacks,
                                           validation_data=(mat_noout_val_30, lab_noout_val_30)
                                          )

# %% [markdown]
# We the take a look at the accuracy of the output:

# %%
import joblib

# predictions
h11_pred = np.rint(inception_square.predict(mat_noout_test_30)['h11_output']).astype(int).reshape(-1,)
h21_pred = np.rint(inception_square.predict(mat_noout_test_30)['h21_output']).astype(int).reshape(-1,)

# true values
h11_true = lab_noout_test_30['h11_output'].astype(int).reshape(-1,)
h21_true = lab_noout_test_30['h21_output'].astype(int).reshape(-1,)

# accuracy
h11_acc = np.mean((h11_pred == h11_true).astype(int))
h21_acc = np.mean((h21_pred == h21_true).astype(int))

# save predictions
predictions = {'h11_pred': h11_pred,
               'h11_true': h11_true,
               'h21_pred': h21_true,
               'h21_true': h21_pred
              }
predictions = pd.DataFrame(predictions)
predictions.to_csv('./dat/inc_square_noout_30.csv')

# save history
joblib.dump(inc_square_noout_30.history, './dat/inc_square_noout_30.pkl')

# print accuracy
print('Accuracy for h_11: {:.2f}%'.format(h11_acc * 100))
print('Accuracy for h_21: {:.2f}%'.format(h21_acc * 100))

# %% [markdown]
# ## Sequential CNN

# %%
from tensorflow import keras

def seq_model(input_shape,
              model_name='sequential',
              learning_rate=0.001,
              filters=[32],
              padding='same',
              kernel_size=(2,2),
              dropout=0.2,
              momentum=0.99,
              l1_reg=0.0,
              l2_reg=0.0,
              rho=0.5
             ):
    
    # reset session
    keras.backend.clear_session()
    
    # define the regularisation factor
    kernel_regularizer = keras.regularizers.l1_l2(l1=l1_reg, l2=l2_reg)
    
    # input of the model
    I = keras.layers.Input(shape=input_shape, name=model_name + '_input')
    x = I
    
    # convolutional layers
    for n in range(len(filters)):
        x = keras.layers.Conv2D(filters=filters[n],
                                kernel_size=kernel_size,
                                padding=padding,
                                kernel_regularizer=kernel_regularizer,
                                activation='relu',
                                name=model_name + '_conv_' + str(n+1)
                               )(x)
        if momentum > 0.0:
            x = keras.layers.BatchNormalization(momentum=momentum,
                                                name=model_name + '_bnorm_' + str(n+1)
                                               )(x)
    
    # dropout layer
    if dropout > 0.0:
        x = keras.layers.Dropout(rate=dropout, name=model_name + '_drop')(x)
        
    # flatten
    x = keras.layers.Flatten(name=model_name + '_flat')(x)
    
    # output
    h11 = keras.layers.Dense(units=1,
                             activation='relu',
                             name='h11_output'
                            )(x)
    h21 = keras.layers.Dense(units=1,
                             activation='relu',
                             name='h21_output'
                            )(x)
    
    # prepare dictionary
    output_layers = {}
    output_layers['h11_output'] = h11
    output_layers['h21_output'] = h21
    
    weights = {'h11_output': rho,
               'h21_output': 1 - rho
              }
    
    # define the model
    model = keras.models.Model(inputs=I, outputs=output_layers, name=model_name)
    model.compile(optimizer=keras.optimizers.Adam(learning_rate=learning_rate),
                  loss='mse',
                  loss_weights=weights,
                  metrics=['mse', 'mae']
                 )
    
    return model

# %% [markdown]
# We then define the model.

# %%
sequential_small = seq_model(input_shape=input_shape,
                             model_name='seq_small',
                             learning_rate=0.01,
                             filters=[180, 100, 40, 20],
                             kernel_size=(3,3),
                             dropout=0.3,
                             l1_reg=1.0e-5,
                             l2_reg=1.0e-5,
                             rho=0.5
                            )
sequential_large = seq_model(input_shape=input_shape,
                             model_name='seq_large',
                             learning_rate=0.01,
                             filters=[180, 100, 40, 20],
                             kernel_size=(5,5),
                             dropout=0.3,
                             l1_reg=1.0e-5,
                             l2_reg=1.0e-5,
                             rho=0.5
                            )

# %% [markdown]
# The model can be visualised using `keras` utility functions:

# %%
#from IPython.display import Image

sequential_dot = keras.utils.model_to_dot(sequential_small,
                                          show_shapes=True,
                                          dpi=150
                                         )
sequential_dot.write_pdf('./img/seq_arch.pdf')
#Image(sequential_dot.create_png(), width=480)

# %% [markdown]
# We then train the model.

# %%
os.makedirs('./dat', exist_ok=True)

# %% [markdown]
# ### 80% Training Data w/ Outliers (small kernel)

# %%
callbacks = [keras.callbacks.ModelCheckpoint('./mod/sequential_small_out_80.h5',
                                             monitor='val_loss',
                                             verbose=0,
                                             save_best_only=True
                                            ),
             keras.callbacks.ReduceLROnPlateau(monitor='val_loss',
                                               factor=0.3,
                                               patience=80,
                                               verbose=0,
                                               min_lr=1.0e-6
                                              ),
             keras.callbacks.EarlyStopping(monitor='val_loss',
                                           patience=200,
                                           restore_best_weights=True,
                                           verbose=0
                                          )
            ]

sequential_small.summary()

print('Training 80% data w/ outliers (small kernel)')

# define the model
sequential_small = seq_model(input_shape=input_shape,
                            model_name='seq_small',
                            learning_rate=0.01,
                            filters=[180, 100, 40, 20],
                            kernel_size=(3,3),
                            dropout=0.3,
                            l1_reg=1.0e-5,
                            l2_reg=1.0e-5,
                            rho=0.5
                           )
seq_small_out_80 = sequential_small.fit(x=mat_out_train_80,
                                        y=lab_out_train_80,
                                        batch_size=32,
                                        epochs=2000,
                                        verbose=0,
                                        callbacks=callbacks,
                                        validation_data=(mat_out_val_80, lab_out_val_80)
                                       )

# %% [markdown]
# We the take a look at the accuracy of the output:

# %%
import joblib

# predictions
h11_pred = np.rint(sequential_small.predict(mat_out_test_80)['h11_output']).astype(int).reshape(-1,)
h21_pred = np.rint(sequential_small.predict(mat_out_test_80)['h21_output']).astype(int).reshape(-1,)

# true values
h11_true = lab_out_test_80['h11_output'].astype(int).reshape(-1,)
h21_true = lab_out_test_80['h21_output'].astype(int).reshape(-1,)

# accuracy
h11_acc = np.mean((h11_pred == h11_true).astype(int))
h21_acc = np.mean((h21_pred == h21_true).astype(int))

# save predictions
predictions = {'h11_pred': h11_pred,
               'h11_true': h11_true,
               'h21_pred': h21_true,
               'h21_true': h21_pred
              }
predictions = pd.DataFrame(predictions)
predictions.to_csv('./dat/seq_small_out_80.csv')

# save history
joblib.dump(seq_small_out_80.history, './dat/seq_small_out_80.pkl')

# print accuracy
print('Accuracy for h_11: {:.2f}%'.format(h11_acc * 100))
print('Accuracy for h_21: {:.2f}%'.format(h21_acc * 100))

# %% [markdown]
# ### 80% Training Data w/o Outliers (small kernel)

# %%
callbacks = [keras.callbacks.ModelCheckpoint('./mod/sequential_small_noout_80.h5',
                                             monitor='val_loss',
                                             verbose=0,
                                             save_best_only=True
                                            ),
             keras.callbacks.ReduceLROnPlateau(monitor='val_loss',
                                               factor=0.3,
                                               patience=80,
                                               verbose=0,
                                               min_lr=1.0e-6
                                              ),
             keras.callbacks.EarlyStopping(monitor='val_loss',
                                           patience=200,
                                           restore_best_weights=True,
                                           verbose=0
                                          )
            ]

sequential_small.summary()

print('Training 80% data w/o outliers (small kernel)')

# define the model
sequential_small = seq_model(input_shape=input_shape,
                             model_name='seq_small',
                             learning_rate=0.01,
                             filters=[180, 100, 40, 20],
                             kernel_size=(3,3),
                             dropout=0.3,
                             l1_reg=1.0e-5,
                             l2_reg=1.0e-5,
                             rho=0.5
                            )
seq_small_noout_80 = sequential_small.fit(x=mat_noout_train_80,
                                          y=lab_noout_train_80,
                                          batch_size=32,
                                          epochs=2000,
                                          verbose=0,
                                          callbacks=callbacks,
                                          validation_data=(mat_noout_val_80, lab_noout_val_80)
                                         )

# %% [markdown]
# We the take a look at the accuracy of the output:

# %%
import joblib

# predictions
h11_pred = np.rint(sequential_small.predict(mat_noout_test_80)['h11_output']).astype(int).reshape(-1,)
h21_pred = np.rint(sequential_small.predict(mat_noout_test_80)['h21_output']).astype(int).reshape(-1,)

# true values
h11_true = lab_noout_test_80['h11_output'].astype(int).reshape(-1,)
h21_true = lab_noout_test_80['h21_output'].astype(int).reshape(-1,)

# accuracy
h11_acc = np.mean((h11_pred == h11_true).astype(int))
h21_acc = np.mean((h21_pred == h21_true).astype(int))

# save predictions
predictions = {'h11_pred': h11_pred,
               'h11_true': h11_true,
               'h21_pred': h21_true,
               'h21_true': h21_pred
              }
predictions = pd.DataFrame(predictions)
predictions.to_csv('./dat/seq_small_noout_80.csv')

# save history
joblib.dump(seq_small_noout_80.history, './dat/seq_small_noout_80.pkl')

# print accuracy
print('Accuracy for h_11: {:.2f}%'.format(h11_acc * 100))
print('Accuracy for h_21: {:.2f}%'.format(h21_acc * 100))

# %% [markdown]
# ### 30% Training Data w/ Outliers (small kernel)

# %%
callbacks = [keras.callbacks.ModelCheckpoint('./mod/sequential_small_out_30.h5',
                                             monitor='val_loss',
                                             verbose=0,
                                             save_best_only=True
                                            ),
             keras.callbacks.ReduceLROnPlateau(monitor='val_loss',
                                               factor=0.3,
                                               patience=80,
                                               verbose=0,
                                               min_lr=1.0e-6
                                              ),
             keras.callbacks.EarlyStopping(monitor='val_loss',
                                           patience=200,
                                           restore_best_weights=True,
                                           verbose=0
                                          )
            ]

sequential_small.summary()

print('Training 30% data w/ outliers (small kernel)')

# define the model
sequential_small = seq_model(input_shape=input_shape,
                             model_name='seq_small',
                             learning_rate=0.01,
                             filters=[180, 100, 40, 20],
                             kernel_size=(3,3),
                             dropout=0.3,
                             l1_reg=1.0e-5,
                             l2_reg=1.0e-5,
                             rho=0.5
                            )
seq_small_out_30 = sequential_small.fit(x=mat_out_train_30,
                                        y=lab_out_train_30,
                                        batch_size=32,
                                        epochs=2000,
                                        verbose=0,
                                        callbacks=callbacks,
                                        validation_data=(mat_out_val_30, lab_out_val_30)
                                       )

# %% [markdown]
# We the take a look at the accuracy of the output:

# %%
import joblib

# predictions
h11_pred = np.rint(sequential_small.predict(mat_out_test_30)['h11_output']).astype(int).reshape(-1,)
h21_pred = np.rint(sequential_small.predict(mat_out_test_30)['h21_output']).astype(int).reshape(-1,)

# true values
h11_true = lab_out_test_30['h11_output'].astype(int).reshape(-1,)
h21_true = lab_out_test_30['h21_output'].astype(int).reshape(-1,)

# accuracy
h11_acc = np.mean((h11_pred == h11_true).astype(int))
h21_acc = np.mean((h21_pred == h21_true).astype(int))

# save predictions
predictions = {'h11_pred': h11_pred,
               'h11_true': h11_true,
               'h21_pred': h21_true,
               'h21_true': h21_pred
              }
predictions = pd.DataFrame(predictions)
predictions.to_csv('./dat/seq_small_out_30.csv')

# save history
joblib.dump(seq_small_out_30.history, './dat/seq_small_out_30.pkl')

# print accuracy
print('Accuracy for h_11: {:.2f}%'.format(h11_acc * 100))
print('Accuracy for h_21: {:.2f}%'.format(h21_acc * 100))

# %% [markdown]
# ### 30% Training Data w/o Outliers (small kernel)

# %%
callbacks = [keras.callbacks.ModelCheckpoint('./mod/sequential_small_noout_30.h5',
                                             monitor='val_loss',
                                             verbose=0,
                                             save_best_only=True
                                            ),
             keras.callbacks.ReduceLROnPlateau(monitor='val_loss',
                                               factor=0.3,
                                               patience=80,
                                               verbose=0,
                                               min_lr=1.0e-6
                                              ),
             keras.callbacks.EarlyStopping(monitor='val_loss',
                                           patience=200,
                                           restore_best_weights=True,
                                           verbose=0
                                          )
            ]

sequential_small.summary()

print('Training 30% data w/o outliers (small kernel)')

# define the model
sequential_small = seq_model(input_shape=input_shape,
                             model_name='seq_small',
                             learning_rate=0.01,
                             filters=[180, 100, 40, 20],
                             kernel_size=(3,3),
                             dropout=0.3,
                             l1_reg=1.0e-5,
                             l2_reg=1.0e-5,
                             rho=0.5
                            )
seq_small_noout_30 = sequential_small.fit(x=mat_noout_train_30,
                                          y=lab_noout_train_30,
                                          batch_size=32,
                                          epochs=2000,
                                          verbose=0,
                                          callbacks=callbacks,
                                          validation_data=(mat_noout_val_30, lab_noout_val_30)
                                         )

# %% [markdown]
# We the take a look at the accuracy of the output:

# %%
import joblib

# predictions
h11_pred = np.rint(sequential_small.predict(mat_noout_test_30)['h11_output']).astype(int).reshape(-1,)
h21_pred = np.rint(sequential_small.predict(mat_noout_test_30)['h21_output']).astype(int).reshape(-1,)

# true values
h11_true = lab_noout_test_30['h11_output'].astype(int).reshape(-1,)
h21_true = lab_noout_test_30['h21_output'].astype(int).reshape(-1,)

# accuracy
h11_acc = np.mean((h11_pred == h11_true).astype(int))
h21_acc = np.mean((h21_pred == h21_true).astype(int))

# save predictions
predictions = {'h11_pred': h11_pred,
               'h11_true': h11_true,
               'h21_pred': h21_true,
               'h21_true': h21_pred
              }
predictions = pd.DataFrame(predictions)
predictions.to_csv('./dat/seq_small_noout_30.csv')

# save history
joblib.dump(seq_small_noout_30.history, './dat/seq_small_noout_30.pkl')

# print accuracy
print('Accuracy for h_11: {:.2f}%'.format(h11_acc * 100))
print('Accuracy for h_21: {:.2f}%'.format(h21_acc * 100))

# %% [markdown]
# ### 80% Training Data w/ Outliers (large kernel)

# %%
callbacks = [keras.callbacks.ModelCheckpoint('./mod/sequential_large_out_80.h5',
                                             monitor='val_loss',
                                             verbose=0,
                                             save_best_only=True
                                            ),
             keras.callbacks.ReduceLROnPlateau(monitor='val_loss',
                                               factor=0.3,
                                               patience=80,
                                               verbose=0,
                                               min_lr=1.0e-6
                                              ),
             keras.callbacks.EarlyStopping(monitor='val_loss',
                                           patience=200,
                                           restore_best_weights=True,
                                           verbose=0
                                          )
            ]

sequential_large.summary()

print('Training 80% data w/ outliers (large kernel)')

# define the model
sequential_large = seq_model(input_shape=input_shape,
                             model_name='seq_large',
                             learning_rate=0.01,
                             filters=[180, 100, 40, 20],
                             kernel_size=(5,5),
                             dropout=0.3,
                             l1_reg=1.0e-5,
                             l2_reg=1.0e-5,
                             rho=0.5
                            )
seq_large_out_80 = sequential_large.fit(x=mat_out_train_80,
                                        y=lab_out_train_80,
                                        batch_size=32,
                                        epochs=2000,
                                        verbose=0,
                                        callbacks=callbacks,
                                        validation_data=(mat_out_val_80, lab_out_val_80)
                                       )

# %% [markdown]
# We the take a look at the accuracy of the output:

# %%
import joblib

# predictions
h11_pred = np.rint(sequential_large.predict(mat_out_test_80)['h11_output']).astype(int).reshape(-1,)
h21_pred = np.rint(sequential_large.predict(mat_out_test_80)['h21_output']).astype(int).reshape(-1,)

# true values
h11_true = lab_out_test_80['h11_output'].astype(int).reshape(-1,)
h21_true = lab_out_test_80['h21_output'].astype(int).reshape(-1,)

# accuracy
h11_acc = np.mean((h11_pred == h11_true).astype(int))
h21_acc = np.mean((h21_pred == h21_true).astype(int))

# save predictions
predictions = {'h11_pred': h11_pred,
               'h11_true': h11_true,
               'h21_pred': h21_true,
               'h21_true': h21_pred
              }
predictions = pd.DataFrame(predictions)
predictions.to_csv('./dat/seq_large_out_80.csv')

# save history
joblib.dump(seq_large_out_80.history, './dat/seq_large_out_80.pkl')

# print accuracy
print('Accuracy for h_11: {:.2f}%'.format(h11_acc * 100))
print('Accuracy for h_21: {:.2f}%'.format(h21_acc * 100))

# %% [markdown]
# ### 80% Training Data w/o Outliers (large kernel)

# %%
callbacks = [keras.callbacks.ModelCheckpoint('./mod/sequential_large_noout_80.h5',
                                             monitor='val_loss',
                                             verbose=0,
                                             save_best_only=True
                                            ),
             keras.callbacks.ReduceLROnPlateau(monitor='val_loss',
                                               factor=0.3,
                                               patience=80,
                                               verbose=0,
                                               min_lr=1.0e-6
                                              ),
             keras.callbacks.EarlyStopping(monitor='val_loss',
                                           patience=200,
                                           restore_best_weights=True,
                                           verbose=0
                                          )
            ]

sequential_large.summary()

print('Training 80% data w/o outliers (large kernel)')

# define the model
sequential_large = seq_model(input_shape=input_shape,
                             model_name='seq_large',
                             learning_rate=0.01,
                             filters=[180, 100, 40, 20],
                             kernel_size=(5,5),
                             dropout=0.3,
                             l1_reg=1.0e-5,
                             l2_reg=1.0e-5,
                             rho=0.5
                            )
seq_large_noout_80 = sequential_large.fit(x=mat_noout_train_80,
                                          y=lab_noout_train_80,
                                          batch_size=32,
                                          epochs=2000,
                                          verbose=0,
                                          callbacks=callbacks,
                                          validation_data=(mat_noout_val_80, lab_noout_val_80)
                                         )

# %% [markdown]
# We the take a look at the accuracy of the output:

# %%
import joblib

# predictions
h11_pred = np.rint(sequential_large.predict(mat_noout_test_80)['h11_output']).astype(int).reshape(-1,)
h21_pred = np.rint(sequential_large.predict(mat_noout_test_80)['h21_output']).astype(int).reshape(-1,)

# true values
h11_true = lab_noout_test_80['h11_output'].astype(int).reshape(-1,)
h21_true = lab_noout_test_80['h21_output'].astype(int).reshape(-1,)

# accuracy
h11_acc = np.mean((h11_pred == h11_true).astype(int))
h21_acc = np.mean((h21_pred == h21_true).astype(int))

# save predictions
predictions = {'h11_pred': h11_pred,
               'h11_true': h11_true,
               'h21_pred': h21_true,
               'h21_true': h21_pred
              }
predictions = pd.DataFrame(predictions)
predictions.to_csv('./dat/seq_large_noout_80.csv')

# save history
joblib.dump(seq_large_noout_80.history, './dat/seq_large_noout_80.pkl')

# print accuracy
print('Accuracy for h_11: {:.2f}%'.format(h11_acc * 100))
print('Accuracy for h_21: {:.2f}%'.format(h21_acc * 100))

# %% [markdown]
# ### 30% Training Data w/ Outliers (large kernel)

# %%
callbacks = [keras.callbacks.ModelCheckpoint('./mod/sequential_large_out_30.h5',
                                             monitor='val_loss',
                                             verbose=0,
                                             save_best_only=True
                                            ),
             keras.callbacks.ReduceLROnPlateau(monitor='val_loss',
                                               factor=0.3,
                                               patience=80,
                                               verbose=0,
                                               min_lr=1.0e-6
                                              ),
             keras.callbacks.EarlyStopping(monitor='val_loss',
                                           patience=200,
                                           restore_best_weights=True,
                                           verbose=0
                                          )
            ]

sequential_large.summary()

print('Training 30% data w/ outliers (large kernel)')

# define the model
sequential_large = seq_model(input_shape=input_shape,
                             model_name='seq_large',
                             learning_rate=0.01,
                             filters=[180, 100, 40, 20],
                             kernel_size=(5,5),
                             dropout=0.3,
                             l1_reg=1.0e-5,
                             l2_reg=1.0e-5,
                             rho=0.5
                            )
seq_large_out_30 = sequential_large.fit(x=mat_out_train_30,
                                        y=lab_out_train_30,
                                        batch_size=32,
                                        epochs=2000,
                                        verbose=0,
                                        callbacks=callbacks,
                                        validation_data=(mat_out_val_30, lab_out_val_30)
                                       )

# %% [markdown]
# We the take a look at the accuracy of the output:

# %%
import joblib

# predictions
h11_pred = np.rint(sequential_large.predict(mat_out_test_30)['h11_output']).astype(int).reshape(-1,)
h21_pred = np.rint(sequential_large.predict(mat_out_test_30)['h21_output']).astype(int).reshape(-1,)

# true values
h11_true = lab_out_test_30['h11_output'].astype(int).reshape(-1,)
h21_true = lab_out_test_30['h21_output'].astype(int).reshape(-1,)

# accuracy
h11_acc = np.mean((h11_pred == h11_true).astype(int))
h21_acc = np.mean((h21_pred == h21_true).astype(int))

# save predictions
predictions = {'h11_pred': h11_pred,
               'h11_true': h11_true,
               'h21_pred': h21_true,
               'h21_true': h21_pred
              }
predictions = pd.DataFrame(predictions)
predictions.to_csv('./dat/seq_large_out_30.csv')

# save history
joblib.dump(seq_large_out_30.history, './dat/seq_large_out_30.pkl')

# print accuracy
print('Accuracy for h_11: {:.2f}%'.format(h11_acc * 100))
print('Accuracy for h_21: {:.2f}%'.format(h21_acc * 100))

# %% [markdown]
# ### 30% Training Data w/o Outliers (large kernel)

# %%
callbacks = [keras.callbacks.ModelCheckpoint('./mod/sequential_large_noout_30.h5',
                                             monitor='val_loss',
                                             verbose=0,
                                             save_best_only=True
                                            ),
             keras.callbacks.ReduceLROnPlateau(monitor='val_loss',
                                               factor=0.3,
                                               patience=80,
                                               verbose=0,
                                               min_lr=1.0e-6
                                              ),
             keras.callbacks.EarlyStopping(monitor='val_loss',
                                           patience=200,
                                           restore_best_weights=True,
                                           verbose=0
                                          )
            ]

sequential_large.summary()

print('Training 30% data w/o outliers (large kernel)')

# define the model
sequential_large = seq_model(input_shape=input_shape,
                             model_name='seq_large',
                             learning_rate=0.01,
                             filters=[180, 100, 40, 20],
                             kernel_size=(5,5),
                             dropout=0.3,
                             l1_reg=1.0e-5,
                             l2_reg=1.0e-5,
                             rho=0.5
                            )
seq_large_noout_30 = sequential_large.fit(x=mat_noout_train_30,
                                          y=lab_noout_train_30,
                                          batch_size=32,
                                          epochs=2000,
                                          verbose=0,
                                          callbacks=callbacks,
                                          validation_data=(mat_noout_val_30, lab_noout_val_30)
                                         )

# %% [markdown]
# We the take a look at the accuracy of the output:

# %%
import joblib

# predictions
h11_pred = np.rint(sequential_large.predict(mat_noout_test_30)['h11_output']).astype(int).reshape(-1,)
h21_pred = np.rint(sequential_large.predict(mat_noout_test_30)['h21_output']).astype(int).reshape(-1,)

# true values
h11_true = lab_noout_test_30['h11_output'].astype(int).reshape(-1,)
h21_true = lab_noout_test_30['h21_output'].astype(int).reshape(-1,)

# accuracy
h11_acc = np.mean((h11_pred == h11_true).astype(int))
h21_acc = np.mean((h21_pred == h21_true).astype(int))

# save predictions
predictions = {'h11_pred': h11_pred,
               'h11_true': h11_true,
               'h21_pred': h21_true,
               'h21_true': h21_pred
              }
predictions = pd.DataFrame(predictions)
predictions.to_csv('./dat/seq_large_noout_30.csv')

# save history
joblib.dump(seq_large_noout_30.history, './dat/seq_large_noout_30.pkl')

# print accuracy
print('Accuracy for h_11: {:.2f}%'.format(h11_acc * 100))
print('Accuracy for h_21: {:.2f}%'.format(h21_acc * 100))
