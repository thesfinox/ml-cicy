# %% [markdown]
# # Machine Learning for CICY 3-Folds
#
# We compute the Hodge numbers of CICY 3-folds using deep learning techniques inspired by the Inception architecture by Google.

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import tarfile
import urllib
import json
import joblib
from IPython.display import Image
from nntools import *

# %%
random_state = 123
np.random.seed(random_state)
tf.random.set_seed(random_state)

# %% [markdown]
# ## Create a Saving Directory
#
# Each model will be assigned to a different directory based on the time of running.

# %%
img_dir, mod_dir = dir_struct('inception_h11_h21', dirs=['img', 'models'])
# Out:
# Current working directories:
#
#   ./img/inception_h11_h21_20201221_193006
#   ./models/inception_h11_h21_20201221_193006

# %% [markdown]
# ## Load the Dataset
#
# We then download the JSON file containing the configuration matrix and the Hodge numbers of the CICY.

# %%
os.makedirs('./data', exist_ok=True)

urllib.request.urlretrieve('http://www.lpthe.jussieu.fr/~erbin/files/data/cicy3o_data.tar.gz', './data/cicy3o_data.tar.gz')
with tarfile.open('./data/cicy3o_data.tar.gz', 'r') as tar:
    tar.extract('cicy3o.h5', path='./data')

# %%
df, (n_rows, n_cols) = load_hdf('./data/cicy3o.h5')
# Out:
# Size of the dataset: 7890 rows, 31 columns.

# %% [markdown]
# We then select only the non product spaces:

# %%
df = df.loc[df['isprod'] == False]

# %% [markdown]
# We the pad the matrix to get the same size for all configuration matrices:

# %%
max_size = df['matrix'].apply(np.shape).max()

df.loc[:, 'matrix'] = df['matrix'].apply(lambda x: np.pad(x, ((0, max_size[0] - np.shape(x)[0]), (0, max_size[1] - np.shape(x)[1]))))
df = df[['h11', 'h21', 'matrix']]
n_rows, n_cols = df.shape

# %%
num_classes = (int(df['h11'].max() + 1), int(df['h21'].max() + 1))

# %% [markdown]
# We then split it into train, validation and test sets:

# %%
df_splits = {'train_split': 0.80, 'val_split': 0.5}
with open(os.path.join(mod_dir, 'train_ratio.json'), 'w') as f:
    json.dump(df_splits, f)

# split the sets
(df_train, df_val, df_test), (n_train, n_val, n_test) = train_test(df, df_splits, random_state=random_state)

# %%
del df

# %% [markdown]
# ## Outliers in the Training Set
#
# We then study the outliers in the training set:

# %%
# remove outliers
df_train = df_train.loc[(df_train['h11'] >= 1) & (df_train['h11'] <= 16)
                        &
                        (df_train['h21'] >= 15) & (df_train['h21'] <= 86)
                       ]
n_train_pruned = df_train.shape[0]

# %%
print(f'Samples removed: {n_train - n_train_pruned:d} ({100 * (n_train - n_train_pruned) / n_train:.2f}% of the training set, {100 * (n_train - n_train_pruned) / n_rows:.2f}% of the total set)')
# Out:
# Samples removed: 12 (0.19% of the training set, 0.15% of the total set)

# %% [markdown]
# ## Rescale the Matrices
#
# We then rescale the matrices in the sets to improve the deep learning results:

# %%
# rescaling = {'min': df_train['matrix'].apply(lambda x: np.min(x)).min(),
#              'max': df_train['matrix'].apply(lambda x: np.max(x)).max()
#             }
rescaling = None

# %% [markdown]
# ## Feature and Label Creation
#
# We then create the features and the labels.

# %%
reshape = df_train['matrix'].apply(np.shape).max() + (1,)

# %%
X_train = create_features(df_train['matrix'], rescaling=rescaling, reshape=reshape)
X_val   = create_features(df_val['matrix'], rescaling=rescaling, reshape=reshape)
X_test  = create_features(df_test['matrix'], rescaling=rescaling, reshape=reshape)

# %%
y_train = create_labels(df_train[['h11', 'h21']], one_hot=True, num_classes=list(num_classes))
y_val   = create_labels(df_val[['h11', 'h21']], one_hot=True, num_classes=list(num_classes))
y_test  = create_labels(df_test[['h11', 'h21']], one_hot=True, num_classes=list(num_classes))

# %%
del df_train, df_val, df_test

# %% [markdown]
# ## Inception Model
#
# We then start to build the Inception model to be trained on the configuration matrices.

# %% [markdown]
# ### Build the Model

# %%
model_data = {'input_shape':   reshape,
              'name':          'matrix',
              'learning_rate': 1.0e-3,
              'output_names':  ['h11', 'h21'],
              'output_size':   list(num_classes),
              'model_type':    'classification',
              'conv_1b1':      False,
              'conv_layers':   [32, 64, 32],
              'conv_alpha':    0.0,
              'conv_class':    None,
              'conv_single':   False,
              'conv_red':      0,
              'feat_map':      0,
              'recurrent':     False,
              'fc_layers':     [],
              'fc_alpha':      0.0,
              'dropout':       0.0,
              'full_dropout':  0.05,
              'batchnorm':     0.99,
              'last_relu':     False,
              'loss_weights':  [0.5, 0.5],
              'l1_reg':        1.0e-3,
              'l2_reg':        1.0e-4,
              'output_layers': True,
              'random_state':  random_state
             }

with open(os.path.join(mod_dir, 'model_data.json'), 'w') as f:
    json.dump(model_data, f)

# %%
inception = nn_inception(**model_data)
inception.summary()
# Out:
# Model: "matrix"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# matrix (InputLayer)             [(None, 12, 15, 1)]  0
# __________________________________________________________________________________________________
# matrix_convAa_0 (Conv2D)        (None, 12, 15, 32)   416         matrix[0][0]
# __________________________________________________________________________________________________
# matrix_convAb_0 (Conv2D)        (None, 12, 15, 32)   512         matrix[0][0]
# __________________________________________________________________________________________________
# matrix_actAa_0 (LeakyReLU)      (None, 12, 15, 32)   0           matrix_convAa_0[0][0]
# __________________________________________________________________________________________________
# matrix_actAb_0 (LeakyReLU)      (None, 12, 15, 32)   0           matrix_convAb_0[0][0]
# __________________________________________________________________________________________________
# matrix_cat_0 (Concatenate)      (None, 12, 15, 64)   0           matrix_actAa_0[0][0]
#                                                                  matrix_actAb_0[0][0]
# __________________________________________________________________________________________________
# matrix_convBN_0 (BatchNormaliza (None, 12, 15, 64)   256         matrix_cat_0[0][0]
# __________________________________________________________________________________________________
# matrix_convFullDrop_0 (Dropout) (None, 12, 15, 64)   0           matrix_convBN_0[0][0]
# __________________________________________________________________________________________________
# matrix_convAa_1 (Conv2D)        (None, 12, 15, 64)   49216       matrix_convFullDrop_0[0][0]
# __________________________________________________________________________________________________
# matrix_convAb_1 (Conv2D)        (None, 12, 15, 64)   61504       matrix_convFullDrop_0[0][0]
# __________________________________________________________________________________________________
# matrix_actAa_1 (LeakyReLU)      (None, 12, 15, 64)   0           matrix_convAa_1[0][0]
# __________________________________________________________________________________________________
# matrix_actAb_1 (LeakyReLU)      (None, 12, 15, 64)   0           matrix_convAb_1[0][0]
# __________________________________________________________________________________________________
# matrix_cat_1 (Concatenate)      (None, 12, 15, 128)  0           matrix_actAa_1[0][0]
#                                                                  matrix_actAb_1[0][0]
# __________________________________________________________________________________________________
# matrix_convBN_1 (BatchNormaliza (None, 12, 15, 128)  512         matrix_cat_1[0][0]
# __________________________________________________________________________________________________
# matrix_convFullDrop_1 (Dropout) (None, 12, 15, 128)  0           matrix_convBN_1[0][0]
# __________________________________________________________________________________________________
# matrix_convAa_2 (Conv2D)        (None, 12, 15, 32)   49184       matrix_convFullDrop_1[0][0]
# __________________________________________________________________________________________________
# matrix_convAb_2 (Conv2D)        (None, 12, 15, 32)   61472       matrix_convFullDrop_1[0][0]
# __________________________________________________________________________________________________
# matrix_actAa_2 (LeakyReLU)      (None, 12, 15, 32)   0           matrix_convAa_2[0][0]
# __________________________________________________________________________________________________
# matrix_actAb_2 (LeakyReLU)      (None, 12, 15, 32)   0           matrix_convAb_2[0][0]
# __________________________________________________________________________________________________
# matrix_cat_2 (Concatenate)      (None, 12, 15, 64)   0           matrix_actAa_2[0][0]
#                                                                  matrix_actAb_2[0][0]
# __________________________________________________________________________________________________
# matrix_convBN_2 (BatchNormaliza (None, 12, 15, 64)   256         matrix_cat_2[0][0]
# __________________________________________________________________________________________________
# matrix_convFullDrop_2 (Dropout) (None, 12, 15, 64)   0           matrix_convBN_2[0][0]
# __________________________________________________________________________________________________
# matrix_flat (Flatten)           (None, 11520)        0           matrix_convFullDrop_2[0][0]
# __________________________________________________________________________________________________
# h11 (Dense)                     (None, 20)           230420      matrix_flat[0][0]
# __________________________________________________________________________________________________
# h21 (Dense)                     (None, 102)          1175142     matrix_flat[0][0]
# ==================================================================================================
# Total params: 1,628,890
# Trainable params: 1,628,378
# Non-trainable params: 512
# __________________________________________________________________________________________________

# %%
inception_graph = keras.utils.model_to_dot(inception, show_shapes=True, dpi=144)
inception_graph.write_pdf(os.path.join(img_dir, 'inception.pdf'))
Image(inception_graph.create_png(), width=480)

# %% [markdown]
# ### Train the Model

# %%
fit_data = {'epochs':             1000,
            'batch_size':         32,
            'reduce_lr_factor':   0.3,
            'reduce_lr_patience': 350,
            'stat_interval':      100
           }

with open(os.path.join(mod_dir, 'fit_data.json'), 'w') as f:
    json.dump(fit_data, f)

# %%
callbacks = model_checkpoints(outputs=['h11', 'h21'],
                              root=mod_dir,
                              validation=True,
                              reduce_lr=fit_data['reduce_lr_factor'],
                              lr_patience=fit_data['reduce_lr_patience'],
                              summary=fit_data['stat_interval']
                             )

inception_hst = inception.fit(x=X_train,
                              y=y_train,
                              batch_size=fit_data['batch_size'],
                              epochs=fit_data['epochs'],
                              verbose=0,
                              callbacks=callbacks,
                              validation_data=(X_val, y_val)
                             )
# Out:
# Training has started. Callouts will be printed every 50 epochs.
#
# Training epoch 1. Started on 21/12/2020 at 19:46:22.
#
#     Average epoch training time: 00 hours, 00 minutes, 24 seconds
#
#     loss = 12.196442
#     h11_loss = 1.750838
#     h21_loss = 4.525281
#     h11_categorical_accuracy = 0.573225
#     h21_categorical_accuracy = 0.114136
#     val_loss = 14.787118
#     val_h11_loss = 4.481276
#     val_h21_loss = 5.063094
#     val_h11_categorical_accuracy = 0.053367
#     val_h21_categorical_accuracy = 0.000000
#     lr = 0.001000
#
# Training epoch 50. Started on 21/12/2020 at 19:47:27.
#
#     Average epoch training time: 00 hours, 00 minutes, 12 seconds
#
#     loss = 1.578848
#     h11_loss = 0.048078
#     h21_loss = 0.257131
#     h11_categorical_accuracy = 0.982330
#     h21_categorical_accuracy = 0.914040
#     val_loss = 8.027822
#     val_h11_loss = 1.135138
#     val_h21_loss = 5.613912
#     val_h11_categorical_accuracy = 0.824651
#     val_h21_categorical_accuracy = 0.260483
#     lr = 0.001000
#
# Training epoch 100. Started on 21/12/2020 at 19:48:09.
#
#     Average epoch training time: 00 hours, 00 minutes, 08 seconds
#
#     loss = 1.120501
#     h11_loss = 0.034163
#     h21_loss = 0.149290
#     h11_categorical_accuracy = 0.988857
#     h21_categorical_accuracy = 0.951926
#     val_loss = 9.945713
#     val_h11_loss = 1.547984
#     val_h21_loss = 7.444413
#     val_h11_categorical_accuracy = 0.820839
#     val_h21_categorical_accuracy = 0.265565
#     lr = 0.001000
#
# Training epoch 150. Started on 21/12/2020 at 19:48:51.
#
#     Average epoch training time: 00 hours, 00 minutes, 06 seconds
#
#     loss = 0.986922
#     h11_loss = 0.027497
#     h21_loss = 0.150073
#     h11_categorical_accuracy = 0.991882
#     h21_categorical_accuracy = 0.953677
#     val_loss = 9.054210
#     val_h11_loss = 1.399500
#     val_h21_loss = 6.815752
#     val_h11_categorical_accuracy = 0.817027
#     val_h21_categorical_accuracy = 0.260483
#     lr = 0.001000
#
# Training epoch 200. Started on 21/12/2020 at 19:49:32.
#
#     Average epoch training time: 00 hours, 00 minutes, 05 seconds
#
#     loss = 0.429792
#     h11_loss = 0.007358
#     h21_loss = 0.046659
#     h11_categorical_accuracy = 0.997453
#     h21_categorical_accuracy = 0.983604
#     val_loss = 9.630097
#     val_h11_loss = 1.677369
#     val_h21_loss = 7.567690
#     val_h11_categorical_accuracy = 0.829733
#     val_h21_categorical_accuracy = 0.274460
#     lr = 0.000300
#
# Training epoch 250. Started on 21/12/2020 at 19:50:14.
#
#     Average epoch training time: 00 hours, 00 minutes, 04 seconds
#
#     loss = 0.391476
#     h11_loss = 0.014789
#     h21_loss = 0.035636
#     h11_categorical_accuracy = 0.993792
#     h21_categorical_accuracy = 0.988698
#     val_loss = 10.833074
#     val_h11_loss = 1.770090
#     val_h21_loss = 8.713080
#     val_h11_categorical_accuracy = 0.839898
#     val_h21_categorical_accuracy = 0.266836
#     lr = 0.000300
#
# Training epoch 300. Started on 21/12/2020 at 19:50:56.
#
#     Average epoch training time: 00 hours, 00 minutes, 04 seconds
#
#     loss = 0.381796
#     h11_loss = 0.009468
#     h21_loss = 0.044472
#     h11_categorical_accuracy = 0.996180
#     h21_categorical_accuracy = 0.986310
#     val_loss = 10.521929
#     val_h11_loss = 1.770320
#     val_h21_loss = 8.415832
#     val_h11_categorical_accuracy = 0.828463
#     val_h21_categorical_accuracy = 0.266836
#     lr = 0.000300
#
# Training epoch 350. Started on 21/12/2020 at 19:51:38.
#
#     Average epoch training time: 00 hours, 00 minutes, 03 seconds
#
#     loss = 0.206098
#     h11_loss = 0.005596
#     h21_loss = 0.011066
#     h11_categorical_accuracy = 0.998249
#     h21_categorical_accuracy = 0.997294
#     val_loss = 10.246591
#     val_h11_loss = 1.707130
#     val_h21_loss = 8.348773
#     val_h11_categorical_accuracy = 0.834816
#     val_h21_categorical_accuracy = 0.271919
#     lr = 0.000090
#
# Training epoch 400. Started on 21/12/2020 at 19:52:20.
#
#     Average epoch training time: 00 hours, 00 minutes, 03 seconds
#
#     loss = 0.189240
#     h11_loss = 0.002292
#     h21_loss = 0.013865
#     h11_categorical_accuracy = 0.999682
#     h21_categorical_accuracy = 0.995384
#     val_loss = 10.574974
#     val_h11_loss = 1.796787
#     val_h21_loss = 8.604919
#     val_h11_categorical_accuracy = 0.839898
#     val_h21_categorical_accuracy = 0.278272
#     lr = 0.000090
#
# Training epoch 450. Started on 21/12/2020 at 19:53:02.
#
#     Average epoch training time: 00 hours, 00 minutes, 03 seconds
#
#     loss = 0.185629
#     h11_loss = 0.004125
#     h21_loss = 0.013187
#     h11_categorical_accuracy = 0.998727
#     h21_categorical_accuracy = 0.995543
#     val_loss = 10.840440
#     val_h11_loss = 1.858493
#     val_h21_loss = 8.814191
#     val_h11_categorical_accuracy = 0.829733
#     val_h21_categorical_accuracy = 0.275731
#     lr = 0.000090
#
# Training epoch 500. Started on 21/12/2020 at 19:53:44.
#
#     Average epoch training time: 00 hours, 00 minutes, 02 seconds
#
#     loss = 0.137518
#     h11_loss = 0.002034
#     h21_loss = 0.007762
#     h11_categorical_accuracy = 0.999522
#     h21_categorical_accuracy = 0.998249
#     val_loss = 10.784745
#     val_h11_loss = 1.875705
#     val_h21_loss = 8.781139
#     val_h11_categorical_accuracy = 0.836086
#     val_h21_categorical_accuracy = 0.278272
#     lr = 0.000027
#
# Training epoch 550. Started on 21/12/2020 at 19:54:26.
#
#     Average epoch training time: 00 hours, 00 minutes, 02 seconds
#
#     loss = 0.130277
#     h11_loss = 0.002510
#     h21_loss = 0.007541
#     h11_categorical_accuracy = 0.999363
#     h21_categorical_accuracy = 0.997612
#     val_loss = 10.663886
#     val_h11_loss = 1.840994
#     val_h21_loss = 8.702231
#     val_h11_categorical_accuracy = 0.822109
#     val_h21_categorical_accuracy = 0.283355
#     lr = 0.000027
#
# Training epoch 600. Started on 21/12/2020 at 19:55:07.
#
#     Average epoch training time: 00 hours, 00 minutes, 02 seconds
#
#     loss = 0.127199
#     h11_loss = 0.002320
#     h21_loss = 0.008911
#     h11_categorical_accuracy = 0.999363
#     h21_categorical_accuracy = 0.996975
#     val_loss = 10.613053
#     val_h11_loss = 1.824718
#     val_h21_loss = 8.671907
#     val_h11_categorical_accuracy = 0.831004
#     val_h21_categorical_accuracy = 0.282084
#     lr = 0.000027
#
# Training epoch 650. Started on 21/12/2020 at 19:55:49.
#
#     Average epoch training time: 00 hours, 00 minutes, 02 seconds
#
#     loss = 0.112942
#     h11_loss = 0.001639
#     h21_loss = 0.006075
#     h11_categorical_accuracy = 0.999682
#     h21_categorical_accuracy = 0.999204
#     val_loss = 10.462076
#     val_h11_loss = 1.802955
#     val_h21_loss = 8.553881
#     val_h11_categorical_accuracy = 0.828463
#     val_h21_categorical_accuracy = 0.284625
#     lr = 0.000008
#
# Training epoch 700. Started on 21/12/2020 at 19:56:31.
#
#     Average epoch training time: 00 hours, 00 minutes, 02 seconds
#
#     loss = 0.112660
#     h11_loss = 0.001628
#     h21_loss = 0.008221
#     h11_categorical_accuracy = 0.999522
#     h21_categorical_accuracy = 0.996498
#     val_loss = 10.462229
#     val_h11_loss = 1.789787
#     val_h21_loss = 8.569572
#     val_h11_categorical_accuracy = 0.829733
#     val_h21_categorical_accuracy = 0.277001
#     lr = 0.000008
#
# Training epoch 750. Started on 21/12/2020 at 19:57:13.
#
#     Average epoch training time: 00 hours, 00 minutes, 02 seconds
#
#     loss = 0.106973
#     h11_loss = 0.000965
#     h21_loss = 0.005279
#     h11_categorical_accuracy = 0.999841
#     h21_categorical_accuracy = 0.998886
#     val_loss = 10.426945
#     val_h11_loss = 1.773482
#     val_h21_loss = 8.552946
#     val_h11_categorical_accuracy = 0.833545
#     val_h21_categorical_accuracy = 0.285896
#     lr = 0.000008
#
# Training epoch 800. Started on 21/12/2020 at 19:57:55.
#
#     Average epoch training time: 00 hours, 00 minutes, 02 seconds
#
#     loss = 0.109494
#     h11_loss = 0.002467
#     h21_loss = 0.008981
#     h11_categorical_accuracy = 0.999522
#     h21_categorical_accuracy = 0.997453
#     val_loss = 10.456538
#     val_h11_loss = 1.784215
#     val_h21_loss = 8.574241
#     val_h11_categorical_accuracy = 0.829733
#     val_h21_categorical_accuracy = 0.282084
#     lr = 0.000002
#
# Training epoch 850. Started on 21/12/2020 at 19:58:37.
#
#     Average epoch training time: 00 hours, 00 minutes, 02 seconds
#
#     loss = 0.105896
#     h11_loss = 0.001413
#     h21_loss = 0.007255
#     h11_categorical_accuracy = 0.999363
#     h21_categorical_accuracy = 0.998249
#     val_loss = 10.427278
#     val_h11_loss = 1.777797
#     val_h21_loss = 8.552264
#     val_h11_categorical_accuracy = 0.828463
#     val_h21_categorical_accuracy = 0.284625
#     lr = 0.000002
#
# Training epoch 900. Started on 21/12/2020 at 19:59:19.
#
#     Average epoch training time: 00 hours, 00 minutes, 02 seconds
#
#     loss = 0.104683
#     h11_loss = 0.001103
#     h21_loss = 0.007128
#     h11_categorical_accuracy = 0.999522
#     h21_categorical_accuracy = 0.998249
#     val_loss = 10.407567
#     val_h11_loss = 1.776367
#     val_h21_loss = 8.534719
#     val_h11_categorical_accuracy = 0.831004
#     val_h21_categorical_accuracy = 0.285896
#     lr = 0.000002
#
# Training epoch 950. Started on 21/12/2020 at 20:00:01.
#
#     Average epoch training time: 00 hours, 00 minutes, 02 seconds
#
#     loss = 0.103478
#     h11_loss = 0.001067
#     h21_loss = 0.006795
#     h11_categorical_accuracy = 0.999841
#     h21_categorical_accuracy = 0.997931
#     val_loss = 10.391107
#     val_h11_loss = 1.774220
#     val_h21_loss = 8.521300
#     val_h11_categorical_accuracy = 0.829733
#     val_h21_categorical_accuracy = 0.283355
#     lr = 0.000001
#
# Training epoch 1000. Started on 21/12/2020 at 20:00:42.
#
#     Average epoch training time: 00 hours, 00 minutes, 01 seconds
#
#     loss = 0.105478
#     h11_loss = 0.001782
#     h21_loss = 0.008397
#     h11_categorical_accuracy = 0.999363
#     h21_categorical_accuracy = 0.997135
#     val_loss = 10.405153
#     val_h11_loss = 1.783069
#     val_h21_loss = 8.526815
#     val_h11_categorical_accuracy = 0.829733
#     val_h21_categorical_accuracy = 0.282084
#     lr = 0.000001
#
# Training ended on 21/12/2020 at 20:00:43 after 00 hours, 14 minutes, 20 seconds.

# %% [markdown]
# ## Visualisation of the Training Data
#
# We plot the metrics and the loss of the training for reference.

# %%
inception_hst = pd.DataFrame(inception_hst.history)
inception_hst.to_json(os.path.join(mod_dir, 'history.json'), orient='index')

# %%
plot_loss(os.path.join(mod_dir, 'history.json'),
          out_name='inception_loss',
          root=img_dir,
          validation=True,
          title='Loss Function (categorical crossentropy)',
          yscale='log',
          base_ratio=(1,1),
          show=True,
          save_pdf=True
         )

# %%
plot_metric(os.path.join(mod_dir, 'history.json'),
            metric='h11_loss',
            out_name='inception_h11_loss',
            root=img_dir,
            validation=True,
            title='',
            ylabel='categorical accuracy',
            yscale=None,
            base_ratio=(1,1),
            show=True,
            save_pdf=True
           )

# %%
plot_metric(os.path.join(mod_dir, 'history.json'),
            metric='h21_loss',
            out_name='inception_h21_loss',
            root=img_dir,
            validation=True,
            title='',
            ylabel='categorical accuracy',
            yscale=None,
            base_ratio=(1,1),
            show=True,
            save_pdf=True
           )

# %%
plot_metric(os.path.join(mod_dir, 'history.json'),
            metric='h11_categorical_accuracy',
            out_name='h11_cat_acc',
            root=img_dir,
            validation=True,
            title='',
            ylabel='categorical accuracy',
            yscale=None,
            base_ratio=(1,1),
            show=True,
            save_pdf=True
           )

# %%
plot_metric(os.path.join(mod_dir, 'history.json'),
            metric='h21_categorical_accuracy',
            out_name='h21_cat_acc',
            root=img_dir,
            validation=True,
            title='',
            ylabel='categorical accuracy',
            yscale=None,
            base_ratio=(1,1),
            show=True,
            save_pdf=True
           )

# %%
plot_lr(os.path.join(mod_dir, 'history.json'),
        out_name='inception_lr',
        root=img_dir,
        show=True,
        save_pdf=True
       )

# %% [markdown]
# ## Test Predictions
#
# We finally compute the predictions on the test set.

# %%
model = {'h11': keras.models.load_model(os.path.join(mod_dir, 'val_h11_loss.h5')),
         'h21': keras.models.load_model(os.path.join(mod_dir, 'val_h21_loss.h5'))
        }

# %%
y_pred = {key: model[key].predict(X_test)[key] for key in model.keys()}
y_pred = {key: value.argmax(axis=1) for key, value in y_pred.items()}
y_true = {key: value.argmax(axis=1) for key, value in y_test.items()}

# %%
test_accuracy = {key: np.mean(np.equal(y_pred[key], y_true[key])) for key in y_true.keys()}
for key in test_accuracy.keys():
    print('Test set accuracy:\n')
    print(f'  {key}: {test_accuracy[key]:.3f}')
# Out:
# Test set accuracy:
#
#   h11: 0.821
# Test set accuracy:
#
#   h21: 0.243

# %%
with open(os.path.join(mod_dir, 'test_accuracy.json'), 'w') as f:
    json.dump(test_accuracy, f)
