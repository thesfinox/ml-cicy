# %% [markdown]
# # Machine Learning for CICY 3-Folds
#
# We compute the Hodge numbers of CICY 3-folds using deep learning techniques inspired by the Inception architecture by Google.

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import os
import sys
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
import time
import tarfile
import urllib
import json
import joblib
from nn_tools.utils.plotutils import *
from nn_tools.utils.datacreate import *
from nn_tools.nn_models.models import *
from nn_tools.nn_models.callbacks import *
from IPython.display import Image

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
            logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
sns.set_theme()
ratio   = lambda x, y: (6 * y, 5 * x)

os.makedirs('./img', exist_ok=True)
os.makedirs('./models', exist_ok=True)

# %%
random_state = 123
np.random.seed(random_state)
tf.random.set_seed(random_state)

# %% [markdown]
# ## Create a Saving Directory
#
# Each model will be assigned to a different directory based on the time of running.

# %%
prefix  = 'inception'
name    = time.strftime('%Y%m%d_%H%M%S', time.localtime())
mod_dir = os.path.join('./models', prefix + '_' + name)
img_dir = os.path.join('./img', prefix + '_' + name)

os.makedirs(mod_dir)
os.makedirs(img_dir)

# %%
print(f'Current working directory: {mod_dir}')
# Out:
# Current working directory: ./models/inception_20201207_122955

# %% [markdown]
# ## Load the Dataset
#
# We then download the JSON file containing the configuration matrix and the Hodge numbers of the CICY.

# %%
os.makedirs('./data', exist_ok=True)

urllib.request.urlretrieve('http://www.lpthe.jussieu.fr/~erbin/files/data/cicy3o_data.tar.gz', './data/cicy3o_data.tar.gz')
with tarfile.open('./data/cicy3o_data.tar.gz', 'r') as tar:
    tar.extract('cicy3o.h5', path='./data')

# %%
df     = pd.read_hdf('./data/cicy3o.h5')
n_rows, n_cols = df.shape
print(f'Size of the dataset: {n_rows:d} rows, {n_cols:d} columns.')
# Out:
# Size of the dataset: 7890 rows, 31 columns.

# %% [markdown]
# We then select only the non product spaces:

# %%
df = df.loc[df['isprod'] == False]

# %% [markdown]
# We the pad the matrix to get the same size for all configuration matrices:

# %%
max_size = df['matrix'].apply(np.shape).max()

df.loc[:, 'matrix'] = df['matrix'].apply(lambda x: np.pad(x, ((0, max_size[0] - np.shape(x)[0]), (0, max_size[1] - np.shape(x)[1]))))
df = df[['h11', 'h21', 'matrix']]
n_rows, n_cols = df.shape

# %%
num_classes = [df['h11'].max() + 1, df['h21'].max() + 1]

# %% [markdown]
# We then split it into train, validation and test sets:

# %%
df_splits = {'train': 0.80, 'val_test': 0.5}
with open(os.path.join(mod_dir, 'train_ratio.json'), 'w') as f:
    json.dump(df_splits, f)

# training set
df_train = df.sample(frac=df_splits['train'], random_state=random_state)
df_oos   = df.loc[~df.index.isin(df_train.index)]

n_train = df_train.shape[0]

# validation/test
df_val   = df_oos.sample(frac=df_splits['val_test'], random_state=random_state)
df_test  = df_oos.loc[~df_oos.index.isin(df_val.index)]

n_val  = df_val.shape[0]
n_test = df_test.shape[0]

assert n_train + n_val + n_test == n_rows

# %%
del df, df_oos

# %% [markdown]
# ## Outliers in the Training Set
#
# We then study the outliers in the training set:

# %%
# remove outliers
df_train = df_train.loc[(df_train['h11'] >= 1) & (df_train['h11'] <= 16)
                        &
                        (df_train['h21'] >= 15) & (df_train['h21'] <= 86)
                       ]
n_train_pruned = df_train.shape[0]

# %%
print(f'Samples removed: {n_train - n_train_pruned:d} ({100 * (n_train - n_train_pruned) / n_train:.2f}% of the training set, {100 * (n_train - n_train_pruned) / n_rows:.2f}% of the total set)')
# Out:
# Samples removed: 12 (0.19% of the training set, 0.15% of the total set)

# %% [markdown]
# ## Rescale the Matrices
#
# We then rescale the matrices in the sets to improve the deep learning results:

# %%
# rescaling = {'min': df_train['matrix'].apply(lambda x: np.min(x)).min(),
#              'max': df_train['matrix'].apply(lambda x: np.max(x)).max()
#             }
rescaling = None

# %% [markdown]
# ## Feature and Label Creation
#
# We then create the features and the labels.

# %%
reshape = (12, 15, 1)

# %%
X_train = create_features(df_train['matrix'], rescaling=rescaling, reshape=reshape)
X_val   = create_features(df_val['matrix'], rescaling=rescaling, reshape=reshape)
X_test  = create_features(df_test['matrix'], rescaling=rescaling, reshape=reshape)

# %%
y_train = create_labels(df_train[['h11', 'h21']], one_hot=True, num_classes=num_classes)
y_val   = create_labels(df_val[['h11', 'h21']], one_hot=True, num_classes=num_classes)
y_test  = create_labels(df_test[['h11', 'h21']], one_hot=True, num_classes=num_classes)

# %%
del df_train, df_val, df_test

# %% [markdown]
# ## Inception Model
#
# We then start to build the Inception model to be trained on the configuration matrices.

# %% [markdown]
# ### Build the Model

# %%
model_data = {'input_shape':   reshape,
              'name':          'matrix',
              'learning_rate': 1.0e-3,
              'model':         'classification',
              'out_size':      [20, 102],
              'conv_1b1':      False,
              'conv_layers':   [32, 64, 32],
              'conv_alpha':    0.0,
              'conv_class':    None,
              'conv_single':   False,
              'conv_red':      0,
              'feat_map':      0,
              'recurrent':     False,
              'fc_layers':     [],
              'fc_alpha':      0.0,
              'dropout':       0.0,
              'full_dropout':  0.1,
              'batchnorm':     0.99,
              'last_relu':     False,
              'loss_weights':  None,
              'l1_reg':        1.0e-3,
              'l2_reg':        1.0e-3,
              'output_layers': True,
              'random_state':  random_state
             }

with open(os.path.join(mod_dir, 'model_data.json'), 'w') as f:
    json.dump(model_data, f)

# %%
inception = nn_inception(**model_data)
inception.summary()
# Out:
# Model: "h21"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# matrix (InputLayer)             [(None, 12, 15, 1)]  0
# __________________________________________________________________________________________________
# matrix_convAa_0 (Conv2D)        (None, 12, 15, 32)   416         matrix[0][0]
# __________________________________________________________________________________________________
# matrix_convAb_0 (Conv2D)        (None, 12, 15, 32)   512         matrix[0][0]
# __________________________________________________________________________________________________
# matrix_actAa_0 (LeakyReLU)      (None, 12, 15, 32)   0           matrix_convAa_0[0][0]
# __________________________________________________________________________________________________
# matrix_actAb_0 (LeakyReLU)      (None, 12, 15, 32)   0           matrix_convAb_0[0][0]
# __________________________________________________________________________________________________
# matrix_cat_0 (Concatenate)      (None, 12, 15, 64)   0           matrix_actAa_0[0][0]
#                                                                  matrix_actAb_0[0][0]
# __________________________________________________________________________________________________
# matrix_convBN_0 (BatchNormaliza (None, 12, 15, 64)   256         matrix_cat_0[0][0]
# __________________________________________________________________________________________________
# matrix_convAa_1 (Conv2D)        (None, 12, 15, 64)   49216       matrix_convBN_0[0][0]
# __________________________________________________________________________________________________
# matrix_convAb_1 (Conv2D)        (None, 12, 15, 64)   61504       matrix_convBN_0[0][0]
# __________________________________________________________________________________________________
# matrix_actAa_1 (LeakyReLU)      (None, 12, 15, 64)   0           matrix_convAa_1[0][0]
# __________________________________________________________________________________________________
# matrix_actAb_1 (LeakyReLU)      (None, 12, 15, 64)   0           matrix_convAb_1[0][0]
# __________________________________________________________________________________________________
# matrix_cat_1 (Concatenate)      (None, 12, 15, 128)  0           matrix_actAa_1[0][0]
#                                                                  matrix_actAb_1[0][0]
# __________________________________________________________________________________________________
# matrix_convBN_1 (BatchNormaliza (None, 12, 15, 128)  512         matrix_cat_1[0][0]
# __________________________________________________________________________________________________
# matrix_convAa_2 (Conv2D)        (None, 12, 15, 32)   49184       matrix_convBN_1[0][0]
# __________________________________________________________________________________________________
# matrix_convAb_2 (Conv2D)        (None, 12, 15, 32)   61472       matrix_convBN_1[0][0]
# __________________________________________________________________________________________________
# matrix_actAa_2 (LeakyReLU)      (None, 12, 15, 32)   0           matrix_convAa_2[0][0]
# __________________________________________________________________________________________________
# matrix_actAb_2 (LeakyReLU)      (None, 12, 15, 32)   0           matrix_convAb_2[0][0]
# __________________________________________________________________________________________________
# matrix_cat_2 (Concatenate)      (None, 12, 15, 64)   0           matrix_actAa_2[0][0]
#                                                                  matrix_actAb_2[0][0]
# __________________________________________________________________________________________________
# matrix_convBN_2 (BatchNormaliza (None, 12, 15, 64)   256         matrix_cat_2[0][0]
# __________________________________________________________________________________________________
# matrix_flat (Flatten)           (None, 11520)        0           matrix_convBN_2[0][0]
# __________________________________________________________________________________________________
# matrix_drop (Dropout)           (None, 11520)        0           matrix_flat[0][0]
# __________________________________________________________________________________________________
# h11 (Dense)                     (None, 20)           230420      matrix_drop[0][0]
# __________________________________________________________________________________________________
# h21 (Dense)                     (None, 102)          1175142     matrix_drop[0][0]
# ==================================================================================================
# Total params: 1,628,890
# Trainable params: 1,628,378
# Non-trainable params: 512
# __________________________________________________________________________________________________

# %%
inception_graph = keras.utils.model_to_dot(inception, show_shapes=True, dpi=144)
inception_graph.write_pdf(os.path.join(img_dir, 'inception.pdf'))
Image(inception_graph.create_png(), width=480)

# %% [markdown]
# ### Train the Model

# %%
fit_data = {'epochs':        5000,
            'batch_size':    32,
            'reduce_lr':     1500,
            'stat_interval': 100
           }

with open(os.path.join(mod_dir, 'fit_data.json'), 'w') as f:
    json.dump(fit_data, f)

# %%
callbacks = [keras.callbacks.ModelCheckpoint(os.path.join(mod_dir, 'inception_val_loss.h5'), monitor='val_loss', save_best_only=True),
             keras.callbacks.ModelCheckpoint(os.path.join(mod_dir, 'inception_val_h11_loss.h5'), monitor='val_h11_loss', save_best_only=True),
             keras.callbacks.ModelCheckpoint(os.path.join(mod_dir, 'inception_val_h21_loss.h5'), monitor='val_h21_loss', save_best_only=True),
             keras.callbacks.ReduceLROnPlateau(factor=0.1, patience=fit_data['reduce_lr'], min_lr=1.0e-6),
             PrintCheckpoint(fit_data['stat_interval'])
            ]

inception_hst = inception.fit(x=X_train,
                              y=y_train,
                              batch_size=fit_data['batch_size'],
                              epochs=fit_data['epochs'],
                              verbose=0,
                              callbacks=callbacks,
                              validation_data=(X_val, y_val)
                             )
# Out:
# Training has started. Callouts will be printed every 100 epochs.
#
# Training epoch 1. Started on 07/12/2020 at 12:29:57.
#
#     Average epoch training time: 00 hours, 00 minutes, 33 seconds
#
#     loss = 12.359885
#     h11_loss = 1.791896
#     h21_loss = 4.642968
#     h11_categorical_accuracy = 0.567335
#     h21_categorical_accuracy = 0.115568
#     val_loss = 15.097528
#     val_h11_loss = 4.594169
#     val_h21_loss = 5.261795
#     val_h11_categorical_accuracy = 0.053367
#     val_h21_categorical_accuracy = 0.000000
#     lr = 0.001000
#
# Training epoch 100. Started on 07/12/2020 at 12:31:50.
#
#     Average epoch training time: 00 hours, 00 minutes, 16 seconds
#
#     loss = 1.088102
#     h11_loss = 0.033694
#     h21_loss = 0.144998
#     h11_categorical_accuracy = 0.989016
#     h21_categorical_accuracy = 0.950016
#     val_loss = 9.642909
#     val_h11_loss = 1.437307
#     val_h21_loss = 7.302485
#     val_h11_categorical_accuracy = 0.833545
#     val_h21_categorical_accuracy = 0.277001
#     lr = 0.001000
#
# Training epoch 200. Started on 07/12/2020 at 12:33:11.
#
#     Average epoch training time: 00 hours, 00 minutes, 11 seconds
#
#     loss = 0.847963
#     h11_loss = 0.020067
#     h21_loss = 0.125100
#     h11_categorical_accuracy = 0.994906
#     h21_categorical_accuracy = 0.959885
#     val_loss = 10.101098
#     val_h11_loss = 1.499048
#     val_h21_loss = 7.896299
#     val_h11_categorical_accuracy = 0.837357
#     val_h21_categorical_accuracy = 0.275731
#     lr = 0.001000
#
# Training epoch 300. Started on 07/12/2020 at 12:34:32.
#
#     Average epoch training time: 00 hours, 00 minutes, 08 seconds
#
#     loss = 0.689082
#     h11_loss = 0.020688
#     h21_loss = 0.082720
#     h11_categorical_accuracy = 0.992678
#     h21_categorical_accuracy = 0.973894
#     val_loss = 10.895491
#     val_h11_loss = 1.851257
#     val_h21_loss = 8.448054
#     val_h11_categorical_accuracy = 0.818297
#     val_h21_categorical_accuracy = 0.256671
#     lr = 0.001000
#
# Training epoch 400. Started on 07/12/2020 at 12:35:53.
#
#     Average epoch training time: 00 hours, 00 minutes, 07 seconds
#
#     loss = 0.589838
#     h11_loss = 0.012167
#     h21_loss = 0.059105
#     h11_categorical_accuracy = 0.996339
#     h21_categorical_accuracy = 0.982967
#     val_loss = 11.365489
#     val_h11_loss = 1.581247
#     val_h21_loss = 9.276844
#     val_h11_categorical_accuracy = 0.825921
#     val_h21_categorical_accuracy = 0.260483
#     lr = 0.001000
#
# Training epoch 500. Started on 07/12/2020 at 12:37:14.
#
#     Average epoch training time: 00 hours, 00 minutes, 06 seconds
#
#     loss = 0.524505
#     h11_loss = 0.013719
#     h21_loss = 0.043238
#     h11_categorical_accuracy = 0.996498
#     h21_categorical_accuracy = 0.986788
#     val_loss = 10.098431
#     val_h11_loss = 1.582699
#     val_h21_loss = 8.050336
#     val_h11_categorical_accuracy = 0.824651
#     val_h21_categorical_accuracy = 0.268107
#     lr = 0.001000
#
# Training epoch 600. Started on 07/12/2020 at 12:38:35.
#
#     Average epoch training time: 00 hours, 00 minutes, 05 seconds
#
#     loss = 0.542157
#     h11_loss = 0.016557
#     h21_loss = 0.057896
#     h11_categorical_accuracy = 0.994747
#     h21_categorical_accuracy = 0.979624
#     val_loss = 13.271147
#     val_h11_loss = 2.199447
#     val_h21_loss = 10.574549
#     val_h11_categorical_accuracy = 0.814485
#     val_h21_categorical_accuracy = 0.266836
#     lr = 0.001000
#
# Training epoch 700. Started on 07/12/2020 at 12:39:56.
#
#     Average epoch training time: 00 hours, 00 minutes, 04 seconds
#
#     loss = 0.598194
#     h11_loss = 0.018587
#     h21_loss = 0.087223
#     h11_categorical_accuracy = 0.994429
#     h21_categorical_accuracy = 0.975008
#     val_loss = 11.888708
#     val_h11_loss = 1.927914
#     val_h21_loss = 9.454167
#     val_h11_categorical_accuracy = 0.803050
#     val_h21_categorical_accuracy = 0.250318
#     lr = 0.001000
#
# Training epoch 800. Started on 07/12/2020 at 12:41:17.
#
#     Average epoch training time: 00 hours, 00 minutes, 04 seconds
#
#     loss = 0.538386
#     h11_loss = 0.014118
#     h21_loss = 0.053847
#     h11_categorical_accuracy = 0.995543
#     h21_categorical_accuracy = 0.984082
#     val_loss = 11.923836
#     val_h11_loss = 1.940909
#     val_h21_loss = 9.514736
#     val_h11_categorical_accuracy = 0.804320
#     val_h21_categorical_accuracy = 0.265565
#     lr = 0.001000
#
# Training epoch 900. Started on 07/12/2020 at 12:42:38.
#
#     Average epoch training time: 00 hours, 00 minutes, 04 seconds
#
#     loss = 0.480131
#     h11_loss = 0.006862
#     h21_loss = 0.034674
#     h11_categorical_accuracy = 0.997453
#     h21_categorical_accuracy = 0.989175
#     val_loss = 11.974341
#     val_h11_loss = 2.013058
#     val_h21_loss = 9.533482
#     val_h11_categorical_accuracy = 0.804320
#     val_h21_categorical_accuracy = 0.270648
#     lr = 0.001000
#
# Training epoch 1000. Started on 07/12/2020 at 12:43:59.
#
#     Average epoch training time: 00 hours, 00 minutes, 03 seconds
#
#     loss = 0.443935
#     h11_loss = 0.006529
#     h21_loss = 0.035437
#     h11_categorical_accuracy = 0.997771
#     h21_categorical_accuracy = 0.989494
#     val_loss = 13.018448
#     val_h11_loss = 2.063434
#     val_h21_loss = 10.549464
#     val_h11_categorical_accuracy = 0.822109
#     val_h21_categorical_accuracy = 0.264295
#     lr = 0.001000
#
# Training epoch 1100. Started on 07/12/2020 at 12:45:20.
#
#     Average epoch training time: 00 hours, 00 minutes, 03 seconds
#
#     loss = 0.418190
#     h11_loss = 0.005661
#     h21_loss = 0.022118
#     h11_categorical_accuracy = 0.997294
#     h21_categorical_accuracy = 0.992518
#     val_loss = 12.207908
#     val_h11_loss = 1.859800
#     val_h21_loss = 9.970014
#     val_h11_categorical_accuracy = 0.819568
#     val_h21_categorical_accuracy = 0.252859
#     lr = 0.001000
#
# Training epoch 1200. Started on 07/12/2020 at 12:46:41.
#
#     Average epoch training time: 00 hours, 00 minutes, 03 seconds
#
#     loss = 0.405771
#     h11_loss = 0.005812
#     h21_loss = 0.023596
#     h11_categorical_accuracy = 0.998249
#     h21_categorical_accuracy = 0.993155
#     val_loss = 12.111263
#     val_h11_loss = 1.904890
#     val_h21_loss = 9.844398
#     val_h11_categorical_accuracy = 0.817027
#     val_h21_categorical_accuracy = 0.270648
#     lr = 0.001000
#
# Training epoch 1300. Started on 07/12/2020 at 12:48:02.
#
#     Average epoch training time: 00 hours, 00 minutes, 03 seconds
#
#     loss = 0.450187
#     h11_loss = 0.008876
#     h21_loss = 0.033197
#     h11_categorical_accuracy = 0.997135
#     h21_categorical_accuracy = 0.988539
#     val_loss = 12.994504
#     val_h11_loss = 2.000799
#     val_h21_loss = 10.603163
#     val_h11_categorical_accuracy = 0.825921
#     val_h21_categorical_accuracy = 0.261753
#     lr = 0.001000
#
# Training epoch 1400. Started on 07/12/2020 at 12:49:23.
#
#     Average epoch training time: 00 hours, 00 minutes, 02 seconds
#
#     loss = 0.430158
#     h11_loss = 0.008220
#     h21_loss = 0.022862
#     h11_categorical_accuracy = 0.997294
#     h21_categorical_accuracy = 0.992837
#     val_loss = 12.682818
#     val_h11_loss = 2.003189
#     val_h21_loss = 10.300529
#     val_h11_categorical_accuracy = 0.825921
#     val_h21_categorical_accuracy = 0.260483
#     lr = 0.001000
#
# Training epoch 1500. Started on 07/12/2020 at 12:50:45.
#
#     Average epoch training time: 00 hours, 00 minutes, 02 seconds
#
#     loss = 0.510028
#     h11_loss = 0.016120
#     h21_loss = 0.050886
#     h11_categorical_accuracy = 0.995702
#     h21_categorical_accuracy = 0.982808
#     val_loss = 12.345195
#     val_h11_loss = 2.028248
#     val_h21_loss = 9.882959
#     val_h11_categorical_accuracy = 0.811944
#     val_h21_categorical_accuracy = 0.263024
#     lr = 0.001000
#
# Training epoch 1600. Started on 07/12/2020 at 12:52:05.
#
#     Average epoch training time: 00 hours, 00 minutes, 02 seconds
#
#     loss = 0.157749
#     h11_loss = 0.001401
#     h21_loss = 0.006024
#     h11_categorical_accuracy = 0.999682
#     h21_categorical_accuracy = 0.998408
#     val_loss = 13.381761
#     val_h11_loss = 2.175741
#     val_h21_loss = 11.054420
#     val_h11_categorical_accuracy = 0.817027
#     val_h21_categorical_accuracy = 0.260483
#     lr = 0.000100
#
# Training epoch 1700. Started on 07/12/2020 at 12:53:27.
#
#     Average epoch training time: 00 hours, 00 minutes, 02 seconds
#
#     loss = 0.141699
#     h11_loss = 0.004360
#     h21_loss = 0.006347
#     h11_categorical_accuracy = 0.998727
#     h21_categorical_accuracy = 0.997771
#     val_loss = 14.748380
#     val_h11_loss = 2.421295
#     val_h21_loss = 12.196054
#     val_h11_categorical_accuracy = 0.818297
#     val_h21_categorical_accuracy = 0.270648
#     lr = 0.000100
#
# Training epoch 1800. Started on 07/12/2020 at 12:54:48.
#
#     Average epoch training time: 00 hours, 00 minutes, 02 seconds
#
#     loss = 0.117375
#     h11_loss = 0.001124
#     h21_loss = 0.004025
#     h11_categorical_accuracy = 0.999841
#     h21_categorical_accuracy = 0.998727
#     val_loss = 15.151593
#     val_h11_loss = 2.497837
#     val_h21_loss = 12.540778
#     val_h11_categorical_accuracy = 0.818297
#     val_h21_categorical_accuracy = 0.269377
#     lr = 0.000100
#
# Training epoch 1900. Started on 07/12/2020 at 12:56:10.
#
#     Average epoch training time: 00 hours, 00 minutes, 02 seconds
#
#     loss = 0.113410
#     h11_loss = 0.001074
#     h21_loss = 0.005300
#     h11_categorical_accuracy = 0.999841
#     h21_categorical_accuracy = 0.998249
#     val_loss = 15.539496
#     val_h11_loss = 2.625040
#     val_h21_loss = 12.808471
#     val_h11_categorical_accuracy = 0.808132
#     val_h21_categorical_accuracy = 0.264295
#     lr = 0.000100
#
# Training epoch 2000. Started on 07/12/2020 at 12:57:31.
#
#     Average epoch training time: 00 hours, 00 minutes, 02 seconds
#
#     loss = 0.108985
#     h11_loss = 0.001095
#     h21_loss = 0.007643
#     h11_categorical_accuracy = 0.999363
#     h21_categorical_accuracy = 0.997931
#     val_loss = 15.843746
#     val_h11_loss = 2.528597
#     val_h21_loss = 13.215869
#     val_h11_categorical_accuracy = 0.817027
#     val_h21_categorical_accuracy = 0.280813
#     lr = 0.000100
#
# Training epoch 2100. Started on 07/12/2020 at 12:58:52.
#
#     Average epoch training time: 00 hours, 00 minutes, 02 seconds
#
#     loss = 0.103639
#     h11_loss = 0.000538
#     h21_loss = 0.004976
#     h11_categorical_accuracy = 0.999841
#     h21_categorical_accuracy = 0.998727
#     val_loss = 15.986475
#     val_h11_loss = 2.540855
#     val_h21_loss = 13.348777
#     val_h11_categorical_accuracy = 0.823380
#     val_h21_categorical_accuracy = 0.269377
#     lr = 0.000100
#
# Training epoch 2200. Started on 07/12/2020 at 13:00:13.
#
#     Average epoch training time: 00 hours, 00 minutes, 02 seconds
#
#     loss = 0.101726
#     h11_loss = 0.001160
#     h21_loss = 0.003828
#     h11_categorical_accuracy = 0.999841
#     h21_categorical_accuracy = 0.998567
#     val_loss = 16.035690
#     val_h11_loss = 2.623195
#     val_h21_loss = 13.317188
#     val_h11_categorical_accuracy = 0.820839
#     val_h21_categorical_accuracy = 0.285896
#     lr = 0.000100
#
# Training epoch 2300. Started on 07/12/2020 at 13:01:35.
#
#     Average epoch training time: 00 hours, 00 minutes, 02 seconds
#
#     loss = 0.103903
#     h11_loss = 0.001396
#     h21_loss = 0.010971
#     h11_categorical_accuracy = 0.999204
#     h21_categorical_accuracy = 0.997294
#     val_loss = 15.945269
#     val_h11_loss = 2.785699
#     val_h21_loss = 13.063177
#     val_h11_categorical_accuracy = 0.817027
#     val_h21_categorical_accuracy = 0.266836
#     lr = 0.000100
#
# Training epoch 2400. Started on 07/12/2020 at 13:02:56.
#
#     Average epoch training time: 00 hours, 00 minutes, 02 seconds
#
#     loss = 0.097299
#     h11_loss = 0.001976
#     h21_loss = 0.003958
#     h11_categorical_accuracy = 0.999204
#     h21_categorical_accuracy = 0.998886
#     val_loss = 16.230793
#     val_h11_loss = 2.601303
#     val_h21_loss = 13.538848
#     val_h11_categorical_accuracy = 0.819568
#     val_h21_categorical_accuracy = 0.271919
#     lr = 0.000100
#
# Training epoch 2500. Started on 07/12/2020 at 13:04:17.
#
#     Average epoch training time: 00 hours, 00 minutes, 02 seconds
#
#     loss = 0.102287
#     h11_loss = 0.003633
#     h21_loss = 0.006285
#     h11_categorical_accuracy = 0.998727
#     h21_categorical_accuracy = 0.998408
#     val_loss = 15.488930
#     val_h11_loss = 2.518883
#     val_h21_loss = 12.878426
#     val_h11_categorical_accuracy = 0.818297
#     val_h21_categorical_accuracy = 0.270648
#     lr = 0.000100
#
# Training epoch 2600. Started on 07/12/2020 at 13:05:38.
#
#     Average epoch training time: 00 hours, 00 minutes, 02 seconds
#
#     loss = 0.100593
#     h11_loss = 0.002012
#     h21_loss = 0.005952
#     h11_categorical_accuracy = 0.999363
#     h21_categorical_accuracy = 0.998408
#     val_loss = 16.178240
#     val_h11_loss = 2.686480
#     val_h21_loss = 13.400230
#     val_h11_categorical_accuracy = 0.814485
#     val_h21_categorical_accuracy = 0.278272
#     lr = 0.000100
#
# Training epoch 2700. Started on 07/12/2020 at 13:06:59.
#
#     Average epoch training time: 00 hours, 00 minutes, 01 seconds
#
#     loss = 0.089622
#     h11_loss = 0.001560
#     h21_loss = 0.003687
#     h11_categorical_accuracy = 0.999522
#     h21_categorical_accuracy = 0.998727
#     val_loss = 16.498850
#     val_h11_loss = 2.763481
#     val_h21_loss = 13.650784
#     val_h11_categorical_accuracy = 0.822109
#     val_h21_categorical_accuracy = 0.274460
#     lr = 0.000100
#
# Training epoch 2800. Started on 07/12/2020 at 13:08:21.
#
#     Average epoch training time: 00 hours, 00 minutes, 01 seconds
#
#     loss = 0.101307
#     h11_loss = 0.004027
#     h21_loss = 0.006124
#     h11_categorical_accuracy = 0.999363
#     h21_categorical_accuracy = 0.997294
#     val_loss = 16.268848
#     val_h11_loss = 2.555719
#     val_h21_loss = 13.621671
#     val_h11_categorical_accuracy = 0.824651
#     val_h21_categorical_accuracy = 0.270648
#     lr = 0.000100
#
# Training epoch 2900. Started on 07/12/2020 at 13:09:42.
#
#     Average epoch training time: 00 hours, 00 minutes, 01 seconds
#
#     loss = 0.096693
#     h11_loss = 0.000646
#     h21_loss = 0.007416
#     h11_categorical_accuracy = 0.999522
#     h21_categorical_accuracy = 0.996975
#     val_loss = 15.467220
#     val_h11_loss = 2.635056
#     val_h21_loss = 12.744749
#     val_h11_categorical_accuracy = 0.824651
#     val_h21_categorical_accuracy = 0.271919
#     lr = 0.000100
#
# Training epoch 3000. Started on 07/12/2020 at 13:11:03.
#
#     Average epoch training time: 00 hours, 00 minutes, 01 seconds
#
#     loss = 0.092385
#     h11_loss = 0.000958
#     h21_loss = 0.006587
#     h11_categorical_accuracy = 0.999522
#     h21_categorical_accuracy = 0.996975
#     val_loss = 16.228123
#     val_h11_loss = 2.795391
#     val_h21_loss = 13.347499
#     val_h11_categorical_accuracy = 0.822109
#     val_h21_categorical_accuracy = 0.266836
#     lr = 0.000100
#
# Training epoch 3100. Started on 07/12/2020 at 13:12:24.
#
#     Average epoch training time: 00 hours, 00 minutes, 01 seconds
#
#     loss = 0.059311
#     h11_loss = 0.000096
#     h21_loss = 0.001991
#     h11_categorical_accuracy = 1.000000
#     h21_categorical_accuracy = 0.999522
#     val_loss = 15.580805
#     val_h11_loss = 2.636788
#     val_h21_loss = 12.886753
#     val_h11_categorical_accuracy = 0.820839
#     val_h21_categorical_accuracy = 0.270648
#     lr = 0.000010
#
# Training epoch 3200. Started on 07/12/2020 at 13:13:46.
#
#     Average epoch training time: 00 hours, 00 minutes, 01 seconds
#
#     loss = 0.055888
#     h11_loss = 0.000147
#     h21_loss = 0.002027
#     h11_categorical_accuracy = 1.000000
#     h21_categorical_accuracy = 0.999363
#     val_loss = 15.492453
#     val_h11_loss = 2.551641
#     val_h21_loss = 12.887131
#     val_h11_categorical_accuracy = 0.817027
#     val_h21_categorical_accuracy = 0.273189
#     lr = 0.000010
#
# Training epoch 3300. Started on 07/12/2020 at 13:15:07.
#
#     Average epoch training time: 00 hours, 00 minutes, 01 seconds
#
#     loss = 0.053495
#     h11_loss = 0.000297
#     h21_loss = 0.001043
#     h11_categorical_accuracy = 0.999841
#     h21_categorical_accuracy = 0.999841
#     val_loss = 15.168093
#     val_h11_loss = 2.524797
#     val_h21_loss = 12.591291
#     val_h11_categorical_accuracy = 0.819568
#     val_h21_categorical_accuracy = 0.259212
#     lr = 0.000010
#
# Training epoch 3400. Started on 07/12/2020 at 13:16:28.
#
#     Average epoch training time: 00 hours, 00 minutes, 01 seconds
#
#     loss = 0.054008
#     h11_loss = 0.000117
#     h21_loss = 0.003038
#     h11_categorical_accuracy = 1.000000
#     h21_categorical_accuracy = 0.999204
#     val_loss = 15.153764
#     val_h11_loss = 2.478553
#     val_h21_loss = 12.624324
#     val_h11_categorical_accuracy = 0.819568
#     val_h21_categorical_accuracy = 0.273189
#     lr = 0.000010
#
# Training epoch 3500. Started on 07/12/2020 at 13:17:50.
#
#     Average epoch training time: 00 hours, 00 minutes, 01 seconds
#
#     loss = 0.053328
#     h11_loss = 0.001091
#     h21_loss = 0.002578
#     h11_categorical_accuracy = 0.999522
#     h21_categorical_accuracy = 0.999522
#     val_loss = 15.260294
#     val_h11_loss = 2.512612
#     val_h21_loss = 12.697727
#     val_h11_categorical_accuracy = 0.827192
#     val_h21_categorical_accuracy = 0.264295
#     lr = 0.000010
#
# Training epoch 3600. Started on 07/12/2020 at 13:19:10.
#
#     Average epoch training time: 00 hours, 00 minutes, 01 seconds
#
#     loss = 0.052095
#     h11_loss = 0.000170
#     h21_loss = 0.002756
#     h11_categorical_accuracy = 1.000000
#     h21_categorical_accuracy = 0.999204
#     val_loss = 15.080050
#     val_h11_loss = 2.468346
#     val_h21_loss = 12.562471
#     val_h11_categorical_accuracy = 0.823380
#     val_h21_categorical_accuracy = 0.261753
#     lr = 0.000010
#
# Training epoch 3700. Started on 07/12/2020 at 13:20:31.
#
#     Average epoch training time: 00 hours, 00 minutes, 01 seconds
#
#     loss = 0.049736
#     h11_loss = 0.000140
#     h21_loss = 0.001378
#     h11_categorical_accuracy = 1.000000
#     h21_categorical_accuracy = 0.999682
#     val_loss = 15.130343
#     val_h11_loss = 2.520678
#     val_h21_loss = 12.561562
#     val_h11_categorical_accuracy = 0.823380
#     val_h21_categorical_accuracy = 0.264295
#     lr = 0.000010
#
# Training epoch 3800. Started on 07/12/2020 at 13:21:52.
#
#     Average epoch training time: 00 hours, 00 minutes, 01 seconds
#
#     loss = 0.049773
#     h11_loss = 0.000437
#     h21_loss = 0.001927
#     h11_categorical_accuracy = 0.999841
#     h21_categorical_accuracy = 0.999363
#     val_loss = 15.181757
#     val_h11_loss = 2.423129
#     val_h21_loss = 12.711111
#     val_h11_categorical_accuracy = 0.827192
#     val_h21_categorical_accuracy = 0.265565
#     lr = 0.000010
#
# Training epoch 3900. Started on 07/12/2020 at 13:23:13.
#
#     Average epoch training time: 00 hours, 00 minutes, 01 seconds
#
#     loss = 0.049021
#     h11_loss = 0.000179
#     h21_loss = 0.001500
#     h11_categorical_accuracy = 1.000000
#     h21_categorical_accuracy = 0.999522
#     val_loss = 15.145805
#     val_h11_loss = 2.463002
#     val_h21_loss = 12.635661
#     val_h11_categorical_accuracy = 0.825921
#     val_h21_categorical_accuracy = 0.264295
#     lr = 0.000010
#
# Training epoch 4000. Started on 07/12/2020 at 13:24:34.
#
#     Average epoch training time: 00 hours, 00 minutes, 01 seconds
#
#     loss = 0.048048
#     h11_loss = 0.000063
#     h21_loss = 0.001408
#     h11_categorical_accuracy = 1.000000
#     h21_categorical_accuracy = 0.999841
#     val_loss = 15.156591
#     val_h11_loss = 2.483621
#     val_h21_loss = 12.626447
#     val_h11_categorical_accuracy = 0.825921
#     val_h21_categorical_accuracy = 0.264295
#     lr = 0.000010
#
# Training epoch 4100. Started on 07/12/2020 at 13:25:56.
#
#     Average epoch training time: 00 hours, 00 minutes, 01 seconds
#
#     loss = 0.048371
#     h11_loss = 0.000162
#     h21_loss = 0.002227
#     h11_categorical_accuracy = 1.000000
#     h21_categorical_accuracy = 0.999522
#     val_loss = 15.160485
#     val_h11_loss = 2.433835
#     val_h21_loss = 12.680821
#     val_h11_categorical_accuracy = 0.829733
#     val_h21_categorical_accuracy = 0.269377
#     lr = 0.000010
#
# Training epoch 4200. Started on 07/12/2020 at 13:27:16.
#
#     Average epoch training time: 00 hours, 00 minutes, 01 seconds
#
#     loss = 0.047247
#     h11_loss = 0.000279
#     h21_loss = 0.001692
#     h11_categorical_accuracy = 0.999841
#     h21_categorical_accuracy = 0.999522
#     val_loss = 15.144915
#     val_h11_loss = 2.438650
#     val_h21_loss = 12.661061
#     val_h11_categorical_accuracy = 0.829733
#     val_h21_categorical_accuracy = 0.260483
#     lr = 0.000010
#
# Training epoch 4300. Started on 07/12/2020 at 13:28:38.
#
#     Average epoch training time: 00 hours, 00 minutes, 01 seconds
#
#     loss = 0.045946
#     h11_loss = 0.000059
#     h21_loss = 0.001193
#     h11_categorical_accuracy = 1.000000
#     h21_categorical_accuracy = 0.999682
#     val_loss = 14.995773
#     val_h11_loss = 2.398058
#     val_h21_loss = 12.553222
#     val_h11_categorical_accuracy = 0.827192
#     val_h21_categorical_accuracy = 0.265565
#     lr = 0.000010
#
# Training epoch 4400. Started on 07/12/2020 at 13:29:59.
#
#     Average epoch training time: 00 hours, 00 minutes, 01 seconds
#
#     loss = 0.049249
#     h11_loss = 0.000746
#     h21_loss = 0.004131
#     h11_categorical_accuracy = 0.999841
#     h21_categorical_accuracy = 0.999363
#     val_loss = 15.112487
#     val_h11_loss = 2.460832
#     val_h21_loss = 12.606941
#     val_h11_categorical_accuracy = 0.822109
#     val_h21_categorical_accuracy = 0.269377
#     lr = 0.000010
#
# Training epoch 4500. Started on 07/12/2020 at 13:31:20.
#
#     Average epoch training time: 00 hours, 00 minutes, 01 seconds
#
#     loss = 0.047122
#     h11_loss = 0.000112
#     h21_loss = 0.003021
#     h11_categorical_accuracy = 1.000000
#     h21_categorical_accuracy = 0.999204
#     val_loss = 15.104099
#     val_h11_loss = 2.459093
#     val_h21_loss = 12.601043
#     val_h11_categorical_accuracy = 0.824651
#     val_h21_categorical_accuracy = 0.271919
#     lr = 0.000010
#
# Training epoch 4600. Started on 07/12/2020 at 13:32:42.
#
#     Average epoch training time: 00 hours, 00 minutes, 01 seconds
#
#     loss = 0.043191
#     h11_loss = 0.000207
#     h21_loss = 0.000890
#     h11_categorical_accuracy = 1.000000
#     h21_categorical_accuracy = 0.999841
#     val_loss = 15.056565
#     val_h11_loss = 2.460360
#     val_h21_loss = 12.554114
#     val_h11_categorical_accuracy = 0.831004
#     val_h21_categorical_accuracy = 0.271919
#     lr = 0.000001
#
# Training epoch 4700. Started on 07/12/2020 at 13:34:03.
#
#     Average epoch training time: 00 hours, 00 minutes, 01 seconds
#
#     loss = 0.043891
#     h11_loss = 0.000165
#     h21_loss = 0.002003
#     h11_categorical_accuracy = 1.000000
#     h21_categorical_accuracy = 0.999363
#     val_loss = 15.064168
#     val_h11_loss = 2.452897
#     val_h21_loss = 12.569530
#     val_h11_categorical_accuracy = 0.831004
#     val_h21_categorical_accuracy = 0.273189
#     lr = 0.000001
#
# Training epoch 4800. Started on 07/12/2020 at 13:35:24.
#
#     Average epoch training time: 00 hours, 00 minutes, 01 seconds
#
#     loss = 0.043465
#     h11_loss = 0.000757
#     h21_loss = 0.001179
#     h11_categorical_accuracy = 0.999682
#     h21_categorical_accuracy = 0.999682
#     val_loss = 15.034604
#     val_h11_loss = 2.451099
#     val_h21_loss = 12.541976
#     val_h11_categorical_accuracy = 0.831004
#     val_h21_categorical_accuracy = 0.268107
#     lr = 0.000001
#
# Training epoch 4900. Started on 07/12/2020 at 13:36:45.
#
#     Average epoch training time: 00 hours, 00 minutes, 01 seconds
#
#     loss = 0.043318
#     h11_loss = 0.000692
#     h21_loss = 0.001228
#     h11_categorical_accuracy = 0.999841
#     h21_categorical_accuracy = 0.999682
#     val_loss = 15.028350
#     val_h11_loss = 2.451328
#     val_h21_loss = 12.535626
#     val_h11_categorical_accuracy = 0.831004
#     val_h21_categorical_accuracy = 0.271919
#     lr = 0.000001
#
# Training epoch 5000. Started on 07/12/2020 at 13:38:06.
#
#     Average epoch training time: 00 hours, 00 minutes, 01 seconds
#
#     loss = 0.043330
#     h11_loss = 0.000201
#     h21_loss = 0.001839
#     h11_categorical_accuracy = 1.000000
#     h21_categorical_accuracy = 0.999682
#     val_loss = 14.994911
#     val_h11_loss = 2.451164
#     val_h21_loss = 12.502461
#     val_h11_categorical_accuracy = 0.832274
#     val_h21_categorical_accuracy = 0.270648
#     lr = 0.000001
#
# Training ended on 07/12/2020 at 13:38:07 after 01 hours, 08 minutes, 10 seconds.

# %% [markdown]
# ## Visualisation of the Training Data
#
# We plot the metrics and the loss of the training for reference.

# %%
inception_hst = pd.DataFrame(inception_hst.history)

# %%
fig, ax = plt.subplots(1, 1, figsize=ratio(1,1))

sns.lineplot(data=inception_hst[['loss', 'val_loss']],
             palette=['tab:blue', 'tab:red'],
             ax=ax
            )
ax.set(title='Loss Function (categorical crossentropy)',
       xlabel='epochs',
       ylabel='loss',
       yscale='log'
      )
ax.legend(['training', 'validation'], bbox_to_anchor=(1.0, 0.0), loc='lower left')

savefig('inception_loss', fig, root=img_dir, show=True)

# %%
fig, ax = plt.subplots(1, 1, figsize=ratio(1,1))

sns.lineplot(data=inception_hst[['h11_loss', 'val_h11_loss', 'h21_loss', 'val_h21_loss']],
             palette=['tab:blue', 'tab:red', 'tab:cyan', 'tab:orange'],
             ax=ax
            )
ax.set(title='Loss Function (categorical crossentropy)',
       xlabel='epochs',
       ylabel='loss',
       yscale='log'
      )
ax.legend(['training $h^{1,1}$', 'validation $h^{1,1}$', 'training $h^{2,1}$', 'validation $h^{2,1}$'], bbox_to_anchor=(1.0, 0.0), loc='lower left')

savefig('inception_loss_split', fig, root=img_dir, show=True)

# %%
fig, ax = plt.subplots(1, 1, figsize=ratio(1,1))

sns.lineplot(data=inception_hst[['h11_categorical_accuracy', 'val_h11_categorical_accuracy', 'h21_categorical_accuracy', 'val_h21_categorical_accuracy']],
             palette=['tab:blue', 'tab:red', 'tab:cyan', 'tab:orange'],
             ax=ax
            )
ax.set(title='Accuracy',
       xlabel='epochs',
       ylabel='accuracy'
      )
ax.legend(['training $h^{1,1}$', 'validation $h^{1,1}$', 'training $h^{2,1}$', 'validation $h^{2,1}$'], bbox_to_anchor=(1.0, 0.0), loc='lower left')

savefig('inception_accuracy', fig, root=img_dir, show=True)

# %%
fig, ax = plt.subplots(1, 1, figsize=ratio(1,1))

sns.lineplot(data=inception_hst['lr'],
             ax=ax
            )
ax.set(title='Learning Rate',
       xlabel='epochs',
       ylabel='learning rate',
       yscale='log'
      )

savefig('inception_lr', fig, root=img_dir, show=True)

# %% [markdown]
# ## Test Predictions
#
# We finally compute the predictions on the test set.

# %%
y_pred = inception.predict(X_test)
y_pred = {key: value.argmax(axis=1) for key, value in y_pred.items()}
y_true = {key: value.argmax(axis=1) for key, value in y_test.items()}

# %%
test_accuracy = {key: np.mean(np.equal(y_pred[key], y_true[key])) for key in y_true.keys()}
for key in test_accuracy.keys():
    print(f'Test set accuracy: {test_accuracy[key]:.3f}')
# Out:
# Test set accuracy: 0.504
