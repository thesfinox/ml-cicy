# %% [markdown]
# # Machine Learning for CICY 3-Folds
#
# We compute the Hodge numbers of CICY 3-folds using deep learning techniques inspired by the Inception architecture by Google.

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import tarfile
import urllib
import json
import joblib
from IPython.display import Image
from nntools import *

# %%
random_state = 123
np.random.seed(random_state)
tf.random.set_seed(random_state)

# %% [markdown]
# ## Create a Saving Directory
#
# Each model will be assigned to a different directory based on the time of running.

# %%
img_dir, mod_dir = dir_struct('convnet_5x5_h11_h21', dirs=['img', 'models'])
# Out:
# Current working directories:
#
#   ./img/convnet_5x5_h11_h21_20201221_222306
#   ./models/convnet_5x5_h11_h21_20201221_222306

# %% [markdown]
# ## Load the Dataset
#
# We then download the JSON file containing the configuration matrix and the Hodge numbers of the CICY.

# %%
os.makedirs('./data', exist_ok=True)

urllib.request.urlretrieve('http://www.lpthe.jussieu.fr/~erbin/files/data/cicy3o_data.tar.gz', './data/cicy3o_data.tar.gz')
with tarfile.open('./data/cicy3o_data.tar.gz', 'r') as tar:
    tar.extract('cicy3o.h5', path='./data')

# %%
df, (n_rows, n_cols) = load_hdf('./data/cicy3o.h5')
# Out:
# Size of the dataset: 7890 rows, 31 columns.

# %% [markdown]
# We then select only the non product spaces:

# %%
df = df.loc[df['isprod'] == False]

# %% [markdown]
# We the pad the matrix to get the same size for all configuration matrices:

# %%
max_size = df['matrix'].apply(np.shape).max()

df.loc[:, 'matrix'] = df['matrix'].apply(lambda x: np.pad(x, ((0, max_size[0] - np.shape(x)[0]), (0, max_size[1] - np.shape(x)[1]))))
df = df[['h11', 'h21', 'matrix']]
n_rows, n_cols = df.shape

# %%
num_classes = (int(df['h11'].max() + 1), int(df['h21'].max() + 1))

# %% [markdown]
# We then split it into train, validation and test sets:

# %%
df_splits = {'train_split': 0.80, 'val_split': 0.5}
with open(os.path.join(mod_dir, 'train_ratio.json'), 'w') as f:
    json.dump(df_splits, f)

# split the sets
(df_train, df_val, df_test), (n_train, n_val, n_test) = train_test(df, df_splits, random_state=random_state)

# %%
del df

# %% [markdown]
# ## Outliers in the Training Set
#
# We then study the outliers in the training set:

# %%
# remove outliers
df_train = df_train.loc[(df_train['h11'] >= 1) & (df_train['h11'] <= 16)
                        &
                        (df_train['h21'] >= 15) & (df_train['h21'] <= 86)
                       ]
n_train_pruned = df_train.shape[0]

# %%
print(f'Samples removed: {n_train - n_train_pruned:d} ({100 * (n_train - n_train_pruned) / n_train:.2f}% of the training set, {100 * (n_train - n_train_pruned) / n_rows:.2f}% of the total set)')
# Out:
# Samples removed: 12 (0.19% of the training set, 0.15% of the total set)

# %% [markdown]
# ## Rescale the Matrices
#
# We then rescale the matrices in the sets to improve the deep learning results:

# %%
# rescaling = {'min': df_train['matrix'].apply(lambda x: np.min(x)).min(),
#              'max': df_train['matrix'].apply(lambda x: np.max(x)).max()
#             }
rescaling = None

# %% [markdown]
# ## Feature and Label Creation
#
# We then create the features and the labels.

# %%
reshape = df_train['matrix'].apply(np.shape).max() + (1,)

# %%
X_train = create_features(df_train['matrix'], rescaling=rescaling, reshape=reshape)
X_val   = create_features(df_val['matrix'], rescaling=rescaling, reshape=reshape)
X_test  = create_features(df_test['matrix'], rescaling=rescaling, reshape=reshape)

# %%
y_train = create_labels(df_train[['h11', 'h21']], one_hot=True, num_classes=list(num_classes))
y_val   = create_labels(df_val[['h11', 'h21']], one_hot=True, num_classes=list(num_classes))
y_test  = create_labels(df_test[['h11', 'h21']], one_hot=True, num_classes=list(num_classes))

# %%
del df_train, df_val, df_test

# %% [markdown]
# ## Inception Model
#
# We then start to build the Inception model to be trained on the configuration matrices.

# %% [markdown]
# ### Build the Model

# %%
model_data = {'input_shape':   reshape,
              'name':          'matrix',
              'learning_rate': 1.0e-3,
              'output_names':  ['h11', 'h21'],
              'output_size':   list(num_classes),
              'model_type':    'classification',
              'conv_1b1':      False,
              'conv_layers':   [256, 128, 128, 64, 32],
              'conv_kernel':   (5,5),
              'conv_padding':  'same',
              'conv_alpha':    0.0,
              'conv_red':      0,
              'feat_map':      0,
              'recurrent':     False,
              'fc_layers':     [],
              'fc_alpha':      0.0,
              'dropout':       0.0,
              'full_dropout':  0.1,
              'batchnorm':     0.99,
              'last_relu':     False,
              'loss_weights':  [0.5, 0.5],
              'l1_reg':        1.0e-4,
              'l2_reg':        1.0e-3,
              'output_layers': True,
              'random_state':  random_state
             }

with open(os.path.join(mod_dir, 'model_data.json'), 'w') as f:
    json.dump(model_data, f)

# %%
convnet = nn_lenet(**model_data)
convnet.summary()
# Out:
# Model: "matrix"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# matrix (InputLayer)             [(None, 12, 15, 1)]  0
# __________________________________________________________________________________________________
# matrix_convA_0 (Conv2D)         (None, 12, 15, 256)  6656        matrix[0][0]
# __________________________________________________________________________________________________
# matrix_actA_0 (LeakyReLU)       (None, 12, 15, 256)  0           matrix_convA_0[0][0]
# __________________________________________________________________________________________________
# matrix_convBN_0 (BatchNormaliza (None, 12, 15, 256)  1024        matrix_actA_0[0][0]
# __________________________________________________________________________________________________
# matrix_convFullDrop_0 (Dropout) (None, 12, 15, 256)  0           matrix_convBN_0[0][0]
# __________________________________________________________________________________________________
# matrix_convA_1 (Conv2D)         (None, 12, 15, 128)  819328      matrix_convFullDrop_0[0][0]
# __________________________________________________________________________________________________
# matrix_actA_1 (LeakyReLU)       (None, 12, 15, 128)  0           matrix_convA_1[0][0]
# __________________________________________________________________________________________________
# matrix_convBN_1 (BatchNormaliza (None, 12, 15, 128)  512         matrix_actA_1[0][0]
# __________________________________________________________________________________________________
# matrix_convFullDrop_1 (Dropout) (None, 12, 15, 128)  0           matrix_convBN_1[0][0]
# __________________________________________________________________________________________________
# matrix_convA_2 (Conv2D)         (None, 12, 15, 128)  409728      matrix_convFullDrop_1[0][0]
# __________________________________________________________________________________________________
# matrix_actA_2 (LeakyReLU)       (None, 12, 15, 128)  0           matrix_convA_2[0][0]
# __________________________________________________________________________________________________
# matrix_convBN_2 (BatchNormaliza (None, 12, 15, 128)  512         matrix_actA_2[0][0]
# __________________________________________________________________________________________________
# matrix_convFullDrop_2 (Dropout) (None, 12, 15, 128)  0           matrix_convBN_2[0][0]
# __________________________________________________________________________________________________
# matrix_convA_3 (Conv2D)         (None, 12, 15, 64)   204864      matrix_convFullDrop_2[0][0]
# __________________________________________________________________________________________________
# matrix_actA_3 (LeakyReLU)       (None, 12, 15, 64)   0           matrix_convA_3[0][0]
# __________________________________________________________________________________________________
# matrix_convBN_3 (BatchNormaliza (None, 12, 15, 64)   256         matrix_actA_3[0][0]
# __________________________________________________________________________________________________
# matrix_convFullDrop_3 (Dropout) (None, 12, 15, 64)   0           matrix_convBN_3[0][0]
# __________________________________________________________________________________________________
# matrix_convA_4 (Conv2D)         (None, 12, 15, 32)   51232       matrix_convFullDrop_3[0][0]
# __________________________________________________________________________________________________
# matrix_actA_4 (LeakyReLU)       (None, 12, 15, 32)   0           matrix_convA_4[0][0]
# __________________________________________________________________________________________________
# matrix_convBN_4 (BatchNormaliza (None, 12, 15, 32)   128         matrix_actA_4[0][0]
# __________________________________________________________________________________________________
# matrix_convFullDrop_4 (Dropout) (None, 12, 15, 32)   0           matrix_convBN_4[0][0]
# __________________________________________________________________________________________________
# matrix_flat (Flatten)           (None, 5760)         0           matrix_convFullDrop_4[0][0]
# __________________________________________________________________________________________________
# h11 (Dense)                     (None, 20)           115220      matrix_flat[0][0]
# __________________________________________________________________________________________________
# h21 (Dense)                     (None, 102)          587622      matrix_flat[0][0]
# ==================================================================================================
# Total params: 2,197,082
# Trainable params: 2,195,866
# Non-trainable params: 1,216
# __________________________________________________________________________________________________

# %%
convnet_graph = keras.utils.model_to_dot(convnet, show_shapes=True, dpi=144)
convnet_graph.write_pdf(os.path.join(img_dir, 'convnet.pdf'))
Image(convnet_graph.create_png(), width=480)

# %% [markdown]
# ### Train the Model

# %%
fit_data = {'epochs':             1000,
            'batch_size':         32,
            'reduce_lr_factor':   0.3,
            'reduce_lr_patience': 350,
            'stat_interval':      100
           }

with open(os.path.join(mod_dir, 'fit_data.json'), 'w') as f:
    json.dump(fit_data, f)

# %%
callbacks = model_checkpoints(outputs=['h11', 'h21'],
                              root=mod_dir,
                              validation=True,
                              reduce_lr=fit_data['reduce_lr_factor'],
                              lr_patience=fit_data['reduce_lr_patience'],
                              summary=fit_data['stat_interval']
                             )

convnet_hst = convnet.fit(x=X_train,
                          y=y_train,
                          batch_size=fit_data['batch_size'],
                          epochs=fit_data['epochs'],
                          verbose=0,
                          callbacks=callbacks,
                          validation_data=(X_val, y_val)
                         )
# Out:
# Training has started. Callouts will be printed every 50 epochs.
#
# Training epoch 1. Started on 21/12/2020 at 22:23:38.
#
#     Average epoch training time: 00 hours, 00 minutes, 29 seconds
#
#     loss = 18.556694
#     h11_loss = 1.397754
#     h21_loss = 3.613160
#     h11_categorical_accuracy = 0.580229
#     h21_categorical_accuracy = 0.108883
#     val_loss = 14.504575
#     val_h11_loss = 2.972480
#     val_h21_loss = 5.572142
#     val_h11_categorical_accuracy = 0.210928
#     val_h21_categorical_accuracy = 0.013977
#     lr = 0.001000
#
# Training epoch 50. Started on 21/12/2020 at 22:26:45.
#
#     Average epoch training time: 00 hours, 00 minutes, 16 seconds
#
#     loss = 1.959469
#     h11_loss = 0.077934
#     h21_loss = 0.620697
#     h11_categorical_accuracy = 0.975008
#     h21_categorical_accuracy = 0.778892
#     val_loss = 5.248791
#     val_h11_loss = 0.679025
#     val_h21_loss = 3.305089
#     val_h11_categorical_accuracy = 0.869123
#     val_h21_categorical_accuracy = 0.329098
#     lr = 0.001000
#
# Training epoch 100. Started on 21/12/2020 at 22:30:29.
#
#     Average epoch training time: 00 hours, 00 minutes, 12 seconds
#
#     loss = 1.634308
#     h11_loss = 0.061828
#     h21_loss = 0.393958
#     h11_categorical_accuracy = 0.978669
#     h21_categorical_accuracy = 0.859440
#     val_loss = 6.891950
#     val_h11_loss = 0.954539
#     val_h21_loss = 4.726200
#     val_h11_categorical_accuracy = 0.843710
#     val_h21_categorical_accuracy = 0.306226
#     lr = 0.001000
#
# Training epoch 150. Started on 21/12/2020 at 22:34:55.
#
#     Average epoch training time: 00 hours, 00 minutes, 10 seconds
#
#     loss = 1.409731
#     h11_loss = 0.047308
#     h21_loss = 0.269215
#     h11_categorical_accuracy = 0.983126
#     h21_categorical_accuracy = 0.908309
#     val_loss = 7.019340
#     val_h11_loss = 0.882364
#     val_h21_loss = 5.048527
#     val_h11_categorical_accuracy = 0.860229
#     val_h21_categorical_accuracy = 0.312579
#     lr = 0.001000
#
# Training epoch 200. Started on 21/12/2020 at 22:39:22.
#
#     Average epoch training time: 00 hours, 00 minutes, 09 seconds
#
#     loss = 0.728670
#     h11_loss = 0.017348
#     h21_loss = 0.119103
#     h11_categorical_accuracy = 0.994588
#     h21_categorical_accuracy = 0.958771
#     val_loss = 7.516029
#     val_h11_loss = 1.064905
#     val_h21_loss = 5.852222
#     val_h11_categorical_accuracy = 0.867853
#     val_h21_categorical_accuracy = 0.313850
#     lr = 0.000300
#
# Training epoch 250. Started on 21/12/2020 at 22:43:48.
#
#     Average epoch training time: 00 hours, 00 minutes, 08 seconds
#
#     loss = 0.643381
#     h11_loss = 0.013369
#     h21_loss = 0.093509
#     h11_categorical_accuracy = 0.995384
#     h21_categorical_accuracy = 0.965298
#     val_loss = 7.702678
#     val_h11_loss = 1.069500
#     val_h21_loss = 6.093966
#     val_h11_categorical_accuracy = 0.875476
#     val_h21_categorical_accuracy = 0.337992
#     lr = 0.000300
#
# Training epoch 300. Started on 21/12/2020 at 22:48:15.
#
#     Average epoch training time: 00 hours, 00 minutes, 08 seconds
#
#     loss = 0.648622
#     h11_loss = 0.017992
#     h21_loss = 0.099449
#     h11_categorical_accuracy = 0.993473
#     h21_categorical_accuracy = 0.964979
#     val_loss = 8.193502
#     val_h11_loss = 1.184728
#     val_h21_loss = 6.474812
#     val_h11_categorical_accuracy = 0.866582
#     val_h21_categorical_accuracy = 0.335451
#     lr = 0.000300
#
# Training epoch 350. Started on 21/12/2020 at 22:52:42.
#
#     Average epoch training time: 00 hours, 00 minutes, 08 seconds
#
#     loss = 0.400700
#     h11_loss = 0.006585
#     h21_loss = 0.048079
#     h11_categorical_accuracy = 0.997931
#     h21_categorical_accuracy = 0.982808
#     val_loss = 8.230292
#     val_h11_loss = 1.140248
#     val_h21_loss = 6.744392
#     val_h11_categorical_accuracy = 0.880559
#     val_h21_categorical_accuracy = 0.334180
#     lr = 0.000090
#
# Training epoch 400. Started on 21/12/2020 at 22:57:08.
#
#     Average epoch training time: 00 hours, 00 minutes, 07 seconds
#
#     loss = 0.356967
#     h11_loss = 0.005141
#     h21_loss = 0.045022
#     h11_categorical_accuracy = 0.998249
#     h21_categorical_accuracy = 0.984877
#     val_loss = 8.459100
#     val_h11_loss = 1.211143
#     val_h21_loss = 6.941813
#     val_h11_categorical_accuracy = 0.861499
#     val_h21_categorical_accuracy = 0.343075
#     lr = 0.000090
#
# Training epoch 450. Started on 21/12/2020 at 23:01:25.
#
#     Average epoch training time: 00 hours, 00 minutes, 07 seconds
#
#     loss = 0.347725
#     h11_loss = 0.006442
#     h21_loss = 0.050674
#     h11_categorical_accuracy = 0.997612
#     h21_categorical_accuracy = 0.984082
#     val_loss = 8.366495
#     val_h11_loss = 1.063904
#     val_h21_loss = 7.015514
#     val_h11_categorical_accuracy = 0.880559
#     val_h21_categorical_accuracy = 0.332910
#     lr = 0.000090
#
# Training epoch 500. Started on 21/12/2020 at 23:04:31.
#
#     Average epoch training time: 00 hours, 00 minutes, 07 seconds
#
#     loss = 0.264974
#     h11_loss = 0.004387
#     h21_loss = 0.027421
#     h11_categorical_accuracy = 0.998727
#     h21_categorical_accuracy = 0.992041
#     val_loss = 8.649755
#     val_h11_loss = 1.194457
#     val_h21_loss = 7.221107
#     val_h11_categorical_accuracy = 0.878018
#     val_h21_categorical_accuracy = 0.335451
#     lr = 0.000027
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-90f4a5608bab> in <module>
#       7                              )
#       8
# ----> 9 convnet_hst = convnet.fit(x=X_train,
#      10                           y=y_train,
#      11                           batch_size=fit_data['batch_size'],
#
# ~/conda/envs/ml-cicy3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
#      67
#      68     # Running inside `run_distribute_coordinator` already.
#
# ~/conda/envs/ml-cicy3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#     846                 batch_size=batch_size):
#     847               callbacks.on_train_batch_begin(step)
# --> 848               tmp_logs = train_function(iterator)
#     849               # Catch OutOfRangeError for Datasets of unknown size.
#     850               # This blocks until the batch has finished executing.
#
# ~/conda/envs/ml-cicy3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     578         xla_context.Exit()
#     579     else:
# --> 580       result = self._call(*args, **kwds)
#     581
#     582     if tracing_count == self._get_tracing_count():
#
# ~/conda/envs/ml-cicy3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     609       # In this case we have created variables on the first call, so we run the
#     610       # defunned version which is guaranteed to never create variables.
# --> 611       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     612     elif self._stateful_fn is not None:
#     613       # Release the lock early so that multiple threads can perform the call
#
# ~/conda/envs/ml-cicy3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2418     with self._lock:
#    2419       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2420     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2421
#    2422   @property
#
# ~/conda/envs/ml-cicy3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1659       `args` and `kwargs`.
#    1660     """
# -> 1661     return self._call_flat(
#    1662         (t for t in nest.flatten((args, kwargs), expand_composites=True)
#    1663          if isinstance(t, (ops.Tensor,
#
# ~/conda/envs/ml-cicy3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1743         and executing_eagerly):
#    1744       # No tape is watching; skip to running the function.
# -> 1745       return self._build_call_outputs(self._inference_function.call(
#    1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#
# ~/conda/envs/ml-cicy3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     591       with _InterpolateFunctionError(self):
#     592         if cancellation_manager is None:
# --> 593           outputs = execute.execute(
#     594               str(self.signature.name),
#     595               num_outputs=self._num_outputs,
#
# ~/conda/envs/ml-cicy3/lib/python3.8/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Visualisation of the Training Data
#
# We plot the metrics and the loss of the training for reference.

# %%
convnet_hst = pd.DataFrame(convnet_hst.history)
convnet_hst.to_json(os.path.join(mod_dir, 'history.json'), orient='index')

# %%
plot_loss(os.path.join(mod_dir, 'history.json'),
          out_name='convnet_loss',
          root=img_dir,
          validation=True,
          title='Loss Function (categorical crossentropy)',
          yscale='log',
          base_ratio=(1,1),
          show=True,
          save_pdf=True
         )

# %%
plot_metric(os.path.join(mod_dir, 'history.json'),
            metric='h11_loss',
            out_name='convnet_h11_loss',
            root=img_dir,
            validation=True,
            title='',
            ylabel='categorical accuracy',
            yscale=None,
            base_ratio=(1,1),
            show=True,
            save_pdf=True
           )

# %%
plot_metric(os.path.join(mod_dir, 'history.json'),
            metric='h21_loss',
            out_name='convnet_h21_loss',
            root=img_dir,
            validation=True,
            title='',
            ylabel='categorical accuracy',
            yscale=None,
            base_ratio=(1,1),
            show=True,
            save_pdf=True
           )

# %%
plot_metric(os.path.join(mod_dir, 'history.json'),
            metric='h11_categorical_accuracy',
            out_name='h11_cat_acc',
            root=img_dir,
            validation=True,
            title='',
            ylabel='categorical accuracy',
            yscale=None,
            base_ratio=(1,1),
            show=True,
            save_pdf=True
           )

# %%
plot_metric(os.path.join(mod_dir, 'history.json'),
            metric='h21_categorical_accuracy',
            out_name='h21_cat_acc',
            root=img_dir,
            validation=True,
            title='',
            ylabel='categorical accuracy',
            yscale=None,
            base_ratio=(1,1),
            show=True,
            save_pdf=True
           )

# %%
plot_lr(os.path.join(mod_dir, 'history.json'),
        out_name='convnet_lr',
        root=img_dir,
        show=True,
        save_pdf=True
       )

# %% [markdown]
# ## Test Predictions
#
# We finally compute the predictions on the test set.

# %%
model = {'h11': keras.models.load_model(os.path.join(mod_dir, 'val_h11_loss.h5')),
         'h21': keras.models.load_model(os.path.join(mod_dir, 'val_h21_loss.h5'))
        }

# %%
y_pred = {key: model[key].predict(X_test)[key] for key in model.keys()}
y_pred = {key: value.argmax(axis=1) for key, value in y_pred.items()}
y_true = {key: value.argmax(axis=1) for key, value in y_test.items()}

# %%
test_accuracy = {key: np.mean(np.equal(y_pred[key], y_true[key])) for key in y_true.keys()}
for key in test_accuracy.keys():
    print('Test set accuracy:\n')
    print(f'  {key}: {test_accuracy[key]:.3f}')

# %%
with open(os.path.join(mod_dir, 'test_accuracy.json'), 'w') as f:
    json.dump(test_accuracy, f)
