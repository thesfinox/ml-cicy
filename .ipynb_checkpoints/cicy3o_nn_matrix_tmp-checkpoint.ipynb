# %% [markdown]
# # Artificial Neural Networks for Complete Intersection Calabi-Yau Manifold
#
# In the framework of String Theory, we apply **deep learning** techniques for the prediction of the **Hodge numbers** of _Complete Intersection Calabi-Yau_ (CICY) 3-folds. The relevant quantities are therefore $h_{11}$ and $h_{21}$ which can be predicted starting from the configuration matrices of known manifolds.
#
# We take advantage of previously studied and feature engineered datasets to build **deep neural networks** (DNN) and **convolutional neural networks** (CNN) to predict the labels. We use [Tensorflow](https://www.tensorflow.org/) as backend framework and its high level API [Keras](https://www.tensorflow.org/versions/r2.0/api_docs/python/tf/keras).

# %% [markdown]
# ## Setup
#
# We first setup the environment and import relevant packages which we will use in the analysis. We print their versions to keep track of changes and set the **random seed** of all random generators in order to get reproducible results.

# %%
import sys

import matplotlib        as mpl
import matplotlib.pyplot as plt
import random            as rnd
import numpy             as np
import pandas            as pd
import sklearn           as skl
import tensorflow        as tf

from tensorflow       import keras
from tensorflow.keras import backend as K

import warnings
warnings.simplefilter(action='ignore', category=UserWarning) # ignore UserWarning: I cannot really do anything about it...

print('Python version: {:d}.{:d}'      .format(sys.version_info.major, sys.version_info.minor), flush=True)
print('Matplot version: {}'            .format(mpl.__version__),                                flush=True)
print('Numpy version: {}'              .format(np.__version__),                                 flush=True)
print('Pandas version: {}'             .format(pd.__version__),                                 flush=True)
print('Scikit-learn version: {}'       .format(skl.__version__),                                flush=True)
print('Tensorflow version: {}'         .format(tf.__version__),                                 flush=True)
print('Keras version: {} (backend: {})'.format(keras.__version__, K.backend()),                 flush=True)

# fix random_seed
RAND = 42
rnd.seed(RAND)
np.random.seed(RAND)
tf.random.set_seed(RAND)
# Out:
# Python version: 3.7
# Matplot version: 3.2.1
# Numpy version: 1.18.1
# Pandas version: 1.0.3
# Scikit-learn version: 0.22.2.post1
# Tensorflow version: 2.0.0
# Keras version: 2.2.4-tf (backend: tensorflow)

# %% [markdown]
# We also print the **hardware specifications** to have a representation of the current build.

# %%
# !echo "OS:  $(uname -o) - $(lsb_release -d| sed 's/^.*:\s*//g')"
# !echo "CPU: $(lscpu| grep 'Model name'| sed 's/^.*:\s*//g')"
# !echo "RAM: $(free --giga| awk '/^Mem/ {print $7}') GiB"
# !echo "GPU: $(lspci | grep '3D controller' | sed 's/^.*controller:\s*//g')"
# Out:
# OS:  GNU/Linux - Arch Linux
# CPU: Intel(R) Core(TM) i7-7700HQ CPU @ 2.80GHz
# RAM: 11 GiB
# GPU: NVIDIA Corporation GM108M [GeForce 940MX] (rev a2)

# %% [markdown]
# In order to store information and results, we create a **logger** for the current Python session and a function to print information to the log file (or the standard output, if the logger is not defined).

# %%
import logging

from os import path, rename
from time import strftime, gmtime

def create_logfile(filename, name='logger', level=logging.INFO):
    """
    Create a logfile and rotate old logs.
    
    Required arguments:
        filename: the name of the file or path to the log
        
    Optional arguments
        name:     the name of the log session
        level:    the level of the information stores
        
    Returns:
        the log
    """
    
    # get current time to rename strings
    ctime = strftime('.%Y%m%d.%H%M%S', gmtime())
    
    # rotate log if it already exists
    if path.isfile(filename):
        print('Rotating existing logs...', flush=True)
        rename(filename, filename + ctime)
    
    # get a logging session by name
    log = logging.getLogger(name + ctime)
    log.setLevel(level)
    
    # define format
    fmt = logging.Formatter('%(asctime)s --> %(levelname)s: %(message)s')
    
    # add the log file
    han = logging.FileHandler(filename=filename)
    han.setLevel(level)
    han.setFormatter(fmt)
    
    # add handler for standard output
    std = logging.StreamHandler(sys.stdout)
    std.setLevel(level)
    std.setFormatter(fmt)
    
    # create the output
    log.addHandler(han)
    log.addHandler(std)
    
    print('Created new log file!', flush=True)
    return log

def logprint(string, stream='info', logger=None):
    """
    Decides whether to print on the logger or the standard output.
    
    Required arguments:
        string: the string to print
    
    Optional arguments:
        stream: standard input (info) or standard error (error)
        logger: the logger (None for standard output/error)
    """
    
    if logger is not None:
        if stream == 'info':
            logger.info(string)
        elif stream == 'error':
            logger.error(string)
        else:
            logger.debug(string)
    else:
        if stream == 'info':
            sys.stdout.write(string)
        elif stream == 'error':
            sys.stderr.write(string)
        else:
            sys.stdout.write(string)

# %% [markdown]
# ## Preparation and Tools
#
# We first fetch the desired dataset and prepare the tools for the analysis. Specifically we need to:
#
# 1. define the names of the main **directories** and create them if non existent,
# 2. import the **database** and read the archive,
# 3. create tools for **visualisation** and **manipulation** of the dataset.

# %%
import logging
from os import makedirs

ROOT_DIR = '.'      # root directory
IMG_DIR  = 'img'    # image directory
MOD_DIR  = 'models' # directory of saved models
LOG_DIR  = 'log'    # directory for logs

# name of the dataset to be considered
DB_NAME = 'cicy3o'
DB_FILE = DB_NAME + '.h5'                                     # full name with extension
DB_PATH = path.join(ROOT_DIR, DB_FILE)                        # full path
DB_DIR  = 'original' if DB_NAME == 'cicy3o' else 'favourable' # subdir where to store images, models, logs

# define full paths
IMG_PATH = path.join(ROOT_DIR, IMG_DIR, DB_DIR)
MOD_PATH = path.join(ROOT_DIR, MOD_DIR, DB_DIR)
LOG_PATH = path.join(ROOT_DIR, LOG_DIR, DB_DIR)

# create directories if non existent
if not path.isdir(IMG_PATH):
    makedirs(IMG_PATH, exist_ok=True)
if not path.isdir(MOD_PATH):
    makedirs(MOD_PATH, exist_ok=True)
if not path.isdir(LOG_PATH):
    makedirs(LOG_PATH, exist_ok=True)
    
# create logfile
logger = create_logfile(filename=path.join(LOG_PATH, DB_NAME + '_nn.log'), name='CICY3', level=logging.INFO)
# Out:
# Rotating existing logs...
# Created new log file!

# %% [markdown]
# We then prepare to load the dataset and prepare for the visualisation analysis.

# %%
import pandas as pd

def load_dataset(filepath, mode='hdf5', shuffle=False, random_state=None, logger=None):
    """
    Load a dataset given the path and the format.
    
    Required arguments:
        filepath: the path of the file
        
    Optional arguments:
        mode:         the format of the file
        shuffle:      whether to shuffle the file
        random_state: the seed of the random generator
        logger:       the logging session (None for standard output)
        
    Returns:
        the dataset
    """
    
    if path.isfile(filepath):
        logprint('Reading database...', logger=logger)
        if mode == 'hdf5':
            df = pd.read_hdf(filepath)
        elif mode == 'csv':
            df = pd.read_csv(filepath)
        logprint('Database loaded!', logger=logger)
    else:
        logprint('Database is not available: cannot load the database!', stream='error', logger=logger)
        
    # shuffle the dataframe
    if shuffle and random_state is not None:
        logprint('Shuffling database...', logger=logger)
        df = skl.utils.shuffle(df, random_state=random_state)
        logprint('Database shuffled!', logger=logger)
        
    return df

# %% [markdown]
# We then define some functions we can use to extract and manipulate the database. We use the _Scikit-learn_ API to create _Estimator_ classes (inheriting the _Scikit_ interface).

# %%
from sklearn.base import BaseEstimator, TransformerMixin

# remove the outliers from a Pandas dataset
class RemoveOutliers(BaseEstimator, TransformerMixin):
    """
    Remove outlying data given a dataset and a dictionary containing the intervals for each class.
    
    E.g.: if the two classes are 'h11' and 'h21', the dictionary will be: {'h11': [1, 16], 'h21': [1, 86]}.
    
    Public methods:
        fit:           unused method
        transform:     remove data outside the given interval
        fit_transform: equivalent to transform(fit(...))
    """

    def __init__(self, filter_dict=None):
        """
        Constructor of the class.
        
        Optional arguments:
            filter_dict: the intervals to retain in the data
        """
        
        self.filter_dict = filter_dict

    def fit(self, X, y=None):
        """
        Unused method.
        """

        return self

    def transform(self, X):
        """
        Transform the input by deleting data outside the interval
        
        Required arguments:
            X: the dataset
            
        Returns:
            the transformed dataset
        """

        x = X.copy() # avoid overwriting

        if self.filter_dict is not None:
            for key in self.filter_dict:
                x = x.loc[x[key] >= self.filter_dict[key][0]]
                x = x.loc[x[key] <= self.filter_dict[key][1]]

        return x

# extract the tensors from a Pandas dataset
class ExtractTensor(BaseEstimator, TransformerMixin):
    """
    Extract a dense tensor from sparse input from a given dataset.
    
    Public methods:
        fit:           unused method
        transform:     extract dense tensor
        fit_transform: equivalent to transform(fit(...))
        get_shape:     compute the shape of the tensor
    """

    def __init__(self, flatten=False, shape=None):
        """
        Constructor of the class.
        
        Optional arguments:
            flatten: whether to flatten the output or keep the current shape
            shape:   force the computation with a given shape
        """

        self.flatten = flatten
        self.shape   = shape

    def fit(self, X, y=None):
        """
        Unused method.
        """

        return self

    def transform(self, X):
        """
        Compute the dense equivalent of the sparse input.
        
        Required arguments:
            X: the dataset
            
        Returns:
            the transformed input
        """

        x = X.copy() # avoid overwriting
        if self.shape is None:
            self.shape = x.apply(np.shape).max() # get the shape of the tensor

        if len(self.shape) > 0: # apply this to vectors and tensors
            offset = lambda s : [ (0, self.shape[i] - np.shape(s)[i]) for i in range(len(self.shape)) ]
            x      = x.apply(lambda s: np.pad(s, offset(s), mode='constant'))

        if self.flatten and len(self.shape) > 0:
            return list(np.stack(x.apply(np.ndarray.flatten).values))
        else:
            return list(np.stack(x.values))

    def get_shape(self):
        """
        Compute the shape of the tensor.
        
        Returns:
            the shape of the tensor
        """
        
        return self.shape

# %% [markdown]
# We the define the functions we will use to evaluate and improve the algorithms. Even though the ultimate goal is a regression task, we will however predict integer values $h_{11},~h_{21} \in \mathbb{Z}$, thus we will evaluate the **accuracy** of the prediction, given the best estimate (in general we use the _mean squared error_ to evaluate the algorithms, but we accept those with best _accuracy_).

# %%
# get the accuracy (possibly after rounding)
def accuracy_score(y_true, y_pred, rounding=np.rint):
    """
    Compute the accuracy of the predictions after rounding.
    
    Required arguments:
        y_true: true values
        y_pred: predicted values
        
    Optional arguments:
        rounding: the Numpy function for rounding the predictions
    """

    assert np.shape(y_true)[0] == np.shape(y_pred)[0] # check if same length
    
    # if same length then proceed
    accuracy = 0
    if rounding is not None:
        for n in range(np.shape(y_true)[0]):
            accuracy = accuracy + 1 \
                       if int(y_true[n]) == int(rounding(y_pred[n])) \
                       else accuracy
    else:
        for n in range(np.shape(y_true)[0]):
            accuracy = accuracy + 1 \
                       if y_true[n] == y_pred[n] \
                       else accuracy
    return accuracy / np.shape(y_true)[0]

# get the error difference (possibly after rounding)
def error_diff(y_true, y_pred, rounding=np.rint):
    """
    Compute the error difference between true values and predictions (positive values are overestimate and viceversa).
    
    Required arguments:
        y_true: true values
        y_pred: predicted values
        
    Optional arguments:
        rounding: the Numpy function for rounding the predictions
    """

    assert np.shape(y_true)[0] == np.shape(y_pred)[0] # check if same length

    # if same length then proceed
    err = y_true - rounding(y_pred)
    return np.array(err).astype(np.int16)

# print *SearchCV scores
def gridcv_score(estimator, rounding=np.rint, logger=None):
    """
    Print scores given by cross-validation and optimisation techniques.
    
    Required arguments:
        estimator: the estimator to be evaluated
        
    Optional arguments:
        rounding: the Numpy function for rounding the predictions
        logger:   the logging session (None for standard output)
    """
    
    best_params = estimator.best_params_              # get best parameters
    df          = pd.DataFrame(estimator.cv_results_) # dataframe with CV res.
    
    cv_best_res = df.loc[df['params'] == best_params] # get best results
    accuracy    = cv_best_res.loc[:, 'mean_test_score'].values[0]
    std         = cv_best_res.loc[:, 'std_test_score'].values[0]
    
    logprint('Best parameters: {}'.format(best_params), logger=logger)
    logprint('Accuracy ({}) of cross-validation: ({:.3f} ± {:.3f})%'.format(rounding.__name__, accuracy*100, std*100), logger=logger)
    
# print the accuracy of the predictions
def prediction_score(estimator, X, y, use_best_estimator=False, rounding=np.rint, logger=None):
    """
    Print the accuracy of the predictions.
    
    Required arguments:
        estimator: the estimator to be used for the predictions
        X: the features
        y: the labels (actual values)
        
    Optional arguments:
        use_best_estimator: whether to use the estimator.best_estimator_ or just estimator
        rounding: the Numpy function for rounding the predictions
        logger:   the logging session (None for standard output)
    """
    
    if use_best_estimator:
        estimator = estimator.best_estimator_
    
    accuracy = accuracy_score(y, estimator.predict(X), rounding=rounding)
    logprint('Accuracy ({}) of the predictions: {:.3f}%'.format(rounding.__name__, accuracy*100), logger=logger)

# %% [markdown]
# We use _Matplotlib_ to plot the data and define a few functions which we can use during the analysis:

# %%
# set label sizes
# %matplotlib inline
mpl.rc('axes', labelsize=12)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# set building block sizes for the plot
mpl_width  = 6
mpl_height = 5

# save the current figure
def save_fig(filename, tight_layout=True, extension='png', resolution=96, logger=None):
    """
    Save current figure to file.
    
    Required arguments:
        filename: the name of the file where to save the figure (without extension)
        
    Optional arguments:
        tight_layout: whether to use the tight_layout
        extension:    extension of the file to use
        resolution:   resolution of the file
        logger:       the logging session (None for standard output)
    """

    filename = path.join(IMG_PATH, filename + '.' + extension)
    if tight_layout:
        plt.tight_layout()

    logprint('Saving {}...'.format(filename), logger=logger)
    plt.savefig(filename, format=extension, dpi=resolution)
    logprint('Saved {}!'.format(filename), logger=logger)

# get a generator to count the occurrencies
def get_counts(df, label, feature):
    """
    Generator to produce the count of unique occurrencies of the data.
    
    Required arguments:
        df:      the Pandas dataframe
        label:   the label to consider
        feature: the feature to consider
        
    Yields:
        [ unique feature, unique value, counts ]
    """

    for n in np.sort(df[feature].unique()):
        uniques, counts = np.unique(df[label].loc[df[feature] == n].values, return_counts=True)
        for u, c in np.c_[uniques, counts]:
            yield [ n, u, c ]

# plot histogram of occurrencies
def count_plot(ax, data, title=None, xlabel=None, ylabel='N',
               legend=None, xlog=False, ylog=False, binstep=5,
               **kwargs):
    """
    Plot histogram of occurrencies (e.g.: frequency plot).
    
    Required arguments:
        ax:   the subplot ax where to plot data
        data: the data to plot
        
    Optional arguments:
        title:    the title of the plot
        xlabel:   the label of the x axis
        ylabel:   the label of the y axis
        legend:   the label for the legend in the plot
        xlog:     whether to use the log scale on the x axis
        ylog:     whether to use the log scale on the y axis
        binstep:  the distance between adjacent bins
        **kwargs: additional arguments to pass to plt.hist
    """

    min_tick = np.min(data) if np.min(data) > -100 else -100 # set a MIN cut
    max_tick = np.max(data) if np.max(data) < 100  else 100  # set a MAX cut

    ax.grid(alpha=0.2)                   # create a grid
    ax.set_title(title)                  # set title
    ax.set_xlabel(xlabel)                # set a label for the x axis
    ax.set_ylabel(ylabel)                # set a label for the y axis
    ax.set_xticks(np.arange(min_tick,    # set no. of ticks in the x axis
                            max_tick,
                            step=binstep
                           )
                 )

    if xlog:                             # use log scale in x axis if needed
        ax.set_xscale('log')
    if ylog:                             # use log scale in y axis if needed
        ax.set_yscale('log')

    ax.hist(data,                        # create histogram using 'step' funct.
            histtype='step',
            label=legend,
            **kwargs)

    if legend is not None:               # add legend
        ax.legend(loc='best')

    return ax

# plot labeled features and their values
def label_plot(ax, data, title=None, xlabel=None, ylabel='values',
               legend=None, xlog=False, ylog=False, binstep=1,
               **kwargs):
    """
    Plot values of labelled data (e.g.: variable ranking).
    
    Required arguments:
        ax:   the subplot ax where to plot data
        data: the data to plot
        
    Optional arguments:
        title:    the title of the plot
        xlabel:   the label of the x axis
        ylabel:   the label of the y axis
        legend:   the label for the legend in the plot
        xlog:     whether to use the log scale on the x axis
        ylog:     whether to use the log scale on the y axis
        binstep:  the distance between adjacent bins
        **kwargs: additional arguments to pass to plt.plot
    """

    labels      = [f[0] for f in data]   # labels vector
    importances = [f[1] for f in data]   # importances vector
    length      = len(labels)            # length of the labels vector
    
    ax.grid(alpha=0.2)                   # create a grid
    ax.set_title(title)                  # set title
    ax.set_xlabel(xlabel)                # set a label for the x axis
    ax.set_ylabel(ylabel)                # set a label for the x axis

    ax.set_xticks(np.arange(length,      # set no. of ticks in the x axis
                            step=binstep
                           )
                 )
    ax.set_xticklabels(labels,           # set name of labels of the x axis
                       ha='right',       # horizontal alignment
                       rotation=45       # rotation of the labels
                      )

    if xlog:                             # use log scale in x axis if needed
        ax.set_xscale('log')
    if ylog:                             # use log scale in y axis if needed
        ax.set_yscale('log')

    ax.plot(np.arange(length),           # plot data
            importances,
            label=legend,
            **kwargs)

    if legend is not None:               # add legend
        ax.legend(loc='best')

    return ax

# plot the correlation matrix of a Pandas dataframe
def mat_plot(ax, matrix, labels, label='correlation matrix', **kwargs):
    """
    Plot the correlation matrix of a given dataframe.
    
    Required arguments:
        ax:     the subplot ax where to plot data
        matrix: the matrix to plot
        labels: the labels to show with the matrix
        
    Optional arguments:
        label:    the label to use for the colour bar
        **kwargs: additional arguments to pass to plt.matshow
    """
    
    ax.set_xticks(np.arange(len(labels), # set ticks for x axis
                  step=1)
                 )
    ax.set_xticklabels([''] + labels,    # set the name of the ticks
                       rotation=90
                      )

    ax.set_yticks(np.arange(len(labels), # set ticks for y axis
                  step=1)
                 )
    ax.set_yticklabels([''] + labels)    # set the name of the ticks
                    
    matshow = ax.matshow(matrix,         # show the matrix
                         vmin=-1.0,
                         vmax=1.0,
                         **kwargs
                        )
                                
    cbar = ax.figure.colorbar(matshow,   # create the colour bar
                              ax=ax,
                              fraction=0.05,
                              pad=0.05
                             )
    cbar.ax.set_ylabel(label,            # show the colour bar
                       va='bottom',      # vertical alignment
                       rotation=-90)     # rotation of the label

    return ax

# plot a scatter plot with colours and sizes
def scatter_plot(ax, data, title=None, xlabel=None, ylabel=None,
                 legend=None, xlog=False, ylog=False,
                 colour=True, size=True, colour_label='N', size_leg=0,
                 **kwargs):
    """
    Scatter plot of occurrencies with colour and size codes.
    
    Required arguments:
        ax:   the subplot ax where to plot data
        data: the data to plot
        
    Optional arguments:
        title:        the title of the plot
        xlabel:       the label of the x axis
        ylabel:       the label of the y axis
        legend:       the label for the legend in the plot
        xlog:         whether to use the log scale on the x axis
        ylog:         whether to use the log scale on the y axis
        colour:       whether to use colour codes
        size:         whether to use entries of different size
        colour_label: label to use for the colour code
        size_leg:     length of the legend of the size code
        **kwargs:     additional arguments to pass to plt.scatter
    """

    ax.grid(alpha=0.2)                   # create  a grid
    ax.set_xlabel(xlabel)                # set labels for the x axis
    ax.set_ylabel(ylabel)                # set labels for the y axis
    ax.set_title(title)                  # set title

    if xlog:                             # use log scale in x axis if needed
        ax.set_xscale('log')
    if ylog:                             # use log scale in y axis if needed
        ax.set_yscale('log')

    if colour:                           # create the plot with size and colours
        if size:
            scat = ax.scatter(data[0], data[1], s=data[2], c=data[2], **kwargs)
        else:
            scat = ax.scatter(data[0], data[1], c=data[2], **kwargs)
        cbar = ax.figure.colorbar(scat, ax=ax)
        cbar.ax.set_ylabel(colour_label, rotation=-90, va='bottom')
    else:
        if size:
            scat = ax.scatter(data[0], data[1], s=data[2], **kwargs)
        else:
            scat = ax.scatter(data[0], data[1], **kwargs)

    scat.set_label(legend)               # set label of the plot
    if size_leg:                         # add the size legend if needed
        handles, labels = scat.legend_elements('sizes', num=size_leg)
        ax.legend(handles, labels, loc='lower center',
                  bbox_to_anchor=(0.5,-0.3), ncol=len(handles),
                  fontsize='medium', frameon=False)

    if legend:                           # show the legend
        ax.legend(loc='best')

    return ax

# plot a series with trivial x label
def series_plot(ax, data, title=None, xlabel='series', ylabel=None,
                legend=None, xlog=False, ylog=False,
                step=False, std=False,
                **kwargs):
    """
    Plot a series of data with ordered x axis (e.g.: epoch series).
    
    Required arguments:
        ax:   the subplot ax where to plot data
        data: the data to plot
        
    Optional arguments:
        title:    the title of the plot
        xlabel:   the label of the x axis
        ylabel:   the label of the y axis
        legend:   the label for the legend in the plot
        xlog:     whether to use the log scale on the x axis
        ylog:     whether to use the log scale on the y axis
        step:     whether to use a step function for the plot
        std:      highlight the strip of the standard deviation
        **kwargs: additional arguments to pass to plt.step or plot.plot
    """

    ax.grid(alpha=0.2)                   # create the grid
    ax.set_title(title)                  # set the title
    ax.set_xlabel(xlabel)                # set labels for the x axis
    ax.set_ylabel(ylabel)                # set labels for the y axis

    if xlog:                             # use log scale in the x axis if needed
        ax.set_xscale('log')
    if ylog:                             # use log scale in the y axis if needed
        ax.set_yscale('log')

    series = np.arange(len(data))        # create trivial x axis data
    if step:                             # create the plot
        ax.step(series, data, label=legend, **kwargs)
    else:
        ax.plot(series, data, label=legend, **kwargs)

    if std:                              # show coloured strip with std
        ax.fill_between(series,
                        data + np.std(data),
                        data - np.std(data),
                        alpha=0.2)

    if legend is not None:               # show the legend
        ax.legend(loc='best')

    return ax

# %% [markdown]
# Before going further we also set the **memory growth** of the GPU RAM in order to avoid memory issues:

# %%
# get the list of installed GPUs
gpus = tf.config.experimental.list_physical_devices('GPU')

if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True) # set memory growth
            
        # get the list of logical devices (GPUs)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        logprint('GPU setup: {:d} physical GPUs, {:d} logical GPUs.'.format(len(gpus), len(logical_gpus)), logger=logger)
    except RuntimeError as e:
        logprint(e, stream='error', logger=logger)
else:
    logprint('No GPUs in the setup!', stream='error', logger=logger)
# Out:
# 2020-04-13 20:56:19,502 --> INFO: GPU setup: 1 physical GPUs, 1 logical GPUs.

# %% [markdown]
# ## Neural Networks
#
# We then proceed with the analysis by first loading the prepared datasets and then building the appropriate architectures for the prediction of the Hodge numbers. We start from the analysis of the configuration matrix through a **CNN** architecture and then compare the results with the analysis of the engineered dataset.
#
# We consider only the configuration matrix and build a CNN to predict the labels. First of all we load the dataset and then divide labels and features, we then proceed with the architecture of the CNN.

# %%
if path.isfile(path.join(ROOT_DIR, DB_NAME + '_matrix.h5')):
    matrix = load_dataset(path.join(ROOT_DIR, DB_NAME + '_matrix.h5'), logger=logger)
    h11    = ExtractTensor(flatten=False).fit_transform(matrix['h11'])
    h21    = ExtractTensor(flatten=False).fit_transform(matrix['h21'])
    matrix = ExtractTensor(flatten=False).fit_transform(matrix['matrix'])
# Out:
# 2020-04-13 20:56:19,515 --> INFO: Reading database...
# 2020-04-13 20:56:19,667 --> INFO: Database loaded!

# %% [markdown]
# ## Setup and Preparation of the Input
#
# Before splitting the dataset into training and test sets, we need to resize the feature inputs in order to feed them to a convolutional layer.

# %%
logprint('Reshaping the matrix...', logger=logger)
matrix = np.reshape(matrix, (-1, np.shape(matrix)[1], np.shape(matrix)[2], 1))
h11    = np.array(h11)
h21    = np.array(h21)
logprint('Matrix reshaped!', logger=logger)
# Out:
# 2020-04-13 20:56:20,183 --> INFO: Reshaping the matrix...
# 2020-04-13 20:56:20,204 --> INFO: Matrix reshaped!

# %% [markdown]
# As for the ML analysis, we keep 10% of the whole dataset as **test** set, while we use 90% of it as **training** set. Specifically we then retain 1/9 of the training set as holdout **validation** such that the entire dataset is thus divided into 10% for test predictions, 10% for validation and 80% for effective training.

# %%
from sklearn.model_selection import train_test_split

logprint('Splitting into training and test sets...', logger=logger)
matrix_train, matrix_test, h11_train, h11_test, h21_train, h21_test = train_test_split(matrix, h11, h21,                   test_size=0.1,     shuffle=False)
matrix_train, matrix_val,  h11_train, h11_val,  h21_train, h21_val  = train_test_split(matrix_train, h11_train, h21_train, test_size=1.0/9.0, shuffle=False)
logprint('Divided into training and test sets!', logger=logger)
# Out:
# 2020-04-13 20:56:20,249 --> INFO: Splitting into training and test sets...
# 2020-04-13 20:56:20,253 --> INFO: Divided into training and test sets!

# %% [markdown]
# We then get the input size of the tensor to insert in the model:

# %%
input_shape = matrix.shape[1:]

# %% [markdown]
# ## Model Building
#
# We the build the architecture of the CNN. We use a modular approach in order to be able to change its parameters in a quick way in order to perform the hyperparameter optimization efficiently. The idea is to use convolutional layers followed by pooling layers in order to reduce the number of features before linking the convolutional network to a fully connected (FC) dense network to process the output.

# %%
from tensorflow.keras              import Input
from tensorflow.keras.models       import Model
from tensorflow.keras.layers       import Conv2D, Dense, Flatten, BatchNormalization, Dropout, LeakyReLU, Lambda
from tensorflow.keras.optimizers   import Adam
from tensorflow.keras.regularizers import l1_l2

#-------------------------
# PARAMETERS
#-------------------------
leaky_alpha   = 6.0
dropout_rate  = 0.4
l1_reg        = 0.001
l2_reg        = 0.001
norm_momentum = 0.99
learning_rate = 0.01

#-------------------------
# MODEL
#-------------------------
i = Input(shape=input_shape)

x = BatchNormalization(momentum=norm_momentum)(i)

#--------------------------------------------------------------- CONV BLOCK
x = Conv2D(filters=100,
           kernel_size=(5,6),
           padding='same',
           kernel_regularizer=l1_l2(l1=l1_reg, l2=l2_reg)
          )(x)
x = LeakyReLU(alpha=leaky_alpha)(x)

x = Dropout(rate=dropout_rate)(x)
x = BatchNormalization(momentum=norm_momentum)(x)

#--------------------------------------------------------------- CONV BLOCK
x = Conv2D(filters=80,
           kernel_size=(5,6),
           padding='same',
           kernel_regularizer=l1_l2(l1=l1_reg, l2=l2_reg)
          )(x)
x = LeakyReLU(alpha=leaky_alpha)(x)

x = Dropout(rate=dropout_rate)(x)
x = BatchNormalization(momentum=norm_momentum)(x)

#--------------------------------------------------------------- CONV BLOCK
x = Conv2D(filters=40,
           kernel_size=(5,6),
           padding='same',
           kernel_regularizer=l1_l2(l1=l1_reg, l2=l2_reg)
          )(x)
x = LeakyReLU(alpha=leaky_alpha)(x)

x = Dropout(rate=dropout_rate)(x)
x = BatchNormalization(momentum=norm_momentum)(x)

#--------------------------------------------------------------- CONV BLOCK
x = Conv2D(filters=20,
           kernel_size=(3,4),
           padding='same',
           kernel_regularizer=l1_l2(l1=l1_reg, l2=l2_reg)
          )(x)
x = LeakyReLU(alpha=leaky_alpha)(x)

x = Dropout(rate=dropout_rate)(x)
x = BatchNormalization(momentum=norm_momentum)(x)

#--------------------------------------------------------------- FC NETWORK
x = Flatten()(x)

x = BatchNormalization(momentum=norm_momentum)(x)

x = Dense(800)(x)
x = LeakyReLU(alpha=leaky_alpha)(x)

x = Dropout(rate=dropout_rate)(x)

f = Dense(1)(x)

#-------------------------
# COMPILATION
#-------------------------
model = Model(inputs=i, outputs=f)
model.compile(optimizers=Adam(learning_rate=learning_rate), loss='mean_squared_error', metrics=['mean_squared_error'])
model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 12, 15, 1)]       0
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 12, 15, 1)         4
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 12, 15, 80)        1680
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 12, 15, 80)        0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 12, 15, 80)        0
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 12, 15, 80)        320
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 12, 15, 40)        64040
# _________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)   (None, 12, 15, 40)        0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 12, 15, 40)        0
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 12, 15, 40)        160
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 12, 15, 20)        16020
# _________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)   (None, 12, 15, 20)        0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 12, 15, 20)        0
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 12, 15, 20)        80
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 3600)              0
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 3600)              14400
# _________________________________________________________________
# dense_4 (Dense)              (None, 800)               2880800
# _________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)   (None, 800)               0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 800)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 801
# =================================================================
# Total params: 2,978,305
# Trainable params: 2,970,823
# Non-trainable params: 7,482
# _________________________________________________________________

# %% [markdown]
# We can also visualise the model using the `plot_model` function in _Keras_:

# %%
from tensorflow.keras.utils import plot_model

plot_model(model=model, to_file=path.join(IMG_PATH, 'cnn_model_matrix.png'), show_shapes=True)

# %% [markdown]
# We then fit the model with the available parameters:

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

callbacks_h11     = [EarlyStopping(monitor='val_mean_squared_error', patience=50, verbose=1, restore_best_weights=True),
                     ReduceLROnPlateau(monitor='val_mean_squared_error', factor=0.33, patience=25),
                     ModelCheckpoint(filepath=path.join(MOD_PATH, 'cnn_model_matrix_h11.h5'), monitor='val_mean_squared_error', verbose=1, save_best_only=True)
                    ]

model_h11_history = model.fit(x=matrix_train,
                              y=h11_train,
                              batch_size=32,
                              epochs=500,
                              verbose=1,
                              callbacks=callbacks_h11,
                              validation_data=(matrix_val, h11_val)
                             )
# Out:
# Train on 6280 samples, validate on 785 samples
# Epoch 1/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 12.4262 - mean_squared_error: 12.4262
# Epoch 00001: val_mean_squared_error improved from inf to 9.20135, saving model to ./models/original/cnn_model_matrix_h11.h5
# 6280/6280 [==============================] - 8s 1ms/sample - loss: 12.3764 - mean_squared_error: 12.3764 - val_loss: 9.2014 - val_mean_squared_error: 9.2014
# Epoch 2/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 4.8054 - mean_squared_error: 4.8054
# Epoch 00002: val_mean_squared_error improved from 9.20135 to 8.05098, saving model to ./models/original/cnn_model_matrix_h11.h5
# 6280/6280 [==============================] - 6s 936us/sample - loss: 4.8091 - mean_squared_error: 4.8091 - val_loss: 8.0510 - val_mean_squared_error: 8.0510
# Epoch 3/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 3.7989 - mean_squared_error: 3.7989
# Epoch 00003: val_mean_squared_error improved from 8.05098 to 5.95588, saving model to ./models/original/cnn_model_matrix_h11.h5
# 6280/6280 [==============================] - 6s 939us/sample - loss: 3.8182 - mean_squared_error: 3.8182 - val_loss: 5.9559 - val_mean_squared_error: 5.9559
# Epoch 4/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 3.4245 - mean_squared_error: 3.4245
# Epoch 00004: val_mean_squared_error improved from 5.95588 to 4.63895, saving model to ./models/original/cnn_model_matrix_h11.h5
# 6280/6280 [==============================] - 6s 939us/sample - loss: 3.4279 - mean_squared_error: 3.4279 - val_loss: 4.6389 - val_mean_squared_error: 4.6389
# Epoch 5/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 3.1005 - mean_squared_error: 3.1005
# Epoch 00005: val_mean_squared_error improved from 4.63895 to 2.59532, saving model to ./models/original/cnn_model_matrix_h11.h5
# 6280/6280 [==============================] - 6s 943us/sample - loss: 3.1029 - mean_squared_error: 3.1029 - val_loss: 2.5953 - val_mean_squared_error: 2.5953
# Epoch 6/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 2.9881 - mean_squared_error: 2.9881
# Epoch 00006: val_mean_squared_error improved from 2.59532 to 2.03924, saving model to ./models/original/cnn_model_matrix_h11.h5
# 6280/6280 [==============================] - 6s 937us/sample - loss: 2.9835 - mean_squared_error: 2.9835 - val_loss: 2.0392 - val_mean_squared_error: 2.0392
# Epoch 7/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 2.8580 - mean_squared_error: 2.8580
# Epoch 00007: val_mean_squared_error did not improve from 2.03924
# 6280/6280 [==============================] - 6s 919us/sample - loss: 2.8634 - mean_squared_error: 2.8634 - val_loss: 5.9482 - val_mean_squared_error: 5.9482
# Epoch 8/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 2.7449 - mean_squared_error: 2.7449
# Epoch 00008: val_mean_squared_error did not improve from 2.03924
# 6280/6280 [==============================] - 6s 917us/sample - loss: 2.7411 - mean_squared_error: 2.7411 - val_loss: 2.7043 - val_mean_squared_error: 2.7043
# Epoch 9/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 2.6239 - mean_squared_error: 2.6239
# Epoch 00009: val_mean_squared_error did not improve from 2.03924
# 6280/6280 [==============================] - 6s 932us/sample - loss: 2.6283 - mean_squared_error: 2.6283 - val_loss: 2.6835 - val_mean_squared_error: 2.6835
# Epoch 10/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 2.4698 - mean_squared_error: 2.4698
# Epoch 00010: val_mean_squared_error did not improve from 2.03924
# 6280/6280 [==============================] - 6s 918us/sample - loss: 2.4659 - mean_squared_error: 2.4659 - val_loss: 4.5618 - val_mean_squared_error: 4.5618
# Epoch 11/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 2.3871 - mean_squared_error: 2.3871
# Epoch 00011: val_mean_squared_error improved from 2.03924 to 1.72210, saving model to ./models/original/cnn_model_matrix_h11.h5
# 6280/6280 [==============================] - 6s 948us/sample - loss: 2.3897 - mean_squared_error: 2.3897 - val_loss: 1.7221 - val_mean_squared_error: 1.7221
# Epoch 12/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 2.2723 - mean_squared_error: 2.2723
# Epoch 00012: val_mean_squared_error improved from 1.72210 to 1.54367, saving model to ./models/original/cnn_model_matrix_h11.h5
# 6280/6280 [==============================] - 6s 934us/sample - loss: 2.2735 - mean_squared_error: 2.2735 - val_loss: 1.5437 - val_mean_squared_error: 1.5437
# Epoch 13/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 2.2796 - mean_squared_error: 2.2796
# Epoch 00013: val_mean_squared_error did not improve from 1.54367
# 6280/6280 [==============================] - 6s 930us/sample - loss: 2.2827 - mean_squared_error: 2.2827 - val_loss: 1.7371 - val_mean_squared_error: 1.7371
# Epoch 14/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 2.1301 - mean_squared_error: 2.1301
# Epoch 00014: val_mean_squared_error did not improve from 1.54367
# 6280/6280 [==============================] - 6s 921us/sample - loss: 2.1327 - mean_squared_error: 2.1327 - val_loss: 2.2170 - val_mean_squared_error: 2.2170
# Epoch 15/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 2.0778 - mean_squared_error: 2.0778
# Epoch 00015: val_mean_squared_error improved from 1.54367 to 1.32268, saving model to ./models/original/cnn_model_matrix_h11.h5
# 6280/6280 [==============================] - 6s 949us/sample - loss: 2.0735 - mean_squared_error: 2.0735 - val_loss: 1.3227 - val_mean_squared_error: 1.3227
# Epoch 16/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 2.0387 - mean_squared_error: 2.0387
# Epoch 00016: val_mean_squared_error did not improve from 1.32268
# 6280/6280 [==============================] - 6s 919us/sample - loss: 2.0391 - mean_squared_error: 2.0391 - val_loss: 3.6005 - val_mean_squared_error: 3.6005
# Epoch 17/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.8700 - mean_squared_error: 1.8700
# Epoch 00017: val_mean_squared_error did not improve from 1.32268
# 6280/6280 [==============================] - 6s 937us/sample - loss: 1.8676 - mean_squared_error: 1.8676 - val_loss: 2.0731 - val_mean_squared_error: 2.0731
# Epoch 18/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.9163 - mean_squared_error: 1.9163
# Epoch 00018: val_mean_squared_error did not improve from 1.32268
# 6280/6280 [==============================] - 6s 925us/sample - loss: 1.9116 - mean_squared_error: 1.9116 - val_loss: 1.4944 - val_mean_squared_error: 1.4944
# Epoch 19/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.7589 - mean_squared_error: 1.7589
# Epoch 00019: val_mean_squared_error improved from 1.32268 to 1.25267, saving model to ./models/original/cnn_model_matrix_h11.h5
# 6280/6280 [==============================] - 6s 944us/sample - loss: 1.7546 - mean_squared_error: 1.7546 - val_loss: 1.2527 - val_mean_squared_error: 1.2527
# Epoch 20/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.7097 - mean_squared_error: 1.7097
# Epoch 00020: val_mean_squared_error did not improve from 1.25267
# 6280/6280 [==============================] - 6s 924us/sample - loss: 1.7120 - mean_squared_error: 1.7120 - val_loss: 8.2264 - val_mean_squared_error: 8.2264
# Epoch 21/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.6962 - mean_squared_error: 1.6962
# Epoch 00021: val_mean_squared_error did not improve from 1.25267
# 6280/6280 [==============================] - 6s 936us/sample - loss: 1.7035 - mean_squared_error: 1.7035 - val_loss: 1.2778 - val_mean_squared_error: 1.2778
# Epoch 22/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.5914 - mean_squared_error: 1.5914
# Epoch 00022: val_mean_squared_error did not improve from 1.25267
# 6280/6280 [==============================] - 6s 920us/sample - loss: 1.5899 - mean_squared_error: 1.5899 - val_loss: 2.0762 - val_mean_squared_error: 2.0762
# Epoch 23/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.6555 - mean_squared_error: 1.6555
# Epoch 00023: val_mean_squared_error improved from 1.25267 to 1.14837, saving model to ./models/original/cnn_model_matrix_h11.h5
# 6280/6280 [==============================] - 6s 958us/sample - loss: 1.6524 - mean_squared_error: 1.6524 - val_loss: 1.1484 - val_mean_squared_error: 1.1484
# Epoch 24/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.6034 - mean_squared_error: 1.6034
# Epoch 00024: val_mean_squared_error did not improve from 1.14837
# 6280/6280 [==============================] - 6s 923us/sample - loss: 1.6035 - mean_squared_error: 1.6035 - val_loss: 1.4141 - val_mean_squared_error: 1.4141
# Epoch 25/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.5464 - mean_squared_error: 1.5464
# Epoch 00025: val_mean_squared_error did not improve from 1.14837
# 6280/6280 [==============================] - 6s 940us/sample - loss: 1.5508 - mean_squared_error: 1.5508 - val_loss: 1.3160 - val_mean_squared_error: 1.3160
# Epoch 26/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.5464 - mean_squared_error: 1.5464
# Epoch 00026: val_mean_squared_error did not improve from 1.14837
# 6280/6280 [==============================] - 6s 926us/sample - loss: 1.5473 - mean_squared_error: 1.5473 - val_loss: 1.6094 - val_mean_squared_error: 1.6094
# Epoch 27/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.5001 - mean_squared_error: 1.5001
# Epoch 00027: val_mean_squared_error did not improve from 1.14837
# 6280/6280 [==============================] - 6s 928us/sample - loss: 1.4973 - mean_squared_error: 1.4973 - val_loss: 1.4068 - val_mean_squared_error: 1.4068
# Epoch 28/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.4667 - mean_squared_error: 1.4667
# Epoch 00028: val_mean_squared_error did not improve from 1.14837
# 6280/6280 [==============================] - 6s 922us/sample - loss: 1.4648 - mean_squared_error: 1.4648 - val_loss: 1.2199 - val_mean_squared_error: 1.2199
# Epoch 29/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.4822 - mean_squared_error: 1.4822
# Epoch 00029: val_mean_squared_error improved from 1.14837 to 0.97964, saving model to ./models/original/cnn_model_matrix_h11.h5
# 6280/6280 [==============================] - 6s 963us/sample - loss: 1.4791 - mean_squared_error: 1.4791 - val_loss: 0.9796 - val_mean_squared_error: 0.9796
# Epoch 30/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.5414 - mean_squared_error: 1.5414
# Epoch 00030: val_mean_squared_error did not improve from 0.97964
# 6280/6280 [==============================] - 6s 922us/sample - loss: 1.5430 - mean_squared_error: 1.5430 - val_loss: 3.7911 - val_mean_squared_error: 3.7911
# Epoch 31/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.4811 - mean_squared_error: 1.4811
# Epoch 00031: val_mean_squared_error did not improve from 0.97964
# 6280/6280 [==============================] - 6s 932us/sample - loss: 1.4836 - mean_squared_error: 1.4836 - val_loss: 1.5029 - val_mean_squared_error: 1.5029
# Epoch 32/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.4729 - mean_squared_error: 1.4729
# Epoch 00032: val_mean_squared_error did not improve from 0.97964
# 6280/6280 [==============================] - 6s 928us/sample - loss: 1.4773 - mean_squared_error: 1.4773 - val_loss: 1.0626 - val_mean_squared_error: 1.0626
# Epoch 33/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.3944 - mean_squared_error: 1.3944
# Epoch 00033: val_mean_squared_error did not improve from 0.97964
# 6280/6280 [==============================] - 6s 933us/sample - loss: 1.3930 - mean_squared_error: 1.3930 - val_loss: 1.6395 - val_mean_squared_error: 1.6395
# Epoch 34/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.3716 - mean_squared_error: 1.3716
# Epoch 00034: val_mean_squared_error did not improve from 0.97964
# 6280/6280 [==============================] - 6s 921us/sample - loss: 1.3699 - mean_squared_error: 1.3699 - val_loss: 2.4825 - val_mean_squared_error: 2.4825
# Epoch 35/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.3788 - mean_squared_error: 1.3788
# Epoch 00035: val_mean_squared_error did not improve from 0.97964
# 6280/6280 [==============================] - 6s 936us/sample - loss: 1.3791 - mean_squared_error: 1.3791 - val_loss: 1.0333 - val_mean_squared_error: 1.0333
# Epoch 36/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.4439 - mean_squared_error: 1.4439
# Epoch 00036: val_mean_squared_error did not improve from 0.97964
# 6280/6280 [==============================] - 6s 924us/sample - loss: 1.4428 - mean_squared_error: 1.4428 - val_loss: 1.2977 - val_mean_squared_error: 1.2977
# Epoch 37/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.4226 - mean_squared_error: 1.4226
# Epoch 00037: val_mean_squared_error did not improve from 0.97964
# 6280/6280 [==============================] - 6s 943us/sample - loss: 1.4208 - mean_squared_error: 1.4208 - val_loss: 1.4454 - val_mean_squared_error: 1.4454
# Epoch 38/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.3187 - mean_squared_error: 1.3187
# Epoch 00038: val_mean_squared_error did not improve from 0.97964
# 6280/6280 [==============================] - 6s 932us/sample - loss: 1.3202 - mean_squared_error: 1.3202 - val_loss: 1.9209 - val_mean_squared_error: 1.9209
# Epoch 39/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.3576 - mean_squared_error: 1.3576
# Epoch 00039: val_mean_squared_error did not improve from 0.97964
# 6280/6280 [==============================] - 6s 932us/sample - loss: 1.3569 - mean_squared_error: 1.3569 - val_loss: 1.3223 - val_mean_squared_error: 1.3223
# Epoch 40/500
# 6272/6280 [============================>.] - ETA: 0s - loss: 1.3280 - mean_squared_error: 1.3280
# Epoch 00040: val_mean_squared_error did not improve from 0.97964
# 6280/6280 [==============================] - 6s 944us/sample - loss: 1.3270 - mean_squared_error: 1.3270 - val_loss: 1.9011 - val_mean_squared_error: 1.9011
# Epoch 41/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.3569 - mean_squared_error: 1.3569
# Epoch 00041: val_mean_squared_error did not improve from 0.97964
# 6280/6280 [==============================] - 6s 946us/sample - loss: 1.3547 - mean_squared_error: 1.3547 - val_loss: 1.0698 - val_mean_squared_error: 1.0698
# Epoch 42/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.3366 - mean_squared_error: 1.3366
# Epoch 00042: val_mean_squared_error did not improve from 0.97964
# 6280/6280 [==============================] - 6s 934us/sample - loss: 1.3348 - mean_squared_error: 1.3348 - val_loss: 2.0203 - val_mean_squared_error: 2.0203
# Epoch 43/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.2965 - mean_squared_error: 1.2965
# Epoch 00043: val_mean_squared_error did not improve from 0.97964
# 6280/6280 [==============================] - 6s 941us/sample - loss: 1.2915 - mean_squared_error: 1.2915 - val_loss: 1.2043 - val_mean_squared_error: 1.2043
# Epoch 44/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.3502 - mean_squared_error: 1.3502
# Epoch 00044: val_mean_squared_error did not improve from 0.97964
# 6280/6280 [==============================] - 6s 928us/sample - loss: 1.3474 - mean_squared_error: 1.3474 - val_loss: 1.0410 - val_mean_squared_error: 1.0410
# Epoch 45/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.2453 - mean_squared_error: 1.2453
# Epoch 00045: val_mean_squared_error did not improve from 0.97964
# 6280/6280 [==============================] - 6s 933us/sample - loss: 1.2480 - mean_squared_error: 1.2480 - val_loss: 4.3145 - val_mean_squared_error: 4.3145
# Epoch 46/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.2830 - mean_squared_error: 1.2830
# Epoch 00046: val_mean_squared_error did not improve from 0.97964
# 6280/6280 [==============================] - 6s 927us/sample - loss: 1.2825 - mean_squared_error: 1.2825 - val_loss: 1.4093 - val_mean_squared_error: 1.4093
# Epoch 47/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.3005 - mean_squared_error: 1.3005
# Epoch 00047: val_mean_squared_error did not improve from 0.97964
# 6280/6280 [==============================] - 6s 945us/sample - loss: 1.2955 - mean_squared_error: 1.2955 - val_loss: 3.2258 - val_mean_squared_error: 3.2258
# Epoch 48/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.2748 - mean_squared_error: 1.2748
# Epoch 00048: val_mean_squared_error did not improve from 0.97964
# 6280/6280 [==============================] - 6s 940us/sample - loss: 1.2767 - mean_squared_error: 1.2767 - val_loss: 1.0956 - val_mean_squared_error: 1.0956
# Epoch 49/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.3533 - mean_squared_error: 1.3533
# Epoch 00049: val_mean_squared_error did not improve from 0.97964
# 6280/6280 [==============================] - 6s 942us/sample - loss: 1.3543 - mean_squared_error: 1.3543 - val_loss: 3.7557 - val_mean_squared_error: 3.7557
# Epoch 50/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.2556 - mean_squared_error: 1.2556
# Epoch 00050: val_mean_squared_error did not improve from 0.97964
# 6280/6280 [==============================] - 6s 931us/sample - loss: 1.2543 - mean_squared_error: 1.2543 - val_loss: 4.5866 - val_mean_squared_error: 4.5866
# Epoch 51/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.1917 - mean_squared_error: 1.1917
# Epoch 00051: val_mean_squared_error did not improve from 0.97964
# 6280/6280 [==============================] - 6s 936us/sample - loss: 1.1931 - mean_squared_error: 1.1931 - val_loss: 1.0901 - val_mean_squared_error: 1.0901
# Epoch 52/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.2993 - mean_squared_error: 1.2993
# Epoch 00052: val_mean_squared_error did not improve from 0.97964
# 6280/6280 [==============================] - 6s 928us/sample - loss: 1.2969 - mean_squared_error: 1.2969 - val_loss: 1.4721 - val_mean_squared_error: 1.4721
# Epoch 53/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.2445 - mean_squared_error: 1.2445
# Epoch 00053: val_mean_squared_error did not improve from 0.97964
# 6280/6280 [==============================] - 6s 938us/sample - loss: 1.2436 - mean_squared_error: 1.2436 - val_loss: 1.3675 - val_mean_squared_error: 1.3675
# Epoch 54/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.2819 - mean_squared_error: 1.2819
# Epoch 00054: val_mean_squared_error did not improve from 0.97964
# 6280/6280 [==============================] - 6s 928us/sample - loss: 1.2932 - mean_squared_error: 1.2932 - val_loss: 2.5842 - val_mean_squared_error: 2.5842
# Epoch 55/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.1966 - mean_squared_error: 1.1966
# Epoch 00055: val_mean_squared_error did not improve from 0.97964
# 6280/6280 [==============================] - 6s 941us/sample - loss: 1.1965 - mean_squared_error: 1.1965 - val_loss: 1.6616 - val_mean_squared_error: 1.6616
# Epoch 56/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.2344 - mean_squared_error: 1.2344
# Epoch 00056: val_mean_squared_error improved from 0.97964 to 0.93475, saving model to ./models/original/cnn_model_matrix_h11.h5
# 6280/6280 [==============================] - 6s 949us/sample - loss: 1.2315 - mean_squared_error: 1.2315 - val_loss: 0.9347 - val_mean_squared_error: 0.9347
# Epoch 57/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.2801 - mean_squared_error: 1.2801
# Epoch 00057: val_mean_squared_error did not improve from 0.93475
# 6280/6280 [==============================] - 6s 933us/sample - loss: 1.2787 - mean_squared_error: 1.2787 - val_loss: 1.1728 - val_mean_squared_error: 1.1728
# Epoch 58/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.1773 - mean_squared_error: 1.1773
# Epoch 00058: val_mean_squared_error did not improve from 0.93475
# 6280/6280 [==============================] - 6s 923us/sample - loss: 1.1862 - mean_squared_error: 1.1862 - val_loss: 2.7400 - val_mean_squared_error: 2.7400
# Epoch 59/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1
val_mean_squared_error did not improve from 0.93475
# 6280/6280 [==============================] - 6s 932us/sample - loss: 1.0959 - mean_squared_error: 1.0959 - val_loss: 3.4365 - val_mean_squared_error: 3.4365
# Epoch 91/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.1528 - mean_squared_error: 1.1528
# Epoch 00091: val_mean_squared_error did not improve from 0.93475
# 6280/6280 [==============================] - 6s 928us/sample - loss: 1.1499 - mean_squared_error: 1.1499 - val_loss: 1.3019 - val_mean_squared_error: 1.3019
# Epoch 92/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.0339 - mean_squared_error: 1.0339
# Epoch 00092: val_mean_squared_error did not improve from 0.93475
# 6280/6280 [==============================] - 6s 924us/sample - loss: 1.0357 - mean_squared_error: 1.0357 - val_loss: 1.2551 - val_mean_squared_error: 1.2551
# Epoch 93/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.0861 - mean_squared_error: 1.0861
# Epoch 00093: val_mean_squared_error did not improve from 0.93475
# 6280/6280 [==============================] - 6s 944us/sample - loss: 1.0850 - mean_squared_error: 1.0850 - val_loss: 1.3707 - val_mean_squared_error: 1.3707
# Epoch 94/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.1183 - mean_squared_error: 1.1183
# Epoch 00094: val_mean_squared_error did not improve from 0.93475
# 6280/6280 [==============================] - 6s 918us/sample - loss: 1.1190 - mean_squared_error: 1.1190 - val_loss: 1.3775 - val_mean_squared_error: 1.3775
# Epoch 95/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.0512 - mean_squared_error: 1.0512
# Epoch 00095: val_mean_squared_error did not improve from 0.93475
# 6280/6280 [==============================] - 6s 938us/sample - loss: 1.0524 - mean_squared_error: 1.0524 - val_loss: 1.4279 - val_mean_squared_error: 1.4279
# Epoch 96/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.1280 - mean_squared_error: 1.1280
# Epoch 00096: val_mean_squared_error did not improve from 0.93475
# 6280/6280 [==============================] - 6s 929us/sample - loss: 1.1323 - mean_squared_error: 1.1323 - val_loss: 5.4761 - val_mean_squared_error: 5.4761
# Epoch 97/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.1049 - mean_squared_error: 1.1049
# Epoch 00097: val_mean_squared_error did not improve from 0.93475
# 6280/6280 [==============================] - 6s 941us/sample - loss: 1.1036 - mean_squared_error: 1.1036 - val_loss: 1.3280 - val_mean_squared_error: 1.3280
# Epoch 98/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.0584 - mean_squared_error: 1.0584
# Epoch 00098: val_mean_squared_error did not improve from 0.93475
# 6280/6280 [==============================] - 6s 941us/sample - loss: 1.0562 - mean_squared_error: 1.0562 - val_loss: 1.0236 - val_mean_squared_error: 1.0236
# Epoch 99/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.0721 - mean_squared_error: 1.0721
# Epoch 00099: val_mean_squared_error did not improve from 0.93475
# 6280/6280 [==============================] - 6s 924us/sample - loss: 1.0722 - mean_squared_error: 1.0722 - val_loss: 1.2478 - val_mean_squared_error: 1.2478
# Epoch 100/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.1007 - mean_squared_error: 1.1007
# Epoch 00100: val_mean_squared_error improved from 0.93475 to 0.85182, saving model to ./models/original/cnn_model_matrix_h11.h5
# 6280/6280 [==============================] - 6s 965us/sample - loss: 1.1020 - mean_squared_error: 1.1020 - val_loss: 0.8518 - val_mean_squared_error: 0.8518
# Epoch 101/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.1026 - mean_squared_error: 1.1026
# Epoch 00101: val_mean_squared_error did not improve from 0.85182
# 6280/6280 [==============================] - 6s 944us/sample - loss: 1.0995 - mean_squared_error: 1.0995 - val_loss: 1.2467 - val_mean_squared_error: 1.2467
# Epoch 102/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.1011 - mean_squared_error: 1.1011
# Epoch 00102: val_mean_squared_error did not improve from 0.85182
# 6280/6280 [==============================] - 6s 933us/sample - loss: 1.1023 - mean_squared_error: 1.1023 - val_loss: 1.9102 - val_mean_squared_error: 1.9102
# Epoch 103/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.0738 - mean_squared_error: 1.0738
# Epoch 00103: val_mean_squared_error did not improve from 0.85182
# 6280/6280 [==============================] - 6s 923us/sample - loss: 1.0766 - mean_squared_error: 1.0766 - val_loss: 1.7840 - val_mean_squared_error: 1.7840
# Epoch 104/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.0940 - mean_squared_error: 1.0940
# Epoch 00104: val_mean_squared_error did not improve from 0.85182
# 6280/6280 [==============================] - 6s 930us/sample - loss: 1.0940 - mean_squared_error: 1.0940 - val_loss: 2.0113 - val_mean_squared_error: 2.0113
# Epoch 105/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.0655 - mean_squared_error: 1.0655
# Epoch 00105: val_mean_squared_error did not improve from 0.85182
# 6280/6280 [==============================] - 6s 928us/sample - loss: 1.0652 - mean_squared_error: 1.0652 - val_loss: 2.9317 - val_mean_squared_error: 2.9317
# Epoch 106/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.0662 - mean_squared_error: 1.0662
# Epoch 00106: val_mean_squared_error did not improve from 0.85182
# 6280/6280 [==============================] - 6s 920us/sample - loss: 1.0654 - mean_squared_error: 1.0654 - val_loss: 0.9205 - val_mean_squared_error: 0.9205
# Epoch 107/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.1036 - mean_squared_error: 1.1036
# Epoch 00107: val_mean_squared_error did not improve from 0.85182
# 6280/6280 [==============================] - 6s 925us/sample - loss: 1.1068 - mean_squared_error: 1.1068 - val_loss: 4.2719 - val_mean_squared_error: 4.2719
# Epoch 108/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.0315 - mean_squared_error: 1.0315
# Epoch 00108: val_mean_squared_error did not improve from 0.85182
# 6280/6280 [==============================] - 6s 915us/sample - loss: 1.0319 - mean_squared_error: 1.0319 - val_loss: 2.2139 - val_mean_squared_error: 2.2139
# Epoch 109/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.0372 - mean_squared_error: 1.0372
# Epoch 00109: val_mean_squared_error did not improve from 0.85182
# 6280/6280 [==============================] - 6s 926us/sample - loss: 1.0338 - mean_squared_error: 1.0338 - val_loss: 1.1799 - val_mean_squared_error: 1.1799
# Epoch 110/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.0611 - mean_squared_error: 1.0611
# Epoch 00110: val_mean_squared_error did not improve from 0.85182
# 6280/6280 [==============================] - 6s 925us/sample - loss: 1.0577 - mean_squared_error: 1.0577 - val_loss: 1.4921 - val_mean_squared_error: 1.4921
# Epoch 111/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.0653 - mean_squared_error: 1.0653
# Epoch 00111: val_mean_squared_error did not improve from 0.85182
# 6280/6280 [==============================] - 6s 922us/sample - loss: 1.0696 - mean_squared_error: 1.0696 - val_loss: 1.7797 - val_mean_squared_error: 1.7797
# Epoch 112/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.0745 - mean_squared_error: 1.0745
# Epoch 00112: val_mean_squared_error did not improve from 0.85182
# 6280/6280 [==============================] - 6s 919us/sample - loss: 1.0710 - mean_squared_error: 1.0710 - val_loss: 0.9798 - val_mean_squared_error: 0.9798
# Epoch 113/500
# 6272/6280 [============================>.] - ETA: 0s - loss: 1.0742 - mean_squared_error: 1.0742
# Epoch 00113: val_mean_squared_error did not improve from 0.85182
# 6280/6280 [==============================] - 6s 932us/sample - loss: 1.0735 - mean_squared_error: 1.0735 - val_loss: 0.9127 - val_mean_squared_error: 0.9127
# Epoch 114/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.0363 - mean_squared_error: 1.0363
# Epoch 00114: val_mean_squared_error did not improve from 0.85182
# 6280/6280 [==============================] - 6s 916us/sample - loss: 1.0404 - mean_squared_error: 1.0404 - val_loss: 4.6788 - val_mean_squared_error: 4.6788
# Epoch 115/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.0430 - mean_squared_error: 1.0430
# Epoch 00115: val_mean_squared_error did not improve from 0.85182
# 6280/6280 [==============================] - 6s 921us/sample - loss: 1.0399 - mean_squared_error: 1.0399 - val_loss: 2.0171 - val_mean_squared_error: 2.0171
# Epoch 116/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.0735 - mean_squared_error: 1.0735
# Epoch 00116: val_mean_squared_error did not improve from 0.85182
# 6280/6280 [==============================] - 6s 923us/sample - loss: 1.0730 - mean_squared_error: 1.0730 - val_loss: 2.3169 - val_mean_squared_error: 2.3169
# Epoch 117/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.0413 - mean_squared_error: 1.0413
# Epoch 00117: val_mean_squared_error improved from 0.85182 to 0.78876, saving model to ./models/original/cnn_model_matrix_h11.h5
# 6280/6280 [==============================] - 6s 950us/sample - loss: 1.0409 - mean_squared_error: 1.0409 - val_loss: 0.7888 - val_mean_squared_error: 0.7888
# Epoch 118/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.0543 - mean_squared_error: 1.0543
# Epoch 00118: val_mean_squared_error improved from 0.78876 to 0.77153, saving model to ./models/original/cnn_model_matrix_h11.h5
# 6280/6280 [==============================] - 6s 944us/sample - loss: 1.0510 - mean_squared_error: 1.0510 - val_loss: 0.7715 - val_mean_squared_error: 0.7715
# Epoch 119/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.0920 - mean_squared_error: 1.0920
# Epoch 00119: val_mean_squared_error did not improve from 0.77153
# 6280/6280 [==============================] - 6s 952us/sample - loss: 1.0895 - mean_squared_error: 1.0895 - val_loss: 2.3845 - val_mean_squared_error: 2.3845
# Epoch 120/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.0264 - mean_squared_error: 1.0264
# Epoch 00120: val_mean_squared_error did not improve from 0.77153
# 6280/6280 [==============================] - 6s 947us/sample - loss: 1.0256 - mean_squared_error: 1.0256 - val_loss: 3.4904 - val_mean_squared_error: 3.4904
# Epoch 121/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.0319 - mean_squared_error: 1.0319
# Epoch 00121: val_mean_squared_error did not improve from 0.77153
# 6280/6280 [==============================] - 6s 934us/sample - loss: 1.0338 - mean_squared_error: 1.0338 - val_loss: 1.3048 - val_mean_squared_error: 1.3048
# Epoch 122/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.0739 - mean_squared_error: 1.0739
# Epoch 00122: val_mean_squared_error did not improve from 0.77153
# 6280/6280 [==============================] - 6s 917us/sample - loss: 1.0737 - mean_squared_error: 1.0737 - val_loss: 6.3529 - val_mean_squared_error: 6.3529
# Epoch 123/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.0566 - mean_squared_error: 1.0566
# Epoch 00123: val_mean_squared_error did not improve from 0.77153
# 6280/6280 [==============================] - 6s 931us/sample - loss: 1.0560 - mean_squared_error: 1.0560 - val_loss: 1.3591 - val_mean_squared_error: 1.3591
# Epoch 124/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 0.9832 - mean_squared_error: 0.9832
# Epoch 00124: val_mean_squared_error did not improve from 0.77153
# 6280/6280 [==============================] - 6s 927us/sample - loss: 0.9918 - mean_squared_error: 0.9918 - val_loss: 1.2829 - val_mean_squared_error: 1.2829
# Epoch 125/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.0426 - mean_squared_error: 1.0426
# Epoch 00125: val_mean_squared_error did not improve from 0.77153
# 6280/6280 [==============================] - 6s 940us/sample - loss: 1.0470 - mean_squared_error: 1.0470 - val_loss: 2.6139 - val_mean_squared_error: 2.6139
# Epoch 126/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.0130 - mean_squared_error: 1.0130
# Epoch 00126: val_mean_squared_error did not improve from 0.77153
# 6280/6280 [==============================] - 6s 938us/sample - loss: 1.0141 - mean_squared_error: 1.0141 - val_loss: 1.1759 - val_mean_squared_error: 1.1759
# Epoch 127/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.0313 - mean_squared_error: 1.0313
# Epoch 00127: val_mean_squared_error did not improve from 0.77153
# 6280/6280 [==============================] - 6s 930us/sample - loss: 1.0324 - mean_squared_error: 1.0324 - val_loss: 2.7418 - val_mean_squared_error: 2.7418
# Epoch 128/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.0190 - mean_squared_error: 1.0190
# Epoch 00128: val_mean_squared_error did not improve from 0.77153
# 6280/6280 [==============================] - 6s 928us/sample - loss: 1.0186 - mean_squared_error: 1.0186 - val_loss: 0.9480 - val_mean_squared_error: 0.9480
# Epoch 129/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.0084 - mean_squared_error: 1.0084
# Epoch 00129: val_mean_squared_error did not improve from 0.77153
# 6280/6280 [==============================] - 6s 937us/sample - loss: 1.0127 - mean_squared_error: 1.0127 - val_loss: 2.3467 - val_mean_squared_error: 2.3467
# Epoch 130/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.0218 - mean_squared_error: 1.0218
# Epoch 00130: val_mean_squared_error did not improve from 0.77153
# 6280/6280 [==============================] - 6s 924us/sample - loss: 1.0216 - mean_squared_error: 1.0216 - val_loss: 2.7522 - val_mean_squared_error: 2.7522
# Epoch 131/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.0540 - mean_squared_error: 1.0540
# Epoch 00131: val_mean_squared_error did not improve from 0.77153
# 6280/6280 [==============================] - 6s 957us/sample - loss: 1.0514 - mean_squared_error: 1.0514 - val_loss: 5.2800 - val_mean_squared_error: 5.2800
# Epoch 132/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.0541 - mean_squared_error: 1.0541
# Epoch 00132: val_mean_squared_error did not improve from 0.77153
# 6280/6280 [==============================] - 6s 926us/sample - loss: 1.0521 - mean_squared_error: 1.0521 - val_loss: 1.2150 - val_mean_squared_error: 1.2150
# Epoch 133/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 0.9915 - mean_squared_error: 0.9915
# Epoch 00133: val_mean_squared_error did not improve from 0.77153
# 6280/6280 [==============================] - 6s 937us/sample - loss: 0.9925 - mean_squared_error: 0.9925 - val_loss: 0.8678 - val_mean_squared_error: 0.8678
# Epoch 134/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.0504 - mean_squared_error: 1.0504
# Epoch 00134: val_mean_squared_error did not improve from 0.77153
# 6280/6280 [==============================] - 6s 923us/sample - loss: 1.0530 - mean_squared_error: 1.0530 - val_loss: 0.8576 - val_mean_squared_error: 0.8576
# Epoch 135/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.0181 - mean_squared_error: 1.0181
# Epoch 00135: val_mean_squared_error did not improve from 0.77153
# 6280/6280 [==============================] - 6s 925us/sample - loss: 1.0161 - mean_squared_error: 1.0161 - val_loss: 1.1279 - val_mean_squared_error: 1.1279
# Epoch 136/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.0369 - mean_squared_error: 1.0369
# Epoch 00136: val_mean_squared_error did not improve from 0.77153
# 6280/6280 [==============================] - 6s 917us/sample - loss: 1.0346 - mean_squared_error: 1.0346 - val_loss: 0.9823 - val_mean_squared_error: 0.9823
# Epoch 137/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 1.
val_mean_squared_error did not improve from 0.76018
# 6280/6280 [==============================] - 6s 933us/sample - loss: 0.9310 - mean_squared_error: 0.9310 - val_loss: 3.0065 - val_mean_squared_error: 3.0065
# Epoch 212/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 0.9225 - mean_squared_error: 0.9225
# Epoch 00212: val_mean_squared_error did not improve from 0.76018
# 6280/6280 [==============================] - 6s 927us/sample - loss: 0.9225 - mean_squared_error: 0.9225 - val_loss: 1.3162 - val_mean_squared_error: 1.3162
# Epoch 213/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 0.8992 - mean_squared_error: 0.8992
# Epoch 00213: val_mean_squared_error did not improve from 0.76018
# 6280/6280 [==============================] - 6s 947us/sample - loss: 0.8999 - mean_squared_error: 0.8999 - val_loss: 0.8446 - val_mean_squared_error: 0.8446
# Epoch 214/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 0.8693 - mean_squared_error: 0.8693
# Epoch 00214: val_mean_squared_error did not improve from 0.76018
# 6280/6280 [==============================] - 6s 932us/sample - loss: 0.8670 - mean_squared_error: 0.8670 - val_loss: 0.8953 - val_mean_squared_error: 0.8953
# Epoch 215/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 0.9041 - mean_squared_error: 0.9041
# Epoch 00215: val_mean_squared_error did not improve from 0.76018
# 6280/6280 [==============================] - 6s 932us/sample - loss: 0.9045 - mean_squared_error: 0.9045 - val_loss: 3.9499 - val_mean_squared_error: 3.9499
# Epoch 216/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 0.9173 - mean_squared_error: 0.9173
# Epoch 00216: val_mean_squared_error did not improve from 0.76018
# 6280/6280 [==============================] - 6s 923us/sample - loss: 0.9158 - mean_squared_error: 0.9158 - val_loss: 0.7629 - val_mean_squared_error: 0.7629
# Epoch 217/500
# 6240/6280 [============================>.] - ETA: 0s - loss: 0.8718 - mean_squared_error: 0.8718Restoring model weights from the end of the best epoch.
#
# Epoch 00217: val_mean_squared_error did not improve from 0.76018
# 6280/6280 [==============================] - 6s 935us/sample - loss: 0.8770 - mean_squared_error: 0.8770 - val_loss: 1.1975 - val_mean_squared_error: 1.1975
# Epoch 00217: early stopping

# %% [markdown]
# Using the history attribute of the model, we plot the history of the model for $h_{11}$:

# %%
xplots  = 2
yplots  = 1

fig, ax = plt.subplots(yplots, xplots, figsize=(xplots*mpl_width, yplots*mpl_height))
fig.tight_layout()

series_plot(ax[0], model_h11_history.history['loss'],     title='Model Loss Function', xlabel='Epoch', ylabel='Loss function', legend='training')
series_plot(ax[0], model_h11_history.history['val_loss'], title='Model Loss Function', xlabel='Epoch', ylabel='Loss function', legend='validation')

series_plot(ax[1], model_h11_history.history['mean_squared_error'],     title='Mean Squared Error', xlabel='Epoch', ylabel='MSE', legend='training')
series_plot(ax[1], model_h11_history.history['val_mean_squared_error'], title='Mean Squared Error', xlabel='Epoch', ylabel='MSE', legend='validation')

save_fig('cnn_model_h11_matrix.png', logger=logger)

plt.show()
plt.close(fig)
# Out:
# 2020-04-13 22:11:24,219 --> INFO: Saving ./img/original/cnn_model_h11_matrix.png.png...
# 2020-04-13 22:11:24,401 --> INFO: Saved ./img/original/cnn_model_h11_matrix.png.png!

# %% [markdown]
# As for the evaluation and the accuracy of the predictions, we first look at the evaluation metric on the test set and then compute the accuracy of the model:

# %%
logprint('MSE on the test set for h11: {:.3f}'.format(model.evaluate(x=matrix_test, y=h11_test, verbose=0)[1]), logger=logger)
prediction_score(estimator=model, X=matrix_test.astype(np.float16), y=h11_test, use_best_estimator=False, rounding=np.rint, logger=logger)
# Out:
# 2020-04-13 22:11:24,882 --> INFO: MSE on the test set for h11: 0.591
# 2020-04-13 22:11:25,170 --> INFO: Accuracy (rint) of the predictions: 66.794%
