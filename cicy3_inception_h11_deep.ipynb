# %% [markdown]
# # Machine Learning for CICY 3-Folds
#
# We compute the Hodge numbers of CICY 3-folds using deep learning techniques inspired by the Inception architecture by Google.

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import tarfile
import urllib
import json
import joblib
from IPython.display import Image
from nntools import *

# %%
random_state = 123
np.random.seed(random_state)
tf.random.set_seed(random_state)

# %% [markdown]
# ## Create a Saving Directory
#
# Each model will be assigned to a different directory based on the time of running.

# %%
img_dir, mod_dir = dir_struct('inception_h11_deep', dirs=['img', 'models'])
# Out:
# Current working directories:
#
#   ./img/inception_h11_deep_20201221_203313
#   ./models/inception_h11_deep_20201221_203313

# %% [markdown]
# ## Load the Dataset
#
# We then download the JSON file containing the configuration matrix and the Hodge numbers of the CICY.

# %%
os.makedirs('./data', exist_ok=True)

urllib.request.urlretrieve('http://www.lpthe.jussieu.fr/~erbin/files/data/cicy3o_data.tar.gz', './data/cicy3o_data.tar.gz')
with tarfile.open('./data/cicy3o_data.tar.gz', 'r') as tar:
    tar.extract('cicy3o.h5', path='./data')

# %%
df, (n_rows, n_cols) = load_hdf('./data/cicy3o.h5')
# Out:
# Size of the dataset: 7890 rows, 31 columns.

# %% [markdown]
# We then select only the non product spaces:

# %%
df = df.loc[df['isprod'] == False]

# %% [markdown]
# We the pad the matrix to get the same size for all configuration matrices:

# %%
max_size = df['matrix'].apply(np.shape).max()

df.loc[:, 'matrix'] = df['matrix'].apply(lambda x: np.pad(x, ((0, max_size[0] - np.shape(x)[0]), (0, max_size[1] - np.shape(x)[1]))))
df = df[['h11', 'h21', 'matrix']]
n_rows, n_cols = df.shape

# %%
num_classes = (int(df['h11'].max() + 1), int(df['h21'].max() + 1))

# %% [markdown]
# We then split it into train, validation and test sets:

# %%
df_splits = {'train_split': 0.80, 'val_split': 0.5}
with open(os.path.join(mod_dir, 'train_ratio.json'), 'w') as f:
    json.dump(df_splits, f)

# split the sets
(df_train, df_val, df_test), (n_train, n_val, n_test) = train_test(df, df_splits, random_state=random_state)

# %%
del df

# %% [markdown]
# ## Outliers in the Training Set
#
# We then study the outliers in the training set:

# %%
# remove outliers
df_train = df_train.loc[(df_train['h11'] >= 1) & (df_train['h11'] <= 16)
                        &
                        (df_train['h21'] >= 15) & (df_train['h21'] <= 86)
                       ]
n_train_pruned = df_train.shape[0]

# %%
print(f'Samples removed: {n_train - n_train_pruned:d} ({100 * (n_train - n_train_pruned) / n_train:.2f}% of the training set, {100 * (n_train - n_train_pruned) / n_rows:.2f}% of the total set)')
# Out:
# Samples removed: 12 (0.19% of the training set, 0.15% of the total set)

# %% [markdown]
# ## Rescale the Matrices
#
# We then rescale the matrices in the sets to improve the deep learning results:

# %%
# rescaling = {'min': df_train['matrix'].apply(lambda x: np.min(x)).min(),
#              'max': df_train['matrix'].apply(lambda x: np.max(x)).max()
#             }
rescaling = None

# %% [markdown]
# ## Feature and Label Creation
#
# We then create the features and the labels.

# %%
reshape = df_train['matrix'].apply(np.shape).max() + (1,)

# %%
X_train = create_features(df_train['matrix'], rescaling=rescaling, reshape=reshape)
X_val   = create_features(df_val['matrix'], rescaling=rescaling, reshape=reshape)
X_test  = create_features(df_test['matrix'], rescaling=rescaling, reshape=reshape)

# %%
y_train = create_labels(df_train[['h11']], one_hot=True, num_classes=num_classes[0])
y_val   = create_labels(df_val[['h11']], one_hot=True, num_classes=num_classes[0])
y_test  = create_labels(df_test[['h11']], one_hot=True, num_classes=num_classes[0])

# %%
del df_train, df_val, df_test

# %% [markdown]
# ## Inception Model
#
# We then start to build the Inception model to be trained on the configuration matrices.

# %% [markdown]
# ### Build the Model

# %%
model_data = {'input_shape':   reshape,
              'name':          'matrix',
              'learning_rate': 1.0e-3,
              'output_names':  'h11',
              'output_size':   num_classes[0],
              'model_type':    'classification',
              'conv_1b1':      False,
              'conv_layers':   [128, 64, 64, 32, 32],
              'conv_alpha':    0.0,
              'conv_class':    None,
              'conv_single':   False,
              'conv_red':      0,
              'feat_map':      0,
              'recurrent':     False,
              'fc_layers':     [],
              'fc_alpha':      0.0,
              'dropout':       0.0,
              'full_dropout':  0.1,
              'batchnorm':     0.99,
              'last_relu':     False,
              'loss_weights':  None,
              'l1_reg':        1.0e-3,
              'l2_reg':        1.0e-3,
              'output_layers': True,
              'random_state':  random_state
             }

with open(os.path.join(mod_dir, 'model_data.json'), 'w') as f:
    json.dump(model_data, f)

# %%
inception = nn_inception(**model_data)
inception.summary()
# Out:
# Model: "matrix"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# matrix (InputLayer)             [(None, 12, 15, 1)]  0
# __________________________________________________________________________________________________
# matrix_convAa_0 (Conv2D)        (None, 12, 15, 128)  1664        matrix[0][0]
# __________________________________________________________________________________________________
# matrix_convAb_0 (Conv2D)        (None, 12, 15, 128)  2048        matrix[0][0]
# __________________________________________________________________________________________________
# matrix_actAa_0 (LeakyReLU)      (None, 12, 15, 128)  0           matrix_convAa_0[0][0]
# __________________________________________________________________________________________________
# matrix_actAb_0 (LeakyReLU)      (None, 12, 15, 128)  0           matrix_convAb_0[0][0]
# __________________________________________________________________________________________________
# matrix_cat_0 (Concatenate)      (None, 12, 15, 256)  0           matrix_actAa_0[0][0]
#                                                                  matrix_actAb_0[0][0]
# __________________________________________________________________________________________________
# matrix_convBN_0 (BatchNormaliza (None, 12, 15, 256)  1024        matrix_cat_0[0][0]
# __________________________________________________________________________________________________
# matrix_convFullDrop_0 (Dropout) (None, 12, 15, 256)  0           matrix_convBN_0[0][0]
# __________________________________________________________________________________________________
# matrix_convAa_1 (Conv2D)        (None, 12, 15, 64)   196672      matrix_convFullDrop_0[0][0]
# __________________________________________________________________________________________________
# matrix_convAb_1 (Conv2D)        (None, 12, 15, 64)   245824      matrix_convFullDrop_0[0][0]
# __________________________________________________________________________________________________
# matrix_actAa_1 (LeakyReLU)      (None, 12, 15, 64)   0           matrix_convAa_1[0][0]
# __________________________________________________________________________________________________
# matrix_actAb_1 (LeakyReLU)      (None, 12, 15, 64)   0           matrix_convAb_1[0][0]
# __________________________________________________________________________________________________
# matrix_cat_1 (Concatenate)      (None, 12, 15, 128)  0           matrix_actAa_1[0][0]
#                                                                  matrix_actAb_1[0][0]
# __________________________________________________________________________________________________
# matrix_convBN_1 (BatchNormaliza (None, 12, 15, 128)  512         matrix_cat_1[0][0]
# __________________________________________________________________________________________________
# matrix_convFullDrop_1 (Dropout) (None, 12, 15, 128)  0           matrix_convBN_1[0][0]
# __________________________________________________________________________________________________
# matrix_convAa_2 (Conv2D)        (None, 12, 15, 64)   98368       matrix_convFullDrop_1[0][0]
# __________________________________________________________________________________________________
# matrix_convAb_2 (Conv2D)        (None, 12, 15, 64)   122944      matrix_convFullDrop_1[0][0]
# __________________________________________________________________________________________________
# matrix_actAa_2 (LeakyReLU)      (None, 12, 15, 64)   0           matrix_convAa_2[0][0]
# __________________________________________________________________________________________________
# matrix_actAb_2 (LeakyReLU)      (None, 12, 15, 64)   0           matrix_convAb_2[0][0]
# __________________________________________________________________________________________________
# matrix_cat_2 (Concatenate)      (None, 12, 15, 128)  0           matrix_actAa_2[0][0]
#                                                                  matrix_actAb_2[0][0]
# __________________________________________________________________________________________________
# matrix_convBN_2 (BatchNormaliza (None, 12, 15, 128)  512         matrix_cat_2[0][0]
# __________________________________________________________________________________________________
# matrix_convFullDrop_2 (Dropout) (None, 12, 15, 128)  0           matrix_convBN_2[0][0]
# __________________________________________________________________________________________________
# matrix_convAa_3 (Conv2D)        (None, 12, 15, 32)   49184       matrix_convFullDrop_2[0][0]
# __________________________________________________________________________________________________
# matrix_convAb_3 (Conv2D)        (None, 12, 15, 32)   61472       matrix_convFullDrop_2[0][0]
# __________________________________________________________________________________________________
# matrix_actAa_3 (LeakyReLU)      (None, 12, 15, 32)   0           matrix_convAa_3[0][0]
# __________________________________________________________________________________________________
# matrix_actAb_3 (LeakyReLU)      (None, 12, 15, 32)   0           matrix_convAb_3[0][0]
# __________________________________________________________________________________________________
# matrix_cat_3 (Concatenate)      (None, 12, 15, 64)   0           matrix_actAa_3[0][0]
#                                                                  matrix_actAb_3[0][0]
# __________________________________________________________________________________________________
# matrix_convBN_3 (BatchNormaliza (None, 12, 15, 64)   256         matrix_cat_3[0][0]
# __________________________________________________________________________________________________
# matrix_convFullDrop_3 (Dropout) (None, 12, 15, 64)   0           matrix_convBN_3[0][0]
# __________________________________________________________________________________________________
# matrix_convAa_4 (Conv2D)        (None, 12, 15, 32)   24608       matrix_convFullDrop_3[0][0]
# __________________________________________________________________________________________________
# matrix_convAb_4 (Conv2D)        (None, 12, 15, 32)   30752       matrix_convFullDrop_3[0][0]
# __________________________________________________________________________________________________
# matrix_actAa_4 (LeakyReLU)      (None, 12, 15, 32)   0           matrix_convAa_4[0][0]
# __________________________________________________________________________________________________
# matrix_actAb_4 (LeakyReLU)      (None, 12, 15, 32)   0           matrix_convAb_4[0][0]
# __________________________________________________________________________________________________
# matrix_cat_4 (Concatenate)      (None, 12, 15, 64)   0           matrix_actAa_4[0][0]
#                                                                  matrix_actAb_4[0][0]
# __________________________________________________________________________________________________
# matrix_convBN_4 (BatchNormaliza (None, 12, 15, 64)   256         matrix_cat_4[0][0]
# __________________________________________________________________________________________________
# matrix_convFullDrop_4 (Dropout) (None, 12, 15, 64)   0           matrix_convBN_4[0][0]
# __________________________________________________________________________________________________
# matrix_flat (Flatten)           (None, 11520)        0           matrix_convFullDrop_4[0][0]
# __________________________________________________________________________________________________
# h11 (Dense)                     (None, 20)           230420      matrix_flat[0][0]
# ==================================================================================================
# Total params: 1,066,516
# Trainable params: 1,065,236
# Non-trainable params: 1,280
# __________________________________________________________________________________________________

# %%
inception_graph = keras.utils.model_to_dot(inception, show_shapes=True, dpi=144)
inception_graph.write_pdf(os.path.join(img_dir, 'inception.pdf'))
Image(inception_graph.create_png(), width=480)

# %% [markdown]
# ### Train the Model

# %%
fit_data = {'epochs':             1000,
            'batch_size':         32,
            'reduce_lr_factor':   0.3,
            'reduce_lr_patience': 350,
            'stat_interval':      100
           }

with open(os.path.join(mod_dir, 'fit_data.json'), 'w') as f:
    json.dump(fit_data, f)

# %%
callbacks = model_checkpoints(root=mod_dir,
                              validation=True,
                              reduce_lr=fit_data['reduce_lr_factor'],
                              lr_patience=fit_data['reduce_lr_patience'],
                              summary=fit_data['stat_interval']
                             )

inception_hst = inception.fit(x=X_train,
                              y=y_train,
                              batch_size=fit_data['batch_size'],
                              epochs=fit_data['epochs'],
                              verbose=0,
                              callbacks=callbacks,
                              validation_data=(X_val, y_val)
                             )
# Out:
# Training has started. Callouts will be printed every 50 epochs.
#
# Training epoch 1. Started on 21/12/2020 at 20:33:20.
#
#     Average epoch training time: 00 hours, 00 minutes, 38 seconds
#
#     loss = 16.310640
#     categorical_accuracy = 0.586597
#     val_loss = 14.854782
#     val_categorical_accuracy = 0.083863
#     lr = 0.001000
#
# Training epoch 50. Started on 21/12/2020 at 20:35:06.
#
#     Average epoch training time: 00 hours, 00 minutes, 19 seconds
#
#     loss = 0.487022
#     categorical_accuracy = 0.978828
#     val_loss = 0.840594
#     val_categorical_accuracy = 0.930114
#     lr = 0.001000
#
# Training epoch 100. Started on 21/12/2020 at 20:36:14.
#
#     Average epoch training time: 00 hours, 00 minutes, 13 seconds
#
#     loss = 0.438409
#     categorical_accuracy = 0.975167
#     val_loss = 0.759089
#     val_categorical_accuracy = 0.912325
#     lr = 0.001000
#
# Training epoch 150. Started on 21/12/2020 at 20:37:23.
#
#     Average epoch training time: 00 hours, 00 minutes, 10 seconds
#
#     loss = 0.327955
#     categorical_accuracy = 0.984400
#     val_loss = 0.618251
#     val_categorical_accuracy = 0.956798
#     lr = 0.001000
#
# Training epoch 200. Started on 21/12/2020 at 20:38:32.
#
#     Average epoch training time: 00 hours, 00 minutes, 08 seconds
#
#     loss = 0.307285
#     categorical_accuracy = 0.987106
#     val_loss = 0.738541
#     val_categorical_accuracy = 0.923761
#     lr = 0.001000
#
# Training epoch 250. Started on 21/12/2020 at 20:39:41.
#
#     Average epoch training time: 00 hours, 00 minutes, 07 seconds
#
#     loss = 0.341166
#     categorical_accuracy = 0.980261
#     val_loss = 0.784037
#     val_categorical_accuracy = 0.945362
#     lr = 0.001000
#
# Training epoch 300. Started on 21/12/2020 at 20:40:50.
#
#     Average epoch training time: 00 hours, 00 minutes, 06 seconds
#
#     loss = 0.141212
#     categorical_accuracy = 0.993314
#     val_loss = 0.482979
#     val_categorical_accuracy = 0.961881
#     lr = 0.000300
#
# Training epoch 350. Started on 21/12/2020 at 20:41:59.
#
#     Average epoch training time: 00 hours, 00 minutes, 05 seconds
#
#     loss = 0.133753
#     categorical_accuracy = 0.994110
#     val_loss = 0.487873
#     val_categorical_accuracy = 0.958069
#     lr = 0.000300
#
# Training epoch 400. Started on 21/12/2020 at 20:43:08.
#
#     Average epoch training time: 00 hours, 00 minutes, 05 seconds
#
#     loss = 0.127010
#     categorical_accuracy = 0.993633
#     val_loss = 0.548291
#     val_categorical_accuracy = 0.954257
#     lr = 0.000300
#
# Training epoch 450. Started on 21/12/2020 at 20:44:17.
#
#     Average epoch training time: 00 hours, 00 minutes, 05 seconds
#
#     loss = 0.093344
#     categorical_accuracy = 0.995702
#     val_loss = 0.459081
#     val_categorical_accuracy = 0.969504
#     lr = 0.000090
#
# Training epoch 500. Started on 21/12/2020 at 20:45:26.
#
#     Average epoch training time: 00 hours, 00 minutes, 04 seconds
#
#     loss = 0.071301
#     categorical_accuracy = 0.996975
#     val_loss = 0.525444
#     val_categorical_accuracy = 0.969504
#     lr = 0.000090
#
# Training epoch 550. Started on 21/12/2020 at 20:46:35.
#
#     Average epoch training time: 00 hours, 00 minutes, 04 seconds
#
#     loss = 0.072968
#     categorical_accuracy = 0.995702
#     val_loss = 0.464898
#     val_categorical_accuracy = 0.963151
#     lr = 0.000090
#
# Training epoch 600. Started on 21/12/2020 at 20:47:44.
#
#     Average epoch training time: 00 hours, 00 minutes, 04 seconds
#
#     loss = 0.069823
#     categorical_accuracy = 0.996020
#     val_loss = 0.512975
#     val_categorical_accuracy = 0.965693
#     lr = 0.000090
#
# Training epoch 650. Started on 21/12/2020 at 20:48:54.
#
#     Average epoch training time: 00 hours, 00 minutes, 03 seconds
#
#     loss = 0.052950
#     categorical_accuracy = 0.997135
#     val_loss = 0.471857
#     val_categorical_accuracy = 0.968234
#     lr = 0.000027
#
# Training epoch 700. Started on 21/12/2020 at 20:50:03.
#
#     Average epoch training time: 00 hours, 00 minutes, 03 seconds
#
#     loss = 0.047686
#     categorical_accuracy = 0.998408
#     val_loss = 0.486217
#     val_categorical_accuracy = 0.965693
#     lr = 0.000027
#
# Training epoch 750. Started on 21/12/2020 at 20:51:12.
#
#     Average epoch training time: 00 hours, 00 minutes, 03 seconds
#
#     loss = 0.044409
#     categorical_accuracy = 0.998886
#     val_loss = 0.454075
#     val_categorical_accuracy = 0.965693
#     lr = 0.000027
#
# Training epoch 800. Started on 21/12/2020 at 20:52:21.
#
#     Average epoch training time: 00 hours, 00 minutes, 03 seconds
#
#     loss = 0.040367
#     categorical_accuracy = 0.998727
#     val_loss = 0.467078
#     val_categorical_accuracy = 0.968234
#     lr = 0.000008
#
# Training epoch 850. Started on 21/12/2020 at 20:53:30.
#
#     Average epoch training time: 00 hours, 00 minutes, 03 seconds
#
#     loss = 0.040345
#     categorical_accuracy = 0.998249
#     val_loss = 0.468377
#     val_categorical_accuracy = 0.969504
#     lr = 0.000008
#
# Training epoch 900. Started on 21/12/2020 at 20:54:39.
#
#     Average epoch training time: 00 hours, 00 minutes, 03 seconds
#
#     loss = 0.039919
#     categorical_accuracy = 0.998727
#     val_loss = 0.476365
#     val_categorical_accuracy = 0.969504
#     lr = 0.000008
#
# Training epoch 950. Started on 21/12/2020 at 20:55:48.
#
#     Average epoch training time: 00 hours, 00 minutes, 03 seconds
#
#     loss = 0.037449
#     categorical_accuracy = 0.998886
#     val_loss = 0.468083
#     val_categorical_accuracy = 0.966963
#     lr = 0.000002
#
# Training epoch 1000. Started on 21/12/2020 at 20:56:57.
#
#     Average epoch training time: 00 hours, 00 minutes, 03 seconds
#
#     loss = 0.037606
#     categorical_accuracy = 0.999045
#     val_loss = 0.457945
#     val_categorical_accuracy = 0.969504
#     lr = 0.000002
#
# Training ended on 21/12/2020 at 20:56:58 after 00 hours, 23 minutes, 37 seconds.

# %% [markdown]
# ## Visualisation of the Training Data
#
# We plot the metrics and the loss of the training for reference.

# %%
inception_hst = pd.DataFrame(inception_hst.history)
inception_hst.to_json(os.path.join(mod_dir, 'history.json'), orient='index')

# %%
plot_loss(os.path.join(mod_dir, 'history.json'),
          out_name='inception_loss',
          root=img_dir,
          validation=True,
          title='Loss Function (categorical crossentropy)',
          yscale='log',
          base_ratio=(1,1),
          show=True,
          save_pdf=True
         )

# %%
plot_metric(os.path.join(mod_dir, 'history.json'),
            metric='categorical_accuracy',
            out_name='cat_acc',
            root=img_dir,
            validation=True,
            title='',
            ylabel='categorical accuracy',
            yscale=None,
            base_ratio=(1,1),
            show=True,
            save_pdf=True
           )

# %%
plot_lr(os.path.join(mod_dir, 'history.json'),
        out_name='inception_lr',
        root=img_dir,
        show=True,
        save_pdf=True
       )

# %% [markdown]
# ## Test Predictions
#
# We finally compute the predictions on the test set.

# %%
model = keras.models.load_model(os.path.join(mod_dir, 'val_loss.h5'))

# %%
y_pred = model.predict(X_test)
y_pred = {key: value.argmax(axis=1) for key, value in y_pred.items()}
y_true = {key: value.argmax(axis=1) for key, value in y_test.items()}

# %%
test_accuracy = {key: np.mean(np.equal(y_pred[key], y_true[key])) for key in y_true.keys()}
for key in test_accuracy.keys():
    print('Test set accuracy:\n')
    print(f'  {key}: {test_accuracy[key]:.3f}')
# Out:
# Test set accuracy:
#
#   h11: 0.967

# %%
with open(os.path.join(mod_dir, 'test_accuracy.json'), 'w') as f:
    json.dump(test_accuracy, f)
